# %%
import geopandas as gpd
from shapely.geometry import Point
import pandas as pd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
from key_2 import api_key
import requests
from IPython.core.display import display, HTML
from IPython.display import Image
import json
# %matplotlib inline

# %% [markdown]
# response=response.json()

# %%
zipcodes = gpd.read_file('zipcodes.geojson')
print(zipcodes.crs)
zipcodes.head( )
# Out:
# epsg:4326
#      zip objectid    po_name      shape_stlength        shape_starea  \
# 0  37115        1    MADISON  178783.02488886821  596553400.57885742
# 1  37216        3  NASHVILLE  75820.997821400058  188884682.28344727
# 2  37204        9  NASHVILLE  93180.292250425613  200664795.51708984
# 3  37027       11  BRENTWOOD   159760.6942933173  174978422.04101562
# 4  37064       18   FRANKLIN  28995.828320601937  46969608.005737305
#
#                                             geometry
# 0  MULTIPOLYGON (((-86.68725 36.31821, -86.68722 ...
# 1  MULTIPOLYGON (((-86.73451 36.23774, -86.73425 ...
# 2  MULTIPOLYGON (((-86.77914 36.13424, -86.77923 ...
# 3  MULTIPOLYGON (((-86.81258 36.06319, -86.81263 ...
# 4  MULTIPOLYGON (((-87.02197 36.01200, -87.02140 ...

# %%
endpoint_nash ='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.163242365862246,-86.78142455028717&maxResults=60&radius=8000&keyword=groceries&key=AIzaSyDR7esAMJqahioM7VjF0FOsoM3mv1Jheo4'

# %%
def find_nearby_places_nash(api_key=api_key,
                      location='36.163242365862246,-86.78142455028717',
                      radius='8000',
                      base = 'https://maps.googleapis.com/maps/api/place/nearbysearch/',
                      keyword= 'groceries',
                      response_type = 'json',
                      pageToken='nextPageToken',
                      **kwargs):
    '''
    Constructs endpoint and params dict, makes request, and returns output as json
    
    api_key: requred, str, API key from google cloud console
    location: required, str, central location for near by search, format: "<lat>, <lng>"
    radius: required, str, radius of circle (in meters) to search for nearby locations
    base: not required, str, URL base for API request
    resoponse_type: not required, format of response
    **kwargs: not required, search criteria for near by locations
    '''
    endpoint_nash = base+response_type
    kwargs['key'] = api_key
    kwargs['location'] = '36.163242365862246,-86.78142455028717'
    kwargs['radius'] = '8000'
    kwargs['pageToken']= 'nextPageToken'
    kwargs['keyword'] = 'groceries',
    res = requests.get(endpoint_nash, kwargs)
    return res.json()

# %%
main_nash ='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.163242365862246,-86.78142455028717&pageToken=api_key&radius=8000&keyword=groceries&key=api_key'

# %%
def find_nearby_places_main_nash(api_key=api_key,
                      location='36.163242365862246,-86.78142455028717',
                      radius='8000',
                      base = 'https://maps.googleapis.com/maps/api/place/nearbysearch/',
                      keyword= 'groceries',
                      response_type = 'json',
                      **kwargs):
    '''
    Constructs endpoint and params dict, makes request, and returns output as json
    
    api_key: requred, str, API key from google cloud console
    location: required, str, central location for near by search, format: "<lat>, <lng>"
    radius: required, str, radius of circle (in meters) to search for nearby locations
    base: not required, str, URL base for API request
    resoponse_type: not required, format of response
    **kwargs: not required, search criteria for near by locations
    '''
    main_nash = base+response_type
    kwargs['key'] = api_key
    kwargs['location'] = '36.163242365862246,-86.78142455028717'
    kwargs['radius'] = '8000'
    kwargs['pageToken']= 'nextPageToken'
    kwargs['keyword'] = 'groceries',
    res = requests.get(main_nash, kwargs)
    return res.json()

# %% [markdown]
# response = requests.get(endpoint, params = params)

# %%
response_m = requests.get(main_nash)

# %%
response_main = find_nearby_places_main_nash()

# %%
endpoint_east='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.19537564483769, -86.74323696479676&maxResults=60&radius=8000&keyword=groceries&key=AIzaSyDR7esAMJqahioM7VjF0FOsoM3mv1Jheo4'

# %%
def find_nearby_places_east(api_key=api_key,
                      location='36.19537564483769, -86.74323696479676',
                      radius='8000',
                      base = 'https://maps.googleapis.com/maps/api/place/nearbysearch/',
                      keyword= 'groceries',
                      response_type = 'json',
                      pageToken='nextPageToken',
                      **kwargs):
    '''
    Constructs endpoint and params dict, makes request, and returns output as json
    
    api_key: requred, str, API key from google cloud console
    location: required, str, central location for near by search, format: "<lat>, <lng>"
    radius: required, str, radius of circle (in meters) to search for nearby locations
    base: not required, str, URL base for API request
    resoponse_type: not required, format of response
    **kwargs: not required, search criteria for near by locations
    '''
    endpoint_east = base+response_type
    kwargs['key'] = api_key
    kwargs['location'] = '36.19537564483769, -86.74323696479676'
    kwargs['radius'] = '8000'
    kwargs['pageToken']= 'nextPageToken'
    kwargs['keyword'] = 'groceries',
    res = requests.get(endpoint_east, kwargs)
    return res.json()

# %%
response_e = requests.get(endpoint_east)

# %%
response_east = find_nearby_places_east()
response_east
# Out:
# {'html_attributions': [],
#  'next_page_token': 'ATtYBwJTWcLERz4jtV5cmH-B5Ccq7mmxJM-T1fwqqhSgBPK23svyQcuyitkBfTnPCBtw10gtfnVjXywFLIrpl2qIHG3IdTd379ElJCQM8C1isgnqKG3hVpIqJ3L-y4XYMG0aQMyc9E97SnguKCnMI9x6BLpfT4-uBCyn-evxOjBNLJn2fvfuNHNjrWXI1mGn0YxaCs7ZIbh5PGUGetqdoefnFnAnZ9xjrTZ9TGyfSBb27YAOnju8buH1AiwCk5xKbTXLB8uRdoDYeCly4nrsOhPmSaMh9qohQXksoEvdfQJkErXF8jKSJJPgh2TpQVtaV9zqOIuVt1YguDuN-c8QO-WCXphU4GXEW9DLdCsNuBP4opXN6zq0cA861sZk99aTJfOXTloov-1h-Is5xBdJte-sZRl4IPoiyvmeZ43nw3lHCPFWAgr0VHNpgfQyXp4',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1758569, 'lng': -86.79427369999999},
#     'viewport': {'northeast': {'lat': 36.17703907989273,
#       'lng': -86.79283387010727},
#      'southwest': {'lat': 36.17433942010728, 'lng': -86.79553352989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1280,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110336675155918874463">Kroger</a>'],
#      'photo_reference': 'ATtYBwK8q6qGO8x2SM2bIY6F3agEVSwkW2eFmS06xHLBNf3WaeU2tDO610RxRvCWa0jOvgoSk0fbR2QDjp8YviUYjqViSFfOpaHaLRpGS3ZMF2QFz-VKWlTvrr3ieqbFZuelwj3JCr_0RLM9nmXAjVrSgxOLk28441TxeBe9Mx-xV8YbNmnA',
#      'width': 1920}],
#    'place_id': 'ChIJ0f1NweJmZIgRYnc_3nqNyag',
#    'plus_code': {'compound_code': '56G4+87 Nashville, Tennessee',
#     'global_code': '868M56G4+87'},
#    'price_level': 2,
#    'rating': 3.7,
#    'reference': 'ChIJ0f1NweJmZIgRYnc_3nqNyag',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 890,
#    'vicinity': '800 Monroe St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1445892, 'lng': -86.8136},
#     'viewport': {'northeast': {'lat': 36.14593902989272,
#       'lng': -86.81225017010728},
#      'southwest': {'lat': 36.14323937010727, 'lng': -86.81494982989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Piggly Wiggly',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113359179597487495544">Jack Warman</a>'],
#      'photo_reference': 'ATtYBwKGfU7DGX-zL82tBHZrrpPUD6tlPveUYUUFghIilMnVIb0Zq1_ZOY0fJNaIWeFCpMOzag9uBHnnI5EJM0HHLenMfzDDFsZwcMDoa-p1I7Yrz6F6H15E62GAZHnrrULTCxKvlp_A3Zgjq1oSPXccLvaH_n0ebMI5tsIVPoR0t9HyZGFO',
#      'width': 3840}],
#    'place_id': 'ChIJF_mw3q9mZIgRQdSpspW80MQ',
#    'plus_code': {'compound_code': '45VP+RH Nashville, Tennessee',
#     'global_code': '868M45VP+RH'},
#    'price_level': 2,
#    'rating': 4,
#    'reference': 'ChIJF_mw3q9mZIgRQdSpspW80MQ',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 364,
#    'vicinity': '2900 West End Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1301887, 'lng': -86.80261089999999},
#     'viewport': {'northeast': {'lat': 36.13147872989272,
#       'lng': -86.80109647010728},
#      'southwest': {'lat': 36.12877907010727, 'lng': -86.80379612989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117053513999049084047">Katherine Romero</a>'],
#      'photo_reference': 'ATtYBwIfGe_Ooz8zeoaqqjMb4YvqPB4UJZoxlNFPhGqqo2dVVGmMAGNUzymFx_Em33f8k8W5dXhushUEaNKc7Wt5ZNHEI0hDuMaounxKTr0krnl__t3kmzfWJgDuoHAf928Bcx5yN6qs3dvBNAeHTJCxrVmOWoqwVgReGaNwGFjoIYOWOUaL',
#      'width': 3264}],
#    'place_id': 'ChIJ8XuUZR9kZIgRohFW4543QB8',
#    'plus_code': {'compound_code': '45JW+3X Nashville, Tennessee',
#     'global_code': '868M45JW+3X'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJ8XuUZR9kZIgRohFW4543QB8',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 555,
#    'vicinity': '2201 21st Ave S, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1708586, 'lng': -86.6787306},
#     'viewport': {'northeast': {'lat': 36.17232252989272,
#       'lng': -86.67756927010727},
#      'southwest': {'lat': 36.16962287010728, 'lng': -86.6802689298927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113890435250045612467">sweetsunnydaygirl</a>'],
#      'photo_reference': 'ATtYBwK1eP4zvXGBRrOMhqMcFWtuE3A2noiGjY7bIHT7GJATtwYp-BxmDFcORQZOgeqqCTu4QRT0lpX3xwu4fHiXhvmtDea4-BCTTw7FiB5zveygqW6Ks9LhAsPFayeVrW_N-T0auzFKpwpacU7aozeVBPn8cweytu26PhZGG5nsAGIXgSS3',
#      'width': 4032}],
#    'place_id': 'ChIJ01nR5XRpZIgR9acvgLYOuAA',
#    'plus_code': {'compound_code': '58CC+8G Nashville, Tennessee',
#     'global_code': '868M58CC+8G'},
#    'price_level': 2,
#    'rating': 4,
#    'reference': 'ChIJ01nR5XRpZIgR9acvgLYOuAA',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 864,
#    'vicinity': '143 McGavock Pk, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1853811, 'lng': -86.8159932},
#     'viewport': {'northeast': {'lat': 36.18672577989272,
#       'lng': -86.81482187010728},
#      'southwest': {'lat': 36.18402612010727, 'lng': -86.81752152989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Save A Lot',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1440,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111089389699251425402">A Google User</a>'],
#      'photo_reference': 'ATtYBwLLpDmM0EnJAvdG2ORPGXlQHeNT51mt_RD-nRFZ6ck4IL-nchlN4mPl393063NCeRe33tM6Nhq8zdynHxj9hSTEIzmuSd6R81_1iKaUDyZzflQbnx0z8Ndp0TOfm7udQuMIOyTLUWmLQ-3KD-XmamJFEPW9OVk52fSTW8fHiqemUWSh',
#      'width': 2560}],
#    'place_id': 'ChIJCTHj7C5nZIgR8KzLicfUjkw',
#    'plus_code': {'compound_code': '55PM+5J Nashville, Tennessee',
#     'global_code': '868M55PM+5J'},
#    'rating': 4,
#    'reference': 'ChIJCTHj7C5nZIgR8KzLicfUjkw',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 516,
#    'vicinity': '2400 Clarksville Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.2101188, 'lng': -86.7324397},
#     'viewport': {'northeast': {'lat': 36.21148802989272,
#       'lng': -86.73108607010728},
#      'southwest': {'lat': 36.20878837010728, 'lng': -86.73378572989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3096,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116765434657480531728">A Google User</a>'],
#      'photo_reference': 'ATtYBwI8aKlnkGfcsmXzWpzzBL8KAkPLDTZi6eQL7h2QhNypYCJOUYU6NJj8mBvKOKk4z6nzYjJvhRiuUed7j_xzSel5ANeE6Jsk6aJ2vYkrYC3kf5yiGI9A0OKiokndbIc9TeojKunf_Qn0ZSN0e1sAkOfdVRkQK0Ph-aKNKSDQ6EBuV7oe',
#      'width': 4128}],
#    'place_id': 'ChIJZyYDJgVoZIgRp_UaluUQWjY',
#    'plus_code': {'compound_code': '6769+22 Nashville, Tennessee',
#     'global_code': '868M6769+22'},
#    'price_level': 2,
#    'rating': 3.9,
#    'reference': 'ChIJZyYDJgVoZIgRp_UaluUQWjY',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 895,
#    'vicinity': '3410 Gallatin Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.163237, 'lng': -86.66439419999999},
#     'viewport': {'northeast': {'lat': 36.16457252989272,
#       'lng': -86.66282442010728},
#      'southwest': {'lat': 36.16187287010727, 'lng': -86.66552407989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Titantic Markets',
#    'place_id': 'ChIJPQif43xpZIgR2ffKTkadUNo',
#    'plus_code': {'compound_code': '587P+76 Nashville, Tennessee',
#     'global_code': '868M587P+76'},
#    'rating': 0,
#    'reference': 'ChIJPQif43xpZIgR2ffKTkadUNo',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': '158 Donelson Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1594967, 'lng': -86.8140176},
#     'viewport': {'northeast': {'lat': 36.16086467989272,
#       'lng': -86.81256562010728},
#      'southwest': {'lat': 36.15816502010728, 'lng': -86.81526527989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "Resha's Bi-Rite Market",
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJ4ZED5shmZIgRz1kBNC9ENYg',
#    'plus_code': {'compound_code': '555P+Q9 Nashville, Tennessee',
#     'global_code': '868M555P+Q9'},
#    'rating': 3.8,
#    'reference': 'ChIJ4ZED5shmZIgRz1kBNC9ENYg',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 57,
#    'vicinity': '717 25th Ave N, Nashville'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 36.1634125, 'lng': -86.779421},
#     'viewport': {'northeast': {'lat': 36.16473492989273,
#       'lng': -86.77817392010726},
#      'southwest': {'lat': 36.16203527010729, 'lng': -86.78087357989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'H.G. Hill Urban Market',
#    'permanently_closed': True,
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106519442576080453760">A Google User</a>'],
#      'photo_reference': 'ATtYBwLMUI43-DkszgoUYKACU05K6rwkQC-153mEV5BLx9zlTZf6sqDZ20Vkr9Ng8ss_CisHNKs0pHI2TlgsYlPbzPVOoumecL9dLmoBplniKGlFsaYds6mAy2BEJFhv-4C8cHte7u1XyOiEDhIYcK4nsEcj5wgLDoJN5AiQBizO-oborm2A',
#      'width': 3264}],
#    'place_id': 'ChIJPStOVVhmZIgRso0FW3wu3Hw',
#    'plus_code': {'compound_code': '567C+96 Nashville, Tennessee',
#     'global_code': '868M567C+96'},
#    'rating': 4.2,
#    'reference': 'ChIJPStOVVhmZIgRso0FW3wu3Hw',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 191,
#    'vicinity': '415 Church St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1707496, 'lng': -86.6838302},
#     'viewport': {'northeast': {'lat': 36.17199487989272,
#       'lng': -86.68247132010727},
#      'southwest': {'lat': 36.16929522010728, 'lng': -86.68517097989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Publix Super Market at The Crossings',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107972891045449379508">James Blunkall</a>'],
#      'photo_reference': 'ATtYBwJ01P8tfGx0ZVbxfMhMgJGyeBjpKotz6M5UPt_ThofoM5HXRjV42h7bAAxY21itJIqoedD6pk4qTyn63yq5wJnroB4-U8BD6iwXzvDY71zzKNglRbLee1XN9Y4I63YGm-zVpn5_t1pEGlV_Z-D8TC1UakfcfVeFppcAvRvyVedJAicN',
#      'width': 5312}],
#    'place_id': 'ChIJWUi8eAtpZIgRPF38_Ur2HUI',
#    'plus_code': {'compound_code': '58C8+7F Nashville, Tennessee',
#     'global_code': '868M58C8+7F'},
#    'price_level': 2,
#    'rating': 4.7,
#    'reference': 'ChIJWUi8eAtpZIgRPF38_Ur2HUI',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'bakery',
#     'liquor_store',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 581,
#    'vicinity': '2324 Lebanon Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1755409, 'lng': -86.75727979999999},
#     'viewport': {'northeast': {'lat': 36.17693902989273,
#       'lng': -86.75582627010729},
#      'southwest': {'lat': 36.17423937010728, 'lng': -86.75852592989274}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Weiss Drive-In Market',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115968242670899721832">Andrea</a>'],
#      'photo_reference': 'ATtYBwIOrHVfoUYEjU0AQVHmfx9XpyOgpPslBG3OqRtUfaNGSKqgoPWKaJwm8Az19gcf-scb4wzjtFHW0mELWgsVlr3jwrZhrecR0glniKOauaK5H5FJTui7yRkSyzcO66OvO47hdt3bmV0gAxwqly9Na4t5svXbxM4ogxEqbBpeyVMek5zH',
#      'width': 4032}],
#    'place_id': 'ChIJrVUAszRmZIgR_uKBTX5M2yo',
#    'plus_code': {'compound_code': '56GV+63 Nashville, Tennessee',
#     'global_code': '868M56GV+63'},
#    'rating': 4.1,
#    'reference': 'ChIJrVUAszRmZIgR_uKBTX5M2yo',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 14,
#    'vicinity': '826 Main St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.2077791, 'lng': -86.76702279999999},
#     'viewport': {'northeast': {'lat': 36.20899562989273,
#       'lng': -86.76577952010727},
#      'southwest': {'lat': 36.20629597010728, 'lng': -86.76847917989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Piggly Wiggly',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2340,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109400472957608256078">Caleb Hendon</a>'],
#      'photo_reference': 'ATtYBwKAzTr2pswbzvNyX7IbpUVaGjYhWMqT8DVg5qU0Wzu51Kjut80rcSEcETzzGgs9uUzkTi73spO7krOCLnIFb8yn2iFfArnnoJuIKHVznXl47h2WGU1AE5j3AfsspeDdowXjghqUshyZbRSf09RlAXt85BdZAbpkpwFFpsQ3WVcpsVxB',
#      'width': 4160}],
#    'place_id': 'ChIJM3OiQKVnZIgRxiZuRvmGZxg',
#    'plus_code': {'compound_code': '665M+45 Nashville, Tennessee',
#     'global_code': '868M665M+45'},
#    'price_level': 2,
#    'rating': 4,
#    'reference': 'ChIJM3OiQKVnZIgRxiZuRvmGZxg',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 535,
#    'vicinity': '2317 Dickerson Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.2505986, 'lng': -86.72085469999999},
#     'viewport': {'northeast': {'lat': 36.25183912989272,
#       'lng': -86.71929847010728},
#      'southwest': {'lat': 36.24913947010727, 'lng': -86.72199812989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Save A Lot',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113069401216296669156">Canon Man</a>'],
#      'photo_reference': 'ATtYBwIHn6wsnrtOEffAnlARe9O8uAVCFftS491eV6jijbrwlJm7fKY08teTNj-Etrgbt0sxt0FT-bVTRoKQc4U548ztD4_VrePuLykRAzz-IuwCWeSR_TCwjJIAljrVC6zMkyiwkWNBo7QqOCaljoD5U_jIBiIXISnmk6PIVztAqamRYVFS',
#      'width': 4032}],
#    'place_id': 'ChIJf6sQRehCZIgRksfIQXBtrwE',
#    'plus_code': {'compound_code': '772H+6M Madison, Nashville, TN',
#     'global_code': '868M772H+6M'},
#    'rating': 4.1,
#    'reference': 'ChIJf6sQRehCZIgRksfIQXBtrwE',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 331,
#    'vicinity': '1134 Gallatin Pike S, Madison'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1257545, 'lng': -86.7109041},
#     'viewport': {'northeast': {'lat': 36.12709057989272,
#       'lng': -86.70937397010728},
#      'southwest': {'lat': 36.12439092010728, 'lng': -86.71207362989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Save A Lot',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3264,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105495554959137446847">A Google User</a>'],
#      'photo_reference': 'ATtYBwKo-B5zFwFk_XBcZ1pYIZyVKmJfmyJrs4XghQ9PVQ-JAjTlZSvOAIMxpPovvBQalXzaQLzkoGZddmCzBtyrH5UI28pzYcgfIWLren0CAdEAPueeBk6AsG_a7LDsS7ePajIPvi0Axgb2ZeWa-uQQgtZ_teLI9fuYW7k1UIMAMHrTkBIc',
#      'width': 2448}],
#    'place_id': 'ChIJHxD44C1vZIgRehI73vtnco0',
#    'plus_code': {'compound_code': '47GQ+8J Nashville, Tennessee',
#     'global_code': '868M47GQ+8J'},
#    'rating': 4,
#    'reference': 'ChIJHxD44C1vZIgRehI73vtnco0',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 583,
#    'vicinity': '1113 Murfreesboro Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1739207, 'lng': -86.7459911},
#     'viewport': {'northeast': {'lat': 36.17517912989273,
#       'lng': -86.74465462010728},
#      'southwest': {'lat': 36.17247947010728, 'lng': -86.74735427989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': '4 Way Market',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106875532012586085102">Massbaum</a>'],
#      'photo_reference': 'ATtYBwLr6SxVXn8MF8ws0ffrykfL43dXELiPIFz-9tE1famd9EM7jnPnTJAx23P46V2rPGTj92EsiphL8_0xv_rhBb5zvPYKFPN_nM0l9dyKGiUMw7ngFkZ05zIfcJlnF128qocmWEekIy0pn5WF80d5kFPilJq3mgGe1VkSYQ7ZGbat0aeb',
#      'width': 4032}],
#    'place_id': 'ChIJCXauaCtmZIgRYZpTghT1TBE',
#    'plus_code': {'compound_code': '57F3+HJ Nashville, Tennessee',
#     'global_code': '868M57F3+HJ'},
#    'rating': 4.3,
#    'reference': 'ChIJCXauaCtmZIgRYZpTghT1TBE',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 74,
#    'vicinity': '1401 Fatherland St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1844743, 'lng': -86.74677849999999},
#     'viewport': {'northeast': {'lat': 36.18570212989272,
#       'lng': -86.74576282010727},
#      'southwest': {'lat': 36.18300247010728, 'lng': -86.74846247989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2201,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113827070569302562718">Andrew L</a>'],
#      'photo_reference': 'ATtYBwJ1DB04BIXdtXsCkVNoDAqAV0KloM1LLi651fgzIThmjk6YeA5VWuX7ZDShOqBdGu1pvTJViA1ZHFaYcObLWa5oG66uHuD35PeXSy_-5X7KRha5KnGPxOqvdIRTXtCfICijuOEh-T1qs6bRsmOOvDolb4J5d71t3vw3ZRw_Q_EEW0c-',
#      'width': 7268}],
#    'place_id': 'ChIJCyiJ2tBnZIgReYaDDx5KLEM',
#    'plus_code': {'compound_code': '57M3+Q7 Nashville, Tennessee',
#     'global_code': '868M57M3+Q7'},
#    'price_level': 2,
#    'rating': 3.7,
#    'reference': 'ChIJCyiJ2tBnZIgReYaDDx5KLEM',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 691,
#    'vicinity': '711 Gallatin Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.2301425, 'lng': -86.7577511},
#     'viewport': {'northeast': {'lat': 36.23138617989272,
#       'lng': -86.75655772010727},
#      'southwest': {'lat': 36.22868652010727, 'lng': -86.75925737989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'H G Hill Food Stores',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3264,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111363067575811693406">Darrell Hulan</a>'],
#      'photo_reference': 'ATtYBwIzjykz5V5e22lOFwJHvjfKsljbWwWgV9ZEa9pwhfGjDkAPNj7SKhb_oQ3V5S4Pric0ur44tYP__D7AwlH0Cg1mOGAs56eOnL74g_Cng28e6VYVMjfxJF8xErr8enBY7ZYvKH5SeaTiJOvpinKMwtUsM5rqrj9UCjlw_2NYkc-tsw8s',
#      'width': 1840}],
#    'place_id': 'ChIJmw2WKENdZIgR70dCGL09NR0',
#    'plus_code': {'compound_code': '66JR+3V Nashville, Tennessee',
#     'global_code': '868M66JR+3V'},
#    'rating': 4.3,
#    'reference': 'ChIJmw2WKENdZIgR70dCGL09NR0',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 553,
#    'vicinity': '3105 Dickerson Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.2619921, 'lng': -86.7141247},
#     'viewport': {'northeast': {'lat': 36.26312487989272,
#       'lng': -86.71256532010727},
#      'southwest': {'lat': 36.26042522010727, 'lng': -86.71526497989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2560,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104680199074870808369">Wendy Banks Foreman</a>'],
#      'photo_reference': 'ATtYBwLc-s7TODd-X0z6iXZeWd47oYVeEKxc8vYAZ1X94uIvl7gBuX_II1nKAKrjIPUszv-rRYtpMPHoG_tyjBd26v3VDysNfcBcUEG9SmA-WxIeStO0A664KRqH52FyIPbTy3SpDgHusZspHuXPYdJP6xJAqVbUCxE40U_RNPcwUNpbDPAI',
#      'width': 1536}],
#    'place_id': 'ChIJYdC5oOJCZIgRKTQyvGwHKB0',
#    'plus_code': {'compound_code': '776P+Q9 Madison, Nashville, TN',
#     'global_code': '868M776P+Q9'},
#    'price_level': 2,
#    'rating': 3.9,
#    'reference': 'ChIJYdC5oOJCZIgRKTQyvGwHKB0',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 785,
#    'vicinity': '200 Gallatin Pike S, Madison'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1360603, 'lng': -86.69944570000001},
#     'viewport': {'northeast': {'lat': 36.13755622989272,
#       'lng': -86.69819217010728},
#      'southwest': {'lat': 36.13485657010727, 'lng': -86.70089182989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "Chico's Mercado",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1920,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113230628559852802167">José Rudy Canizales</a>'],
#      'photo_reference': 'ATtYBwJPcKji2qx5H2HNmedivbVNPyJ14v_zeZg5djcZZ2pohbCWK5IVaMupPxlmHVq01N57IrPDrRb5vUTqi_TwpPzGvcnaaCMzE9qLmfDR6Z_nVdshLSgDBw0HP1rVCa89BhkzPHPa53fA97QrRAZDUhKSPvQ39FvmNMZboQLqXsMEqypz',
#      'width': 1080}],
#    'place_id': 'ChIJq073KippZIgRChERYvn9d9U',
#    'plus_code': {'compound_code': '48P2+C6 Nashville, Tennessee',
#     'global_code': '868M48P2+C6'},
#    'rating': 4.4,
#    'reference': 'ChIJq073KippZIgRChERYvn9d9U',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 72,
#    'vicinity': '859 Briley Pkwy, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1832883, 'lng': -86.7475518},
#     'viewport': {'northeast': {'lat': 36.18446342989272,
#       'lng': -86.74629432010728},
#      'southwest': {'lat': 36.18176377010728, 'lng': -86.74899397989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'ALDI',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118177537537198645393">Lucky O</a>'],
#      'photo_reference': 'ATtYBwL_j9PqgiUWLn4otl3jwF7tWXQWqvSi5xxrClClyojsYXfQfgYWOyc5S6iQcjDRhq1PLrHkC8CW4R7D5zCmjbs_1xHVgIar-CbrTxpHIWcX6_hasU4MVw0dGxFRvlr7lwg-qda8mQodzHFj0taSrVIR-ctqvj_rKX1sd1ZhgXZrNn-T',
#      'width': 3024}],
#    'place_id': 'ChIJgRoqI9FnZIgRK-JHS7MI0qE',
#    'plus_code': {'compound_code': '57M2+8X Nashville, Tennessee',
#     'global_code': '868M57M2+8X'},
#    'price_level': 1,
#    'rating': 4.5,
#    'reference': 'ChIJgRoqI9FnZIgRK-JHS7MI0qE',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 637,
#    'vicinity': '615 Gallatin Ave, Nashville'}],
#  'status': 'OK'}

# %%
endpoint_south='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.10070107139286, -86.76297802246299&maxResults=60&radius=8000&keyword=groceries&key=AIzaSyDR7esAMJqahioM7VjF0FOsoM3mv1Jheo4'

# %%
def find_nearby_places_south(api_key=api_key,
                      location='36.10070107139286, -86.76297802246299',
                      radius='8000',
                      base = 'https://maps.googleapis.com/maps/api/place/nearbysearch/',
                      keyword= 'groceries',
                      response_type = 'json',
                      pageToken='nextPageToken',
                      **kwargs):
    '''
    Constructs endpoint and params dict, makes request, and returns output as json
    
    api_key: requred, str, API key from google cloud console
    location: required, str, central location for near by search, format: "<lat>, <lng>"
    radius: required, str, radius of circle (in meters) to search for nearby locations
    base: not required, str, URL base for API request
    resoponse_type: not required, format of response
    **kwargs: not required, search criteria for near by locations
    '''
    endpoint_south = base+response_type
    kwargs['key'] = api_key
    kwargs['location'] = '36.10070107139286, -86.76297802246299'
    kwargs['radius'] = '8000'
    kwargs['pageToken']= 'nextPageToken'
    kwargs['keyword'] = 'groceries',
    res = requests.get(endpoint_south, kwargs)
    return res.json()

# %%
response_s = requests.get(endpoint_south)

# %%
response_south = find_nearby_places_south()

# %%
endpoint_west='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.14188399793224, -86.86254161940951&maxResults=60&radius=8000&keyword=groceries&key=AIzaSyDR7esAMJqahioM7VjF0FOsoM3mv1Jheo4'

# %%
def find_nearby_places_west(api_key=api_key,
                      location='36.14188399793224, -86.86254161940951',
                      radius='8000',
                      base = 'https://maps.googleapis.com/maps/api/place/nearbysearch/',
                      keyword= 'groceries',
                      response_type = 'json',
                      pageToken='nextPageToken',
                      **kwargs):
    '''
    Constructs endpoint and params dict, makes request, and returns output as json
    
    api_key: requred, str, API key from google cloud console
    location: required, str, central location for near by search, format: "<lat>, <lng>"
    radius: required, str, radius of circle (in meters) to search for nearby locations
    base: not required, str, URL base for API request
    resoponse_type: not required, format of response
    **kwargs: not required, search criteria for near by locations
    '''
    endpoint_south = base+response_type
    kwargs['key'] = api_key
    kwargs['location'] = '36.14188399793224, -86.86254161940951'
    kwargs['radius'] = '8000'
    kwargs['pageToken']= 'nextPageToken'
    kwargs['keyword'] = 'groceries',
    res = requests.get(endpoint_west, kwargs)
    return res.json()

# %%
response_w = requests.get(endpoint_west)

# %%
response_west = find_nearby_places_west()

# %%
endpoint_north='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.18456939531024, -86.81773800109394&maxResults=60&radius=8000&keyword=groceries&key=AIzaSyDR7esAMJqahioM7VjF0FOsoM3mv1Jheo4'

# %%
def find_nearby_places_north(api_key=api_key,
                      location='36.18456939531024, -86.81773800109394',
                      radius='8000',
                      base = 'https://maps.googleapis.com/maps/api/place/nearbysearch/',
                      keyword= 'groceries',
                      response_type = 'json',
                      pageToken='nextPageToken',
                      **kwargs):
    '''
    Constructs endpoint and params dict, makes request, and returns output as json
    
    api_key: requred, str, API key from google cloud console
    location: required, str, central location for near by search, format: "<lat>, <lng>"
    radius: required, str, radius of circle (in meters) to search for nearby locations
    base: not required, str, URL base for API request
    resoponse_type: not required, format of response
    **kwargs: not required, search criteria for near by locations
    '''
    endpoint_north = base+response_type
    kwargs['key'] = api_key
    kwargs['location'] = '36.18456939531024, -86.81773800109394'
    kwargs['radius'] = '8000'
    kwargs['pageToken']= 'nextPageToken'
    kwargs['keyword'] = 'groceries',
    res = requests.get(endpoint_north, kwargs)
    return res.json()

# %%
response_n = requests.get(endpoint_north)

# %%
response_north = find_nearby_places_north()

# %%
endpoint_extra_north='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.25575870948682, -86.84154395259326&radius=8000&keyword=groceries&key=AIzaSyDR7esAMJqahioM7VjF0FOsoM3mv1Jheo4'

# %%
def find_nearby_places_extra_north(api_key=api_key,
                      location='36.25575870948682, -86.84154395259326',
                      radius='8000',
                      base = 'https://maps.googleapis.com/maps/api/place/nearbysearch/',
                      keyword= 'groceries',
                      response_type = 'json',
                      pageToken='nextPageToken',
                      **kwargs):
    '''
    Constructs endpoint and params dict, makes request, and returns output as json
    
    api_key: requred, str, API key from google cloud console
    location: required, str, central location for near by search, format: "<lat>, <lng>"
    radius: required, str, radius of circle (in meters) to search for nearby locations
    base: not required, str, URL base for API request
    resoponse_type: not required, format of response
    **kwargs: not required, search criteria for near by locations
    '''
    endpoint_extra_north = base+response_type
    kwargs['key'] = api_key
    kwargs['location'] = '36.25575870948682, -86.84154395259326'
    kwargs['radius'] = '8000'
    kwargs['pageToken']= 'nextPageToken'
    kwargs['keyword'] = 'groceries',
    res = requests.get(endpoint_extra_north, kwargs)
    return res.json()

# %%
response_ex_n = requests.get(endpoint_extra_north)

# %%
response_extra_n = find_nearby_places_extra_north()

# %%
endpoint_extra_west='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.0835526902928, -86.91534688090898&radius=8000&keyword=groceries&key=AIzaSyDR7esAMJqahioM7VjF0FOsoM3mv1Jheo4'

# %%
def find_nearby_places_extra_west(api_key=api_key,
                      location='36.0835526902928, -86.91534688090898',
                      radius='8000',
                      base = 'https://maps.googleapis.com/maps/api/place/nearbysearch/',
                      keyword= 'groceries',
                      response_type = 'json',
                      pageToken='nextPageToken',
                      **kwargs):
    '''
    Constructs endpoint and params dict, makes request, and returns output as json
    
    api_key: requred, str, API key from google cloud console
    location: required, str, central location for near by search, format: "<lat>, <lng>"
    radius: required, str, radius of circle (in meters) to search for nearby locations
    base: not required, str, URL base for API request
    resoponse_type: not required, format of response
    **kwargs: not required, search criteria for near by locations
    '''
    endpoint_extra_west = base+response_type
    kwargs['key'] = api_key
    kwargs['location'] = '36.0835526902928, -86.91534688090898'
    kwargs['radius'] = '8000'
    kwargs['pageToken']= 'nextPageToken'
    kwargs['keyword'] = 'groceries',
    res = requests.get(endpoint_extra_west, kwargs)
    return res.json()

# %%
response_ex_w = requests.get(endpoint_extra_west)

# %%
response_extra_w = find_nearby_places_extra_west()

# %%
endpoint_extra_south='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.038124618200555, -86.67809866582112&radius=8000&keyword=groceries&key=AIzaSyDR7esAMJqahioM7VjF0FOsoM3mv1Jheo4'

# %%
def find_nearby_places_extra_south(api_key=api_key,
                      location='36.038124618200555, -86.67809866582112',
                      radius='8000',
                      base = 'https://maps.googleapis.com/maps/api/place/nearbysearch/',
                      keyword= 'groceries',
                      response_type = 'json',
                      pageToken='nextPageToken',
                      **kwargs):
    '''
    Constructs endpoint and params dict, makes request, and returns output as json
    
    api_key: requred, str, API key from google cloud console
    location: required, str, central location for near by search, format: "<lat>, <lng>"
    radius: required, str, radius of circle (in meters) to search for nearby locations
    base: not required, str, URL base for API request
    resoponse_type: not required, format of response
    **kwargs: not required, search criteria for near by locations
    '''
    endpoint_extra_south = base+response_type
    kwargs['key'] = api_key
    kwargs['location'] = '36.038124618200555, -86.67809866582112'
    kwargs['radius'] = '8000'
    kwargs['pageToken']= 'nextPageToken'
    kwargs['keyword'] = 'groceries',
    res = requests.get(endpoint_extra_south, kwargs)
    return res.json()

# %%
response_ex_s = requests.get(endpoint_extra_south)

# %%
response_extra_s = find_nearby_places_extra_south()

# %%
endpoint_extra_east='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.250479864381326, -86.65024593095815&radius=4000&keyword=groceries&key=AIzaSyDR7esAMJqahioM7VjF0FOsoM3mv1Jheo4'

# %%
def find_nearby_places_extra_east(api_key=api_key,
                      location='36.250479864381326, -86.65024593095815',
                      radius='4000',
                      base = 'https://maps.googleapis.com/maps/api/place/nearbysearch/',
                      keyword= 'groceries',
                      response_type = 'json',
                      pageToken='nextPageToken',
                      **kwargs):
    '''
    Constructs endpoint and params dict, makes request, and returns output as json
    
    api_key: requred, str, API key from google cloud console
    location: required, str, central location for near by search, format: "<lat>, <lng>"
    radius: required, str, radius of circle (in meters) to search for nearby locations
    base: not required, str, URL base for API request
    resoponse_type: not required, format of response
    **kwargs: not required, search criteria for near by locations
    '''
    endpoint_extra_east = base+response_type
    kwargs['key'] = api_key
    kwargs['location'] = '36.250479864381326, -86.65024593095815'
    kwargs['radius'] = '4000'
    kwargs['pageToken']= 'nextPageToken'
    kwargs['keyword'] = 'groceries',
    res = requests.get(endpoint_extra_east, kwargs)
    return res.json()

# %%
response_ex_e = requests.get(endpoint_extra_east)

# %%
response_extra_e = find_nearby_places_extra_east()

# %%
endpoint_extra_nashwe='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.126095842613154, -86.97492724047552&radius=6000&keyword=groceries&key=AIzaSyDR7esAMJqahioM7VjF0FOsoM3mv1Jheo4'

# %%
def find_nearby_places_extra_nashwe(api_key=api_key,
                      location='36.126095842613154, -86.97492724047552',
                      radius='6000',
                      base = 'https://maps.googleapis.com/maps/api/place/nearbysearch/',
                      keyword= 'groceries',
                      response_type = 'json',
                      pageToken='nextPageToken',
                      **kwargs):
    '''
    Constructs endpoint and params dict, makes request, and returns output as json
    
    api_key: requred, str, API key from google cloud console
    location: required, str, central location for near by search, format: "<lat>, <lng>"
    radius: required, str, radius of circle (in meters) to search for nearby locations
    base: not required, str, URL base for API request
    resoponse_type: not required, format of response
    **kwargs: not required, search criteria for near by locations
    '''
    endpoint_extra_nashwe = base+response_type
    kwargs['key'] = api_key
    kwargs['location'] = '36.126095842613154, -86.97492724047552'
    kwargs['radius'] = '6000'
    kwargs['pageToken']= 'nextPageToken'
    kwargs['keyword'] = 'groceries',
    res = requests.get(endpoint_extra_nashwe, kwargs)
    return res.json()

# %%
response_ex_nashwe = requests.get(endpoint_extra_nashwe)

# %%
response_extra_nashwe = find_nearby_places_extra_nashwe()

# %%
endpoint_extra_nashno='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.33373282105635, -86.78077822354277&radius=6000&keyword=groceries&key=AIzaSyDR7esAMJqahioM7VjF0FOsoM3mv1Jheo4'

# %%
def find_nearby_places_extra_nashno(api_key=api_key,
                      location='36.33373282105635, -86.78077822354277',
                      radius='6000',
                      base = 'https://maps.googleapis.com/maps/api/place/nearbysearch/',
                      keyword= 'groceries',
                      response_type = 'json',
                      pageToken='nextPageToken',
                      **kwargs):
    '''
    Constructs endpoint and params dict, makes request, and returns output as json
    
    api_key: requred, str, API key from google cloud console
    location: required, str, central location for near by search, format: "<lat>, <lng>"
    radius: required, str, radius of circle (in meters) to search for nearby locations
    base: not required, str, URL base for API request
    resoponse_type: not required, format of response
    **kwargs: not required, search criteria for near by locations
    '''
    endpoint_extra_nashno = base+response_type
    kwargs['key'] = api_key
    kwargs['location'] = '36.33373282105635, -86.78077822354277'
    kwargs['radius'] = '6000'
    kwargs['pageToken']= 'nextPageToken'
    kwargs['keyword'] = 'groceries',
    res = requests.get(endpoint_extra_nashno, kwargs)
    return res.json()

# %%
response_ex_nashno = requests.get(endpoint_extra_nashno)

# %%
response_extra_nashno = find_nearby_places_extra_nashno()

# %%
results_east=pd.DataFrame.from_dict(response_east['results'])

# %%
results_west=pd.DataFrame.from_dict(response_west['results'])

# %%
results_south=pd.DataFrame.from_dict(response_south['results'])

# %%
results_north=pd.DataFrame.from_dict(response_north['results'])

# %%
results_main=pd.DataFrame.from_dict(response_main['results'])

# %% [markdown]
# zipcodes.loc[0, 'geometry']

# %%
print(zipcodes.loc[0, 'geometry'])
# Out:
# MULTIPOLYGON (((-86.68724897141 36.318212121092, -86.687216475338 36.318210560887, -86.687181702435 36.318208780693, -86.68714696276101 36.318206917893, -86.68711218725601 36.318205000347, -86.687077445444 36.318202972151, -86.687042702928 36.318200862685, -86.68703469075101 36.318200362824, -86.687007959928 36.318198697129, -86.68697325063 36.318196422067, -86.686938539918 36.318194065167, -86.68690382778099 36.318191625285, -86.68686914958001 36.318189102792, -86.68683443743301 36.318186498074, -86.6867997571 36.318183810757, -86.686765111412 36.318181040826, -86.686730430357 36.318178188106, -86.686695782299 36.318175225883, -86.68666116771 36.318172208522, -86.686626552408 36.318169108746, -86.686591935688 36.318165926561, -86.68655731872499 36.318162634491, -86.686522735235 36.318159287854, -86.68648815149901 36.318155830759, -86.686453600524 36.318152318529, -86.68641904813001 36.31814872389, -86.68638449549 36.318145018792, -86.686349976324 36.318141259129, -86.68631549014999 36.318137389391, -86.68628096933 36.318133438004, -86.686246516617 36.318129430138, -86.68621202761 36.318125313735, -86.68617760718 36.318121113381, -86.68614315092699 36.318116858854, -86.686108729087 36.318112494817, -86.68607433906 36.318108047609, -86.686039949262 36.318103544879, -86.686005593171 36.318098932643, -86.685971235663 36.318094237998, -86.685939398024 36.318082634251, -86.68590729219601 36.318071498996, -86.685874920782 36.318060887727, -86.68584231535399 36.318050771653, -86.68582538629499 36.318045817313, -86.68580944268599 36.318041152105, -86.68577637041599 36.318032081922, -86.68574309855001 36.318023480412, -86.685709629211 36.318015429399, -86.685675959802 36.31800787396, -86.685642125447 36.318000868832, -86.685608160318 36.317994358884, -86.685573994884 36.317988399449, -86.685539732856 36.317982962468, -86.685505339112 36.317978075611, -86.68547081624 36.317973710821, -86.68543622789301 36.317969869453, -86.68540154318001 36.317966577436, -86.68536676139399 36.317963834774, -86.68533195019501 36.317961615329, -86.685296631768 36.317959617931, -86.685296497355 36.317959611826, -86.68526104442201 36.317957924209, -86.685225561751 36.317956558944, -86.685190048001 36.31795552462, -86.68515453662199 36.317954764393, -86.685118994154 36.317954333964, -86.68508348848999 36.317954234092, -86.685083420601 36.317954233904, -86.685047952189 36.317954434829, -86.68504778177299 36.317954435794, -86.68501241708699 36.317954937711, -86.684976920197 36.317955770571, -86.684941390795 36.317956932663, -86.68490593307 36.317958369605, -86.684870443546 36.317960136348, -86.684835024051 36.317962232888, -86.684801499123 36.317967367212, -86.684767689594 36.317971074161, -86.684733697773 36.317973326831, -86.684699591776 36.317974151733, -86.684665507134 36.317973520632, -86.684631477793 36.317971433333, -86.68459763905 36.317967916542, -86.68456406091801 36.317962970434, -86.684530877033 36.317956593108, -86.684498156464 36.317948839113, -86.684465966872 36.317939682313, -86.684434410539 36.317929174779, -86.684403588837 36.317917345124, -86.684373571297 36.317904219853, -86.68434445928099 36.317889826434, -86.684326674234 36.317879990052, -86.684316287432 36.317874245935, -86.684302824084 36.317865914792, -86.684289191525 36.317857478161, -86.68426324764 36.317839571324, -86.68425610203199 36.317834107592, -86.68423884572699 36.317820888334, -86.684238467028 36.31782059976, -86.684214941205 36.317800597286, -86.684198087132 36.317784659146, -86.684192764759 36.31777962632, -86.684192703379 36.317779560856, -86.684171971159 36.317757713569, -86.684152631595 36.317734995979, -86.684134777648 36.317711445901, -86.68411858438699 36.317687355353, -86.684118479798 36.317687199713, -86.684092188873 36.317669383506, -86.68406566297701 36.317651788949, -86.684038935337 36.31763441471, -86.684012006185 36.317617205848, -86.683984908062 36.317600245732, -86.683957575439 36.317583479794, -86.683930039415 36.31756690614, -86.68390233701599 36.317550554 ...

# %% [markdown]
# #geopandas handles legend styling if you pass a dict of keywords
#
# leg_kwds = {'title': 'Zipcodes', 'loc': 'upper left',
#             'bbox_to_anchor': (1, 1.03), 'ncol': 2}
#
# zipcodes.plot(column = 'zip', figsize=(10, 10),
#               edgecolor = 'black',
#               legend = True, legend_kwds = leg_kwds,
#               cmap = 'Set2')
# plt.show()

# %% [markdown]
# bus_stops = pd.read_csv('../data/busstops_cleaned.csv')
# print(bus_stops.shape)
# bus_stops.head(3)

# %% [markdown]
# bus_stops.info()

# %% [markdown]
# bus_stops['geometry'] = bus_stops.apply(lambda x: Point((float(x.lng),
#                                                          float(x.lat))),
#                                         axis=1)
# bus_stops.head(3)

# %%
zipcodes.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# bus_geo = gpd.GeoDataFrame(bus_stops,
#                            crs = zipcodes.crs,
#                            geometry = bus_stops['geometry'])

# %% [markdown]
# type(bus_geo)

# %% [markdown]
# zipcodes = zipcodes[['zip', 'po_name', 'geometry']]

# %% [markdown]
# stops_by_zip = gpd.sjoin(bus_geo, zipcodes, op = 'within')

# %% [markdown]
# stops_by_zip.head()

# %% [markdown]
# stops_by_zip['zip'].value_counts()

# %%
polygon37207 = zipcodes.loc[zipcodes['zip'] == '37207']
polygon37207.shape
# Out:
# (2, 6)

# %% [markdown]
# #fig, ax = matplotlib.subplots()
# ax = polygon37207.plot(figsize = (8, 10), color = 'lightgreen')
# stops_in_37207.plot( ax = ax, column = 'route');
# plt.show();

# %% [markdown]
# #fig, ax = matplotlib.subplots()
# ax = zipcodes.plot(figsize = (8, 10), color = 'lightgreen')
# stops_in_37207.plot( ax = ax, column = 'route');
# plt.show();

# %%
polygon37207.geometry.centroid
# Out:
# <ipython-input-58-4b0ae630d95c>:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   polygon37207.geometry.centroid
# 19    POINT (-86.78726 36.28724)
# 42    POINT (-86.77677 36.23245)
# dtype: geometry

# %%
center = polygon37207.geometry.centroid[42]
print(center)
# Out:
# POINT (-86.77676762469858 36.23245257407244)
# <ipython-input-59-3004e9892aae>:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center = polygon37207.geometry.centroid[42]

# %% [markdown]
# area_center = [center.y, center.x]
#
#
# print(area_center)

# %% [markdown]
# map_37207 = folium.Map(location =  area_center, zoom_start = 12)
# map_37207

# %% [markdown]
# i = 0
# for row_index, row_values in stops_in_37207.iterrows():
#     if i <3:
#         print('index is', row_index)
#         print('values are:')
#         print(' ')
#         print(row_values)
#         print('------------------------- ')
#         i+=1

# %% [markdown]
# map_37207 = folium.Map(location =  area_center, zoom_start = 12)
#
#
#
# for row_index, row_values in stops_in_37207.iterrows():
#     loc = [row_values['lat'], row_values['lng']]
#     pop = str(row_values['route'])
#     marker = folium.Marker(
#         location = loc,
#         popup = pop)
#
#     marker.add_to(map_37207)
# map_37207.save('../maps/map37207.html')
#
# #display our map
# map_37207

# %%
nash_map = folium.Map(location =  area_center, zoom_start = 12)

for store in response_main['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(nash_map)
for store in response_east['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(nash_map)
for store in response_west['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(nash_map)
for store in response_south['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(nash_map)
for store in response_north['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(nash_map)
for store in response_extra_n['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(nash_map)
for store in response_extra_w['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(nash_map)
for store in response_extra_s['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(nash_map)
for store in response_extra_e['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(nash_map)
for store in response_extra_nashwe['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(nash_map)
for store in response_extra_nashno['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(nash_map)

folium.GeoJson(zipcodes).add_to(nash_map)

nash_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Map?

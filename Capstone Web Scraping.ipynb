# %% [markdown]
# #code start

# %%
from bs4 import BeautifulSoup
import pandas as pd
from IPython.core.display import display, HTML
import pandas as pd
import requests
import matplotlib.pyplot as plt
from IPython.display import Image
import folium
from key_2 import api_key
import json
# %matplotlib inline

# %%
endpoint_nash ='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.163242365862246,-86.78142455028717&maxResults=60&radius=1600&keyword=groceries&key=AIzaSyDR7esAMJqahioM7VjF0FOsoM3mv1Jheo4'

# %% [markdown]
# params = dict()
# params["keyword"]= "groceries"

# %% [markdown]
# response = requests.get(endpoint)

# %%
# %who
# Out:
# BeautifulSoup	 HTML	 Image	 api_key	 display	 endpoint_nash	 folium	 json	 pd
# plt	 requests

# %%
def find_nearby_places_nash(api_key=api_key,
                      location='36.163242365862246,-86.78142455028717',
                      radius='1600',
                      base = 'https://maps.googleapis.com/maps/api/place/nearbysearch/',
                      keyword= 'groceries',
                      response_type = 'json',
                      pageToken='nextPageToken',
                      **kwargs):
    '''
    Constructs endpoint and params dict, makes request, and returns output as json
    
    api_key: requred, str, API key from google cloud console
    location: required, str, central location for near by search, format: "<lat>, <lng>"
    radius: required, str, radius of circle (in meters) to search for nearby locations
    base: not required, str, URL base for API request
    resoponse_type: not required, format of response
    **kwargs: not required, search criteria for near by locations
    '''
    endpoint_nash = base+response_type
    kwargs['key'] = api_key
    kwargs['location'] = '36.163242365862246,-86.78142455028717'
    kwargs['radius'] = '1600'
    kwargs['pageToken']= 'nextPageToken'
    kwargs['keyword'] = 'groceries',
    res = requests.get(endpoint_nash, kwargs)
    return res.json()

# %% [markdown]
# print(str(response.url))

# %% [markdown]
# response = requests.post(endpoint)
# response.content

# %% [markdown]
# soup = BeautifulSoup(response.content, "html.parser")
# soup.find(attrs={"class": "section-result"}) \
#     .find("section-divider-bottom-line")

# %% [markdown]
# full2017all = []
# x = 1
# while x < 280:
#   # baseURL = "https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2017-Results"
#     URL ='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.163242365862246,-86.78142455028717&radius=1600&keyword=groceries&key=AIzaSyDR7esAMJqahioM7VjF0FOsoM3mv1Jheo4'.format(x)
#     response = requests.post(URL)
#     soup =BeautifulSoup(response.content, "html.parser")
#     full2017page = soup.find(attrs = {"class": "section-result"}).find("results")
#     full2017_list = pd.read_html(str(full2017page))
#     full2017_list = full2017_list[0]
#     full2017all.append(full2017_list)
#     x += 1

# %% [markdown]
# url='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.160678412664296,-86.78306233064329&radius=1600&keyword=groceries&key=api_key'

# %% [markdown]
# response = requests.get(endpoint, params = params)

# %% [markdown]
# ###URL ='https://www.google.com/maps/search/Groceries/@36.1818696,-86.8284668,14z/data=!3m1!4b1!4m2!2m1!6e6'

# %% [markdown]
# response = requests.post(endpoint)

# %% [markdown]
# response=response.json()

# %%
response = requests.get(endpoint_nash)
response.status_code
# Out:
# 200

# %%
type(response)
# Out:
# requests.models.Response

# %%
response_nash = find_nearby_places_nash()

# %%
response_nash
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1758569, 'lng': -86.79427369999999},
#     'viewport': {'northeast': {'lat': 36.17703907989273,
#       'lng': -86.79283387010727},
#      'southwest': {'lat': 36.17433942010728, 'lng': -86.79553352989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1280,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110336675155918874463">Kroger</a>'],
#      'photo_reference': 'ATtYBwJPphaouyljTve26Tof8OMhHQFpDxty70_riB_BcvH6UBIMswk-WQDfjJISbXgUbof0cXXFEa3vHijbwD4cgaPqV5Sh-AtIStwnuJ9qxRGGhSB2qEDhyAHpxEcnQLgZlFgmtEByMIrG8UDh_WiyR-CdPrSMIytDggIeyDQ06I6-fQZP',
#      'width': 1920}],
#    'place_id': 'ChIJ0f1NweJmZIgRYnc_3nqNyag',
#    'plus_code': {'compound_code': '56G4+87 Nashville, Tennessee',
#     'global_code': '868M56G4+87'},
#    'price_level': 2,
#    'rating': 3.7,
#    'reference': 'ChIJ0f1NweJmZIgRYnc_3nqNyag',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 890,
#    'vicinity': '800 Monroe St, Nashville'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 36.1634125, 'lng': -86.779421},
#     'viewport': {'northeast': {'lat': 36.16473492989273,
#       'lng': -86.77817392010726},
#      'southwest': {'lat': 36.16203527010729, 'lng': -86.78087357989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'H.G. Hill Urban Market',
#    'permanently_closed': True,
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106519442576080453760">A Google User</a>'],
#      'photo_reference': 'ATtYBwI3jZxIws3YNuBIRd6-n-QT_Vxnzs2s3dQ95LGQaX27udjCWrFouj1yvHC5mmSmBAk_qY7coXCZXHhm2eaHhF0t4QFN3ne0Oyj4JAuxJ9G0-DrQOKhkNaiN3Skq_1nKpTW0zVSK4Oz0K0XtgvByQs9W0L4kXs3Wbk_4MIhz5DXOXDmp',
#      'width': 3264}],
#    'place_id': 'ChIJPStOVVhmZIgRso0FW3wu3Hw',
#    'plus_code': {'compound_code': '567C+96 Nashville, Tennessee',
#     'global_code': '868M567C+96'},
#    'rating': 4.2,
#    'reference': 'ChIJPStOVVhmZIgRso0FW3wu3Hw',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 191,
#    'vicinity': '415 Church St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1567496, 'lng': -86.7880596},
#     'viewport': {'northeast': {'lat': 36.15822177989272,
#       'lng': -86.78688217010726},
#      'southwest': {'lat': 36.15552212010728, 'lng': -86.78958182989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Whole Foods Market',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3801,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116546288138045050659">A Google User</a>'],
#      'photo_reference': 'ATtYBwKn3qacvDmpjMhv3GuvtOEXsNgqPwooDtW5OaoCT5q1SkgzSvJoo2WgS_vqaBk-8ihOrsHtrumUQSglkvh0SULM9W2Ey5rxrnIyEtvue8fX3kisHwXcAcxpisjJ43i9fEtrDCD6q6ELm5bUKY86VeYKeZD78MDIkLZaGOAgYVF6ig-P',
#      'width': 6000}],
#    'place_id': 'ChIJY1hOx5hnZIgRaU2PoQEx2R0',
#    'plus_code': {'compound_code': '5646+MQ Nashville, Tennessee',
#     'global_code': '868M5646+MQ'},
#    'rating': 4.6,
#    'reference': 'ChIJY1hOx5hnZIgRaU2PoQEx2R0',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 156,
#    'vicinity': '1202 Broadway, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1527599, 'lng': -86.78545869999999},
#     'viewport': {'northeast': {'lat': 36.15402722989273,
#       'lng': -86.78403837010728},
#      'southwest': {'lat': 36.15132757010728, 'lng': -86.78673802989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'The Turnip Truck Urban Fare',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111780832437308997914">A Google User</a>'],
#      'photo_reference': 'ATtYBwI93NUV142OmgM6HCooh2s8fsLxz9Pu4CdGbEgGrft2SBbQNTDMszz3RzlLtKzbWQcL97ueJBHmOaXnKIXsxV4zZXnXq5AGq5sDWixxMDEzZ7giSgLc1yzxR2cz50n1M8fIV6mOMSjampaaWIS2L-aPIEuOh2JZ25yL4evVpe29r3D1',
#      'width': 3024}],
#    'place_id': 'ChIJE-1HDItmZIgRSm3egxKPeck',
#    'plus_code': {'compound_code': '5637+4R Nashville, Tennessee',
#     'global_code': '868M5637+4R'},
#    'rating': 4.5,
#    'reference': 'ChIJE-1HDItmZIgRSm3egxKPeck',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 424,
#    'vicinity': '321 12th Ave S, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1632696, 'lng': -86.7896679},
#     'viewport': {'northeast': {'lat': 36.16425947989273,
#       'lng': -86.78834562010726},
#      'southwest': {'lat': 36.16155982010728, 'lng': -86.79104527989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Publix Super Market at Capitol View',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101238290545615941587">Jenn Durham</a>'],
#      'photo_reference': 'ATtYBwKsnKTvqD1wzmtvNCLflJSIb52ZDJSYh88mvsML3TAMxYQzcgEp0CJ43wOxTaSTy4rghQXiqUKJLJEVDBq8Dk9IjddFoyMC7zdO8bHIGsEQ5sahwuVfU3KoD_wZtSzhLOSUOg9GPfglTWOcC_q9dtVCq2_0m9uLd4buhs2sfYOemm4g',
#      'width': 4032}],
#    'place_id': 'ChIJ_3hhuz9nZIgROr9342w22Ic',
#    'plus_code': {'compound_code': '5676+84 Nashville, Tennessee',
#     'global_code': '868M5676+84'},
#    'rating': 4.4,
#    'reference': 'ChIJ_3hhuz9nZIgROr9342w22Ic',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'bakery',
#     'liquor_store',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 137,
#    'vicinity': '1010 Dr Martin L King Jr Blvd, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1549405, 'lng': -86.7734169},
#     'viewport': {'northeast': {'lat': 36.15631442989272,
#       'lng': -86.77200867010727},
#      'southwest': {'lat': 36.15361477010727, 'lng': -86.77470832989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'DOWNTOWN FRESH MARKET',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113017152172333760517">A Google User</a>'],
#      'photo_reference': 'ATtYBwI-OjhQpiR5CZ9-AtYNbzpAIK4byQwuwzt-qhlzV-xZbmZTbb-TWyVEJY6xI42jWayizXxVIzR05cV9pzTV8zkuuxSB5emUGiu9sp7DHfURgMFuhWeLMigVrQ5VTd5UMTmKXVc-t23oJdNHF6QCV2Xz7ZiuybcIOh8M09d8McqVNkXG',
#      'width': 3024}],
#    'place_id': 'ChIJuTn3A-tnZIgREs7ZhppWRb0',
#    'plus_code': {'compound_code': '563G+XJ Nashville, Tennessee',
#     'global_code': '868M563G+XJ'},
#    'rating': 5,
#    'reference': 'ChIJuTn3A-tnZIgREs7ZhppWRb0',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'convenience_store',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '531 4th Ave S, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1765293, 'lng': -86.7751309},
#     'viewport': {'northeast': {'lat': 36.17791167989272,
#       'lng': -86.77373622010727},
#      'southwest': {'lat': 36.17521202010727, 'lng': -86.77643587989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "Larry's Quick Stop",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100091017896489400911">Beth1014</a>'],
#      'photo_reference': 'ATtYBwLrVfbpnF21U4mmDwh62QikjKys90fFchI3Ij6mc5ktnNX9yGYXqnh-QyGvsYgiW4Lg733jaIL83C594M0oP4PhaNzNjcEDutAZlfLN_M-8yjKOwSVHvcI99VfSrj6MjCpgs--7VfYKUWkWkzzX3-J6dCrD18nYr5CE7EBUR3bzCdEt',
#      'width': 4160}],
#    'place_id': 'ChIJXyC3zaxnZIgRfcdTJ8AjYCQ',
#    'plus_code': {'compound_code': '56GF+JW Nashville, Tennessee',
#     'global_code': '868M56GF+JW'},
#    'rating': 3,
#    'reference': 'ChIJXyC3zaxnZIgRfcdTJ8AjYCQ',
#    'scope': 'GOOGLE',
#    'types': ['convenience_store',
#     'gas_station',
#     'grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 10,
#    'vicinity': '240 N 1st St, Nashville'}],
#  'status': 'OK'}

# %%
type(response_nash)
# Out:
# dict

# %%
response_nash['results'][0].values()
# Out:
# dict_values(['OPERATIONAL', {'location': {'lat': 36.1758569, 'lng': -86.79427369999999}, 'viewport': {'northeast': {'lat': 36.17703907989273, 'lng': -86.79283387010727}, 'southwest': {'lat': 36.17433942010728, 'lng': -86.79553352989272}}}, 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png', 'Kroger', {'open_now': True}, [{'height': 1280, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110336675155918874463">Kroger</a>'], 'photo_reference': 'ATtYBwJPphaouyljTve26Tof8OMhHQFpDxty70_riB_BcvH6UBIMswk-WQDfjJISbXgUbof0cXXFEa3vHijbwD4cgaPqV5Sh-AtIStwnuJ9qxRGGhSB2qEDhyAHpxEcnQLgZlFgmtEByMIrG8UDh_WiyR-CdPrSMIytDggIeyDQ06I6-fQZP', 'width': 1920}], 'ChIJ0f1NweJmZIgRYnc_3nqNyag', {'compound_code': '56G4+87 Nashville, Tennessee', 'global_code': '868M56G4+87'}, 2, 3.7, 'ChIJ0f1NweJmZIgRYnc_3nqNyag', 'GOOGLE', ['grocery_or_supermarket', 'food', 'point_of_interest', 'store', 'establishment'], 890, '800 Monroe St, Nashville'])

# %%
endpoint_east='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.19537564483769, -86.74323696479676&maxResults=60&radius=1600&keyword=groceries&key=AIzaSyDR7esAMJqahioM7VjF0FOsoM3mv1Jheo4'

# %%
def find_nearby_places_east(api_key=api_key,
                      location='36.19537564483769, -86.74323696479676',
                      radius='1600',
                      base = 'https://maps.googleapis.com/maps/api/place/nearbysearch/',
                      keyword= 'groceries',
                      response_type = 'json',
                      pageToken='nextPageToken',
                      **kwargs):
    '''
    Constructs endpoint and params dict, makes request, and returns output as json
    
    api_key: requred, str, API key from google cloud console
    location: required, str, central location for near by search, format: "<lat>, <lng>"
    radius: required, str, radius of circle (in meters) to search for nearby locations
    base: not required, str, URL base for API request
    resoponse_type: not required, format of response
    **kwargs: not required, search criteria for near by locations
    '''
    endpoint_east = base+response_type
    kwargs['key'] = api_key
    kwargs['location'] = '36.19537564483769, -86.74323696479676'
    kwargs['radius'] = '1600'
    kwargs['pageToken']= 'nextPageToken'
    kwargs['keyword'] = 'groceries',
    res = requests.get(endpoint_east, kwargs)
    return res.json()

# %%
response = requests.get(endpoint_east)
response.status_code
# Out:
# 200

# %%
response_east = find_nearby_places_east()
response_east
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1844743, 'lng': -86.74677849999999},
#     'viewport': {'northeast': {'lat': 36.18570212989272,
#       'lng': -86.74576282010727},
#      'southwest': {'lat': 36.18300247010728, 'lng': -86.74846247989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2201,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113827070569302562718">Andrew L</a>'],
#      'photo_reference': 'ATtYBwJfdw0Mp9oGJ68EyLV18e41EIp7rPZapE3wIQkrpfxtXSU7m9Aersod0acwODgR0KUjhDxUYSj0-WuNoK4FbOSEfcd2VeH54n7EJWfoucfh2cC--tX-VfjwaS4Mq6JhOnQaQFyDgd1gtnLefucQ9eE_UxPqxr7VsdRgj1GeHnYXluCu',
#      'width': 7268}],
#    'place_id': 'ChIJCyiJ2tBnZIgReYaDDx5KLEM',
#    'plus_code': {'compound_code': '57M3+Q7 Nashville, Tennessee',
#     'global_code': '868M57M3+Q7'},
#    'price_level': 2,
#    'rating': 3.7,
#    'reference': 'ChIJCyiJ2tBnZIgReYaDDx5KLEM',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 687,
#    'vicinity': '711 Gallatin Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.2101188, 'lng': -86.7324397},
#     'viewport': {'northeast': {'lat': 36.21148802989272,
#       'lng': -86.73108607010728},
#      'southwest': {'lat': 36.20878837010728, 'lng': -86.73378572989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3096,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116765434657480531728">A Google User</a>'],
#      'photo_reference': 'ATtYBwKMjFRTodudxMIkB1e1djuLOg0d80fLZXMeTdh3Hc97QnkHWuvKYqa_T6IT9Yn3SHYZ8GtCrODruXpVIHD5OOU9tzMzj4sUeOBd3MT4ngU-xJuFcJe0G7oN5qlMhw5Sjc8L7LdfCboquEaOSf9AFZq5k1zMzoUBJ_k6z6to9a-w5JxV',
#      'width': 4128}],
#    'place_id': 'ChIJZyYDJgVoZIgRp_UaluUQWjY',
#    'plus_code': {'compound_code': '6769+22 Nashville, Tennessee',
#     'global_code': '868M6769+22'},
#    'price_level': 2,
#    'rating': 3.9,
#    'reference': 'ChIJZyYDJgVoZIgRp_UaluUQWjY',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 893,
#    'vicinity': '3410 Gallatin Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1832883, 'lng': -86.7475518},
#     'viewport': {'northeast': {'lat': 36.18446342989272,
#       'lng': -86.74629432010728},
#      'southwest': {'lat': 36.18176377010728, 'lng': -86.74899397989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'ALDI',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107053115772497782619">A Google User</a>'],
#      'photo_reference': 'ATtYBwJkTKYftfmCNU__c1Fc0u9BkPi8fY7I-FwBKZxiP0rlh_dQwaKrwqNp4oO4eGjVNVS9LhZUuC60iRGRlockHFyYgMf8xfHjERvncx0bmcz_YaKWdFaTrPvlOsaq7rC3b9XO3rNJX021oS4oN6tEJhw2GJiz9VdZJodu_m97KoZHcqEA',
#      'width': 4032}],
#    'place_id': 'ChIJgRoqI9FnZIgRK-JHS7MI0qE',
#    'plus_code': {'compound_code': '57M2+8X Nashville, Tennessee',
#     'global_code': '868M57M2+8X'},
#    'price_level': 1,
#    'rating': 4.5,
#    'reference': 'ChIJgRoqI9FnZIgRK-JHS7MI0qE',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 631,
#    'vicinity': '615 Gallatin Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.2022406, 'lng': -86.7389614},
#     'viewport': {'northeast': {'lat': 36.20367657989272,
#       'lng': -86.73762212010728},
#      'southwest': {'lat': 36.20097692010728, 'lng': -86.74032177989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "Litton's Corner Market",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3492,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103498631302409342999">Michael Tims</a>'],
#      'photo_reference': 'ATtYBwI9knaFIQRzPpwvJROm2UHGZIj2DIzEJCnb2ADEY7jSqhoiw8EhdPqY1YDdsADdXLCPma9Q5gZbU0TE-LILFoyAzjpIV3xg4z1eLSnJzflqyN0lpx29z27AYwMPjopZVJoJmA00UQIu0ZduB-fzOIrMvGGlrXx9qV-XQAUlGmOoMy8K',
#      'width': 4656}],
#    'place_id': 'ChIJa55T0QtoZIgRtVCd8YGpy8I',
#    'plus_code': {'compound_code': '6726+VC Nashville, Tennessee',
#     'global_code': '868M6726+VC'},
#    'rating': 4.1,
#    'reference': 'ChIJa55T0QtoZIgRtVCd8YGpy8I',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 29,
#    'vicinity': '2830 Gallatin Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.2012332, 'lng': -86.7581587},
#     'viewport': {'northeast': {'lat': 36.20259067989272,
#       'lng': -86.75687717010727},
#      'southwest': {'lat': 36.19989102010728, 'lng': -86.75957682989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Jammers Market',
#    'photos': [{'height': 960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113157421530263330371">Crafty Mama</a>'],
#      'photo_reference': 'ATtYBwKQMfkYa69kVgZl1NQA1_bnybHG2ia462WJbo2foGh0bifEIBebiRWghO_JSbSmEAp79Pg63LoLQneuoa9FZyr-Yv5bVpE1Ae5DQRNBwzYk9mocmIUAgO3DIv6-N8ewFO1c7nP9SwJi89AtXsuWqX0wWi-VScbncsWgzZ5MVBnX3Yfl',
#      'width': 1280}],
#    'place_id': 'ChIJiaIWuetnZIgR7Riz5lPYIYI',
#    'plus_code': {'compound_code': '662R+FP Nashville, Tennessee',
#     'global_code': '868M662R+FP'},
#    'rating': 4.5,
#    'reference': 'ChIJiaIWuetnZIgR7Riz5lPYIYI',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 24,
#    'vicinity': '1519 Jones Ave, Nashville'}],
#  'status': 'OK'}

# %%
endpoint_south='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.10070107139286, -86.76297802246299&maxResults=60&radius=1600&keyword=groceries&key=AIzaSyDR7esAMJqahioM7VjF0FOsoM3mv1Jheo4'

# %%
def find_nearby_places_south(api_key=api_key,
                      location='36.10070107139286, -86.76297802246299',
                      radius='1600',
                      base = 'https://maps.googleapis.com/maps/api/place/nearbysearch/',
                      keyword= 'groceries',
                      response_type = 'json',
                      pageToken='nextPageToken',
                      **kwargs):
    '''
    Constructs endpoint and params dict, makes request, and returns output as json
    
    api_key: requred, str, API key from google cloud console
    location: required, str, central location for near by search, format: "<lat>, <lng>"
    radius: required, str, radius of circle (in meters) to search for nearby locations
    base: not required, str, URL base for API request
    resoponse_type: not required, format of response
    **kwargs: not required, search criteria for near by locations
    '''
    endpoint_south = base+response_type
    kwargs['key'] = api_key
    kwargs['location'] = '36.10070107139286, -86.76297802246299'
    kwargs['radius'] = '1600'
    kwargs['pageToken']= 'nextPageToken'
    kwargs['keyword'] = 'groceries',
    res = requests.get(endpoint_south, kwargs)
    return res.json()

# %%
response = requests.get(endpoint_south)
response.status_code
# Out:
# 200

# %%
response_south = find_nearby_places_south()

# %%
endpoint_west='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.14188399793224, -86.86254161940951&maxResults=60&radius=1600&keyword=groceries&key=AIzaSyDR7esAMJqahioM7VjF0FOsoM3mv1Jheo4'

# %%
def find_nearby_places_west(api_key=api_key,
                      location='36.14188399793224, -86.86254161940951',
                      radius='1600',
                      base = 'https://maps.googleapis.com/maps/api/place/nearbysearch/',
                      keyword= 'groceries',
                      response_type = 'json',
                      pageToken='nextPageToken',
                      **kwargs):
    '''
    Constructs endpoint and params dict, makes request, and returns output as json
    
    api_key: requred, str, API key from google cloud console
    location: required, str, central location for near by search, format: "<lat>, <lng>"
    radius: required, str, radius of circle (in meters) to search for nearby locations
    base: not required, str, URL base for API request
    resoponse_type: not required, format of response
    **kwargs: not required, search criteria for near by locations
    '''
    endpoint_south = base+response_type
    kwargs['key'] = api_key
    kwargs['location'] = '36.14188399793224, -86.86254161940951'
    kwargs['radius'] = '1600'
    kwargs['pageToken']= 'nextPageToken'
    kwargs['keyword'] = 'groceries',
    res = requests.get(endpoint_west, kwargs)
    return res.json()

# %%
response = requests.get(endpoint_west)
response.status_code
# Out:
# 200

# %%
response_west = find_nearby_places_west()

# %%
endpoint_north='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.18456939531024, -86.81773800109394&maxResults=60&radius=1600&keyword=groceries&key=AIzaSyDR7esAMJqahioM7VjF0FOsoM3mv1Jheo4'

# %%
def find_nearby_places_north(api_key=api_key,
                      location='36.18456939531024, -86.81773800109394',
                      radius='1600',
                      base = 'https://maps.googleapis.com/maps/api/place/nearbysearch/',
                      keyword= 'groceries',
                      response_type = 'json',
                      pageToken='nextPageToken',
                      **kwargs):
    '''
    Constructs endpoint and params dict, makes request, and returns output as json
    
    api_key: requred, str, API key from google cloud console
    location: required, str, central location for near by search, format: "<lat>, <lng>"
    radius: required, str, radius of circle (in meters) to search for nearby locations
    base: not required, str, URL base for API request
    resoponse_type: not required, format of response
    **kwargs: not required, search criteria for near by locations
    '''
    endpoint_north = base+response_type
    kwargs['key'] = api_key
    kwargs['location'] = '36.18456939531024, -86.81773800109394'
    kwargs['radius'] = '1600'
    kwargs['pageToken']= 'nextPageToken'
    kwargs['keyword'] = 'groceries',
    res = requests.get(endpoint_north, kwargs)
    return res.json()

# %%
response = requests.get(endpoint_north)
response.status_code
# Out:
# 200

# %%
response_north = find_nearby_places_north()

# %%
results_east=pd.DataFrame.from_dict(response_east['results'])

# %%
results_west=pd.DataFrame.from_dict(response_west['results'])

# %%
results_south=pd.DataFrame.from_dict(response_south['results'])

# %%
results_north=pd.DataFrame.from_dict(response_north['results'])

# %%
type(results_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-1dacf088a631> in <module>
# ----> 1 type(results_df)
#
# NameError: name 'results_df' is not defined

# %% [markdown]
# results_df= pd.concat[(response_east + response_nash + response_north + response_south + response_west)]

# %% [markdown]
# results_df['results'].astype(object)

# %% [markdown]
# results_df=(response_east + response_nash + response_north
# +response_south+ response_west)

# %% [markdown]
# for store in jsonResponse["results"]:
#     print(item["name"])

# %%
results_df = [response_east['results'] + response_nash['results'] + response_north['results']
+response_south['results']+ response_west['results']]

# %%
response_east['results'][0].values()
# Out:
# dict_values(['OPERATIONAL', {'location': {'lat': 36.1844743, 'lng': -86.74677849999999}, 'viewport': {'northeast': {'lat': 36.18570212989272, 'lng': -86.74576282010727}, 'southwest': {'lat': 36.18300247010728, 'lng': -86.74846247989272}}}, 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png', 'Kroger', {'open_now': True}, [{'height': 2201, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113827070569302562718">Andrew L</a>'], 'photo_reference': 'ATtYBwJfdw0Mp9oGJ68EyLV18e41EIp7rPZapE3wIQkrpfxtXSU7m9Aersod0acwODgR0KUjhDxUYSj0-WuNoK4FbOSEfcd2VeH54n7EJWfoucfh2cC--tX-VfjwaS4Mq6JhOnQaQFyDgd1gtnLefucQ9eE_UxPqxr7VsdRgj1GeHnYXluCu', 'width': 7268}], 'ChIJCyiJ2tBnZIgReYaDDx5KLEM', {'compound_code': '57M3+Q7 Nashville, Tennessee', 'global_code': '868M57M3+Q7'}, 2, 3.7, 'ChIJCyiJ2tBnZIgReYaDDx5KLEM', 'GOOGLE', ['grocery_or_supermarket', 'food', 'point_of_interest', 'store', 'establishment'], 687, '711 Gallatin Ave, Nashville'])

# %% [markdown]
# results_df=pd.DataFrame.from_list(results_df['results'])

# %% [markdown]
# results_df=pd.DataFrame(results_df)
# results_df.reset_index()

# %%
type(results_north)
# Out:
# pandas.core.frame.DataFrame

# %%
results_north
# Out:
#   business_status                                           geometry  \
# 0     OPERATIONAL  {'location': {'lat': 36.1853811, 'lng': -86.81...
# 1     OPERATIONAL  {'location': {'lat': 36.193048, 'lng': -86.832...
# 2     OPERATIONAL  {'location': {'lat': 36.1832368, 'lng': -86.81...
# 3     OPERATIONAL  {'location': {'lat': 36.1797936, 'lng': -86.82...
# 4     OPERATIONAL  {'location': {'lat': 36.1823898, 'lng': -86.81...
#
#                                                 icon               name  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...         Save A Lot
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...      Bordeaux Food
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...       SAM'S MARKET
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...            Daily's
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...  Titan Deli Market
#
#          opening_hours                                             photos  \
# 0  {'open_now': False}  [{'height': 1440, 'html_attributions': ['<a hr...
# 1   {'open_now': True}                                                NaN
# 2   {'open_now': True}  [{'height': 2448, 'html_attributions': ['<a hr...
# 3   {'open_now': True}                                                NaN
# 4                  NaN  [{'height': 4032, 'html_attributions': ['<a hr...
#
#                       place_id  \
# 0  ChIJCTHj7C5nZIgR8KzLicfUjkw
# 1  ChIJvTVWTs9gZIgRuVx57Xu68ww
# 2  ChIJGVsGTi9nZIgRAa6Iee-oLMQ
# 3  ChIJUQLDPNVgZIgRmyj3WCvY_Sg
# 4  ChIJ44MojGVnZIgRcTbCBsjkG5M
#
#                                            plus_code  rating  \
# 0  {'compound_code': '55PM+5J Nashville, Tennesse...     4.0
# 1  {'compound_code': '55V9+62 Nashville, Tennesse...     4.2
# 2  {'compound_code': '55MP+7X Nashville, Tennesse...     4.5
# 3  {'compound_code': '55HG+WF Nashville, Tennesse...     0.0
# 4  {'compound_code': '55JP+XW Nashville, Tennesse...     5.0
#
#                      reference   scope  \
# 0  ChIJCTHj7C5nZIgR8KzLicfUjkw  GOOGLE
# 1  ChIJvTVWTs9gZIgRuVx57Xu68ww  GOOGLE
# 2  ChIJGVsGTi9nZIgRAa6Iee-oLMQ  GOOGLE
# 3  ChIJUQLDPNVgZIgRmyj3WCvY_Sg  GOOGLE
# 4  ChIJ44MojGVnZIgRcTbCBsjkG5M  GOOGLE
#
#                                                types  user_ratings_total  \
# 0  [grocery_or_supermarket, food, point_of_intere...                 512
# 1  [grocery_or_supermarket, food, point_of_intere...                 196
# 2  [grocery_or_supermarket, food, point_of_intere...                  34
# 3  [grocery_or_supermarket, food, point_of_intere...                   0
# 4  [grocery_or_supermarket, food, point_of_intere...                   1
#
#                              vicinity
# 0    2400 Clarksville Pike, Nashville
# 1    3205 Clarksville Pike, Nashville
# 2    2012 Clarksville Pike, Nashville
# 3      1740 Ed Temple Blvd, Nashville
# 4  2001 Dr DB Todd Jr Blvd, Nashville

# %%
results_df['results'][0].values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-cf3f4f3685c5> in <module>
# ----> 1 results_df['results'][0].values()
#
# TypeError: list indices must be integers or slices, not str

# %%
results_nash=pd.DataFrame.from_dict(response_nash['results'])
results_nash
# Out:
#       business_status                                           geometry  \
# 0         OPERATIONAL  {'location': {'lat': 36.1758569, 'lng': -86.79...
# 1  CLOSED_TEMPORARILY  {'location': {'lat': 36.1634125, 'lng': -86.77...
# 2         OPERATIONAL  {'location': {'lat': 36.1567496, 'lng': -86.78...
# 3         OPERATIONAL  {'location': {'lat': 36.1527599, 'lng': -86.78...
# 4         OPERATIONAL  {'location': {'lat': 36.1632696, 'lng': -86.78...
# 5         OPERATIONAL  {'location': {'lat': 36.1549405, 'lng': -86.77...
# 6         OPERATIONAL  {'location': {'lat': 36.1765293, 'lng': -86.77...
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
# 5  https://maps.gstatic.com/mapfiles/place_api/ic...
# 6  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                   name        opening_hours  \
# 0                               Kroger   {'open_now': True}
# 1               H.G. Hill Urban Market                  NaN
# 2                   Whole Foods Market   {'open_now': True}
# 3          The Turnip Truck Urban Fare   {'open_now': True}
# 4  Publix Super Market at Capitol View   {'open_now': True}
# 5                DOWNTOWN FRESH MARKET  {'open_now': False}
# 6                   Larry's Quick Stop   {'open_now': True}
#
#                                               photos  \
# 0  [{'height': 1280, 'html_attributions': ['<a hr...
# 1  [{'height': 2448, 'html_attributions': ['<a hr...
# 2  [{'height': 3801, 'html_attributions': ['<a hr...
# 3  [{'height': 4032, 'html_attributions': ['<a hr...
# 4  [{'height': 3024, 'html_attributions': ['<a hr...
# 5  [{'height': 4032, 'html_attributions': ['<a hr...
# 6  [{'height': 2080, 'html_attributions': ['<a hr...
#
#                       place_id  \
# 0  ChIJ0f1NweJmZIgRYnc_3nqNyag
# 1  ChIJPStOVVhmZIgRso0FW3wu3Hw
# 2  ChIJY1hOx5hnZIgRaU2PoQEx2R0
# 3  ChIJE-1HDItmZIgRSm3egxKPeck
# 4  ChIJ_3hhuz9nZIgROr9342w22Ic
# 5  ChIJuTn3A-tnZIgREs7ZhppWRb0
# 6  ChIJXyC3zaxnZIgRfcdTJ8AjYCQ
#
#                                            plus_code  price_level  rating  \
# 0  {'compound_code': '56G4+87 Nashville, Tennesse...          2.0     3.7
# 1  {'compound_code': '567C+96 Nashville, Tennesse...          NaN     4.2
# 2  {'compound_code': '5646+MQ Nashville, Tennesse...          NaN     4.6
# 3  {'compound_code': '5637+4R Nashville, Tennesse...          NaN     4.5
# 4  {'compound_code': '5676+84 Nashville, Tennesse...          NaN     4.4
# 5  {'compound_code': '563G+XJ Nashville, Tennesse...          NaN     5.0
# 6  {'compound_code': '56GF+JW Nashville, Tennesse...          NaN     3.0
#
#                      reference   scope  \
# 0  ChIJ0f1NweJmZIgRYnc_3nqNyag  GOOGLE
# 1  ChIJPStOVVhmZIgRso0FW3wu3Hw  GOOGLE
# 2  ChIJY1hOx5hnZIgRaU2PoQEx2R0  GOOGLE
# 3  ChIJE-1HDItmZIgRSm3egxKPeck  GOOGLE
# 4  ChIJ_3hhuz9nZIgROr9342w22Ic  GOOGLE
# 5  ChIJuTn3A-tnZIgREs7ZhppWRb0  GOOGLE
# 6  ChIJXyC3zaxnZIgRfcdTJ8AjYCQ  GOOGLE
#
#                                                types  user_ratings_total  \
# 0  [grocery_or_supermarket, food, point_of_intere...                 890
# 1  [grocery_or_supermarket, supermarket, food, po...                 191
# 2  [grocery_or_supermarket, supermarket, food, he...                 156
# 3  [grocery_or_supermarket, food, point_of_intere...                 424
# 4  [grocery_or_supermarket, bakery, liquor_store,...                 137
# 5  [grocery_or_supermarket, convenience_store, fo...                   1
# 6  [convenience_store, gas_station, grocery_or_su...                  10
#
#                                    vicinity permanently_closed
# 0                  800 Monroe St, Nashville                NaN
# 1                  415 Church St, Nashville               True
# 2                  1202 Broadway, Nashville                NaN
# 3                 321 12th Ave S, Nashville                NaN
# 4  1010 Dr Martin L King Jr Blvd, Nashville                NaN
# 5                  531 4th Ave S, Nashville                NaN
# 6                   240 N 1st St, Nashville                NaN

# %%
results_df
# Out:
# [[{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1844743, 'lng': -86.74677849999999},
#     'viewport': {'northeast': {'lat': 36.18570212989272,
#       'lng': -86.74576282010727},
#      'southwest': {'lat': 36.18300247010728, 'lng': -86.74846247989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2201,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113827070569302562718">Andrew L</a>'],
#      'photo_reference': 'ATtYBwJfdw0Mp9oGJ68EyLV18e41EIp7rPZapE3wIQkrpfxtXSU7m9Aersod0acwODgR0KUjhDxUYSj0-WuNoK4FbOSEfcd2VeH54n7EJWfoucfh2cC--tX-VfjwaS4Mq6JhOnQaQFyDgd1gtnLefucQ9eE_UxPqxr7VsdRgj1GeHnYXluCu',
#      'width': 7268}],
#    'place_id': 'ChIJCyiJ2tBnZIgReYaDDx5KLEM',
#    'plus_code': {'compound_code': '57M3+Q7 Nashville, Tennessee',
#     'global_code': '868M57M3+Q7'},
#    'price_level': 2,
#    'rating': 3.7,
#    'reference': 'ChIJCyiJ2tBnZIgReYaDDx5KLEM',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 687,
#    'vicinity': '711 Gallatin Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.2101188, 'lng': -86.7324397},
#     'viewport': {'northeast': {'lat': 36.21148802989272,
#       'lng': -86.73108607010728},
#      'southwest': {'lat': 36.20878837010728, 'lng': -86.73378572989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3096,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116765434657480531728">A Google User</a>'],
#      'photo_reference': 'ATtYBwKMjFRTodudxMIkB1e1djuLOg0d80fLZXMeTdh3Hc97QnkHWuvKYqa_T6IT9Yn3SHYZ8GtCrODruXpVIHD5OOU9tzMzj4sUeOBd3MT4ngU-xJuFcJe0G7oN5qlMhw5Sjc8L7LdfCboquEaOSf9AFZq5k1zMzoUBJ_k6z6to9a-w5JxV',
#      'width': 4128}],
#    'place_id': 'ChIJZyYDJgVoZIgRp_UaluUQWjY',
#    'plus_code': {'compound_code': '6769+22 Nashville, Tennessee',
#     'global_code': '868M6769+22'},
#    'price_level': 2,
#    'rating': 3.9,
#    'reference': 'ChIJZyYDJgVoZIgRp_UaluUQWjY',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 893,
#    'vicinity': '3410 Gallatin Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1832883, 'lng': -86.7475518},
#     'viewport': {'northeast': {'lat': 36.18446342989272,
#       'lng': -86.74629432010728},
#      'southwest': {'lat': 36.18176377010728, 'lng': -86.74899397989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'ALDI',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107053115772497782619">A Google User</a>'],
#      'photo_reference': 'ATtYBwJkTKYftfmCNU__c1Fc0u9BkPi8fY7I-FwBKZxiP0rlh_dQwaKrwqNp4oO4eGjVNVS9LhZUuC60iRGRlockHFyYgMf8xfHjERvncx0bmcz_YaKWdFaTrPvlOsaq7rC3b9XO3rNJX021oS4oN6tEJhw2GJiz9VdZJodu_m97KoZHcqEA',
#      'width': 4032}],
#    'place_id': 'ChIJgRoqI9FnZIgRK-JHS7MI0qE',
#    'plus_code': {'compound_code': '57M2+8X Nashville, Tennessee',
#     'global_code': '868M57M2+8X'},
#    'price_level': 1,
#    'rating': 4.5,
#    'reference': 'ChIJgRoqI9FnZIgRK-JHS7MI0qE',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 631,
#    'vicinity': '615 Gallatin Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.2022406, 'lng': -86.7389614},
#     'viewport': {'northeast': {'lat': 36.20367657989272,
#       'lng': -86.73762212010728},
#      'southwest': {'lat': 36.20097692010728, 'lng': -86.74032177989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "Litton's Corner Market",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3492,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103498631302409342999">Michael Tims</a>'],
#      'photo_reference': 'ATtYBwI9knaFIQRzPpwvJROm2UHGZIj2DIzEJCnb2ADEY7jSqhoiw8EhdPqY1YDdsADdXLCPma9Q5gZbU0TE-LILFoyAzjpIV3xg4z1eLSnJzflqyN0lpx29z27AYwMPjopZVJoJmA00UQIu0ZduB-fzOIrMvGGlrXx9qV-XQAUlGmOoMy8K',
#      'width': 4656}],
#    'place_id': 'ChIJa55T0QtoZIgRtVCd8YGpy8I',
#    'plus_code': {'compound_code': '6726+VC Nashville, Tennessee',
#     'global_code': '868M6726+VC'},
#    'rating': 4.1,
#    'reference': 'ChIJa55T0QtoZIgRtVCd8YGpy8I',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 29,
#    'vicinity': '2830 Gallatin Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.2012332, 'lng': -86.7581587},
#     'viewport': {'northeast': {'lat': 36.20259067989272,
#       'lng': -86.75687717010727},
#      'southwest': {'lat': 36.19989102010728, 'lng': -86.75957682989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Jammers Market',
#    'photos': [{'height': 960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113157421530263330371">Crafty Mama</a>'],
#      'photo_reference': 'ATtYBwKQMfkYa69kVgZl1NQA1_bnybHG2ia462WJbo2foGh0bifEIBebiRWghO_JSbSmEAp79Pg63LoLQneuoa9FZyr-Yv5bVpE1Ae5DQRNBwzYk9mocmIUAgO3DIv6-N8ewFO1c7nP9SwJi89AtXsuWqX0wWi-VScbncsWgzZ5MVBnX3Yfl',
#      'width': 1280}],
#    'place_id': 'ChIJiaIWuetnZIgR7Riz5lPYIYI',
#    'plus_code': {'compound_code': '662R+FP Nashville, Tennessee',
#     'global_code': '868M662R+FP'},
#    'rating': 4.5,
#    'reference': 'ChIJiaIWuetnZIgR7Riz5lPYIYI',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 24,
#    'vicinity': '1519 Jones Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1758569, 'lng': -86.79427369999999},
#     'viewport': {'northeast': {'lat': 36.17703907989273,
#       'lng': -86.79283387010727},
#      'southwest': {'lat': 36.17433942010728, 'lng': -86.79553352989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1280,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110336675155918874463">Kroger</a>'],
#      'photo_reference': 'ATtYBwJPphaouyljTve26Tof8OMhHQFpDxty70_riB_BcvH6UBIMswk-WQDfjJISbXgUbof0cXXFEa3vHijbwD4cgaPqV5Sh-AtIStwnuJ9qxRGGhSB2qEDhyAHpxEcnQLgZlFgmtEByMIrG8UDh_WiyR-CdPrSMIytDggIeyDQ06I6-fQZP',
#      'width': 1920}],
#    'place_id': 'ChIJ0f1NweJmZIgRYnc_3nqNyag',
#    'plus_code': {'compound_code': '56G4+87 Nashville, Tennessee',
#     'global_code': '868M56G4+87'},
#    'price_level': 2,
#    'rating': 3.7,
#    'reference': 'ChIJ0f1NweJmZIgRYnc_3nqNyag',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 890,
#    'vicinity': '800 Monroe St, Nashville'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 36.1634125, 'lng': -86.779421},
#     'viewport': {'northeast': {'lat': 36.16473492989273,
#       'lng': -86.77817392010726},
#      'southwest': {'lat': 36.16203527010729, 'lng': -86.78087357989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'H.G. Hill Urban Market',
#    'permanently_closed': True,
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106519442576080453760">A Google User</a>'],
#      'photo_reference': 'ATtYBwI3jZxIws3YNuBIRd6-n-QT_Vxnzs2s3dQ95LGQaX27udjCWrFouj1yvHC5mmSmBAk_qY7coXCZXHhm2eaHhF0t4QFN3ne0Oyj4JAuxJ9G0-DrQOKhkNaiN3Skq_1nKpTW0zVSK4Oz0K0XtgvByQs9W0L4kXs3Wbk_4MIhz5DXOXDmp',
#      'width': 3264}],
#    'place_id': 'ChIJPStOVVhmZIgRso0FW3wu3Hw',
#    'plus_code': {'compound_code': '567C+96 Nashville, Tennessee',
#     'global_code': '868M567C+96'},
#    'rating': 4.2,
#    'reference': 'ChIJPStOVVhmZIgRso0FW3wu3Hw',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 191,
#    'vicinity': '415 Church St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1567496, 'lng': -86.7880596},
#     'viewport': {'northeast': {'lat': 36.15822177989272,
#       'lng': -86.78688217010726},
#      'southwest': {'lat': 36.15552212010728, 'lng': -86.78958182989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Whole Foods Market',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3801,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116546288138045050659">A Google User</a>'],
#      'photo_reference': 'ATtYBwKn3qacvDmpjMhv3GuvtOEXsNgqPwooDtW5OaoCT5q1SkgzSvJoo2WgS_vqaBk-8ihOrsHtrumUQSglkvh0SULM9W2Ey5rxrnIyEtvue8fX3kisHwXcAcxpisjJ43i9fEtrDCD6q6ELm5bUKY86VeYKeZD78MDIkLZaGOAgYVF6ig-P',
#      'width': 6000}],
#    'place_id': 'ChIJY1hOx5hnZIgRaU2PoQEx2R0',
#    'plus_code': {'compound_code': '5646+MQ Nashville, Tennessee',
#     'global_code': '868M5646+MQ'},
#    'rating': 4.6,
#    'reference': 'ChIJY1hOx5hnZIgRaU2PoQEx2R0',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 156,
#    'vicinity': '1202 Broadway, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1527599, 'lng': -86.78545869999999},
#     'viewport': {'northeast': {'lat': 36.15402722989273,
#       'lng': -86.78403837010728},
#      'southwest': {'lat': 36.15132757010728, 'lng': -86.78673802989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'The Turnip Truck Urban Fare',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111780832437308997914">A Google User</a>'],
#      'photo_reference': 'ATtYBwI93NUV142OmgM6HCooh2s8fsLxz9Pu4CdGbEgGrft2SBbQNTDMszz3RzlLtKzbWQcL97ueJBHmOaXnKIXsxV4zZXnXq5AGq5sDWixxMDEzZ7giSgLc1yzxR2cz50n1M8fIV6mOMSjampaaWIS2L-aPIEuOh2JZ25yL4evVpe29r3D1',
#      'width': 3024}],
#    'place_id': 'ChIJE-1HDItmZIgRSm3egxKPeck',
#    'plus_code': {'compound_code': '5637+4R Nashville, Tennessee',
#     'global_code': '868M5637+4R'},
#    'rating': 4.5,
#    'reference': 'ChIJE-1HDItmZIgRSm3egxKPeck',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 424,
#    'vicinity': '321 12th Ave S, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1632696, 'lng': -86.7896679},
#     'viewport': {'northeast': {'lat': 36.16425947989273,
#       'lng': -86.78834562010726},
#      'southwest': {'lat': 36.16155982010728, 'lng': -86.79104527989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Publix Super Market at Capitol View',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101238290545615941587">Jenn Durham</a>'],
#      'photo_reference': 'ATtYBwKsnKTvqD1wzmtvNCLflJSIb52ZDJSYh88mvsML3TAMxYQzcgEp0CJ43wOxTaSTy4rghQXiqUKJLJEVDBq8Dk9IjddFoyMC7zdO8bHIGsEQ5sahwuVfU3KoD_wZtSzhLOSUOg9GPfglTWOcC_q9dtVCq2_0m9uLd4buhs2sfYOemm4g',
#      'width': 4032}],
#    'place_id': 'ChIJ_3hhuz9nZIgROr9342w22Ic',
#    'plus_code': {'compound_code': '5676+84 Nashville, Tennessee',
#     'global_code': '868M5676+84'},
#    'rating': 4.4,
#    'reference': 'ChIJ_3hhuz9nZIgROr9342w22Ic',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'bakery',
#     'liquor_store',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 137,
#    'vicinity': '1010 Dr Martin L King Jr Blvd, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1549405, 'lng': -86.7734169},
#     'viewport': {'northeast': {'lat': 36.15631442989272,
#       'lng': -86.77200867010727},
#      'southwest': {'lat': 36.15361477010727, 'lng': -86.77470832989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'DOWNTOWN FRESH MARKET',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113017152172333760517">A Google User</a>'],
#      'photo_reference': 'ATtYBwI-OjhQpiR5CZ9-AtYNbzpAIK4byQwuwzt-qhlzV-xZbmZTbb-TWyVEJY6xI42jWayizXxVIzR05cV9pzTV8zkuuxSB5emUGiu9sp7DHfURgMFuhWeLMigVrQ5VTd5UMTmKXVc-t23oJdNHF6QCV2Xz7ZiuybcIOh8M09d8McqVNkXG',
#      'width': 3024}],
#    'place_id': 'ChIJuTn3A-tnZIgREs7ZhppWRb0',
#    'plus_code': {'compound_code': '563G+XJ Nashville, Tennessee',
#     'global_code': '868M563G+XJ'},
#    'rating': 5,
#    'reference': 'ChIJuTn3A-tnZIgREs7ZhppWRb0',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'convenience_store',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '531 4th Ave S, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1765293, 'lng': -86.7751309},
#     'viewport': {'northeast': {'lat': 36.17791167989272,
#       'lng': -86.77373622010727},
#      'southwest': {'lat': 36.17521202010727, 'lng': -86.77643587989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "Larry's Quick Stop",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100091017896489400911">Beth1014</a>'],
#      'photo_reference': 'ATtYBwLrVfbpnF21U4mmDwh62QikjKys90fFchI3Ij6mc5ktnNX9yGYXqnh-QyGvsYgiW4Lg733jaIL83C594M0oP4PhaNzNjcEDutAZlfLN_M-8yjKOwSVHvcI99VfSrj6MjCpgs--7VfYKUWkWkzzX3-J6dCrD18nYr5CE7EBUR3bzCdEt',
#      'width': 4160}],
#    'place_id': 'ChIJXyC3zaxnZIgRfcdTJ8AjYCQ',
#    'plus_code': {'compound_code': '56GF+JW Nashville, Tennessee',
#     'global_code': '868M56GF+JW'},
#    'rating': 3,
#    'reference': 'ChIJXyC3zaxnZIgRfcdTJ8AjYCQ',
#    'scope': 'GOOGLE',
#    'types': ['convenience_store',
#     'gas_station',
#     'grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 10,
#    'vicinity': '240 N 1st St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1853811, 'lng': -86.8159932},
#     'viewport': {'northeast': {'lat': 36.18663382989272,
#       'lng': -86.81489022010727},
#      'southwest': {'lat': 36.18393417010728, 'lng': -86.81758987989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Save A Lot',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1440,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111089389699251425402">A Google User</a>'],
#      'photo_reference': 'ATtYBwJYtxdkVKBsHX8JtzcxGX8DLncWXkyg3hoqcPkEzbEnpvB4ssNm_ymIMohH631IhbHOkWD92fc14B9xcseAuG4NwdGOpepi0cYM-aPBOKzqGsp05xhv49Ez6iTGPk4TaPmIlclsON4A8pSyPWfdbojHpraeyw2DINxpVAT_Ax7zGWg4',
#      'width': 2560}],
#    'place_id': 'ChIJCTHj7C5nZIgR8KzLicfUjkw',
#    'plus_code': {'compound_code': '55PM+5J Nashville, Tennessee',
#     'global_code': '868M55PM+5J'},
#    'rating': 4,
#    'reference': 'ChIJCTHj7C5nZIgR8KzLicfUjkw',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 512,
#    'vicinity': '2400 Clarksville Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.193048, 'lng': -86.83246199999999},
#     'viewport': {'northeast': {'lat': 36.19457997989272,
#       'lng': -86.83091502010727},
#      'southwest': {'lat': 36.19188032010727, 'lng': -86.83361467989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Bordeaux Food',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJvTVWTs9gZIgRuVx57Xu68ww',
#    'plus_code': {'compound_code': '55V9+62 Nashville, Tennessee',
#     'global_code': '868M55V9+62'},
#    'rating': 4.2,
#    'reference': 'ChIJvTVWTs9gZIgRuVx57Xu68ww',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 196,
#    'vicinity': '3205 Clarksville Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1832368, 'lng': -86.812551},
#     'viewport': {'northeast': {'lat': 36.18449012989272,
#       'lng': -86.81129432010728},
#      'southwest': {'lat': 36.18179047010728, 'lng': -86.81399397989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "SAM'S MARKET",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103659464595606534317">SAM</a>'],
#      'photo_reference': 'ATtYBwIetAhYQCR7tvFDTWKR7C2pSKWyiM4CCp4Y6SawQaF8m8C03_dY817iNeDU22VkNzIBDBCEp1R_sDRBiTRZOZUL8Qo_e2NtIeL1wREQPB8dzIZYNFbGRtwdmStT0p16JRrauNpgpawuQQKcHxx2Du3ePYUgyhXEEA1QYj6-243c3NFJ',
#      'width': 3264}],
#    'place_id': 'ChIJGVsGTi9nZIgRAa6Iee-oLMQ',
#    'plus_code': {'compound_code': '55MP+7X Nashville, Tennessee',
#     'global_code': '868M55MP+7X'},
#    'rating': 4.5,
#    'reference': 'ChIJGVsGTi9nZIgRAa6Iee-oLMQ',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 34,
#    'vicinity': '2012 Clarksville Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1797936, 'lng': -86.8238214},
#     'viewport': {'northeast': {'lat': 36.18105802989272,
#       'lng': -86.82262987010728},
#      'southwest': {'lat': 36.17835837010727, 'lng': -86.82532952989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "Daily's",
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJUQLDPNVgZIgRmyj3WCvY_Sg',
#    'plus_code': {'compound_code': '55HG+WF Nashville, Tennessee',
#     'global_code': '868M55HG+WF'},
#    'rating': 0,
#    'reference': 'ChIJUQLDPNVgZIgRmyj3WCvY_Sg',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': '1740 Ed Temple Blvd, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1823898, 'lng': -86.8126391},
#     'viewport': {'northeast': {'lat': 36.18380342989272,
#       'lng': -86.81107047010728},
#      'southwest': {'lat': 36.18110377010728, 'lng': -86.81377012989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Titan Deli Market',
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110580202096073238904">Albertine Baker</a>'],
#      'photo_reference': 'ATtYBwJqWhMIDrD35SPwu_HcGAUcPJFawnLkwbvaCHctSS2YzpF9cY8cbPScakAT0N_YKLVSVwkdwjeOylhgB2NPr3VL4hG_gdqUzSP0MDU-cFID8SvCswcu_xpVOKdMApr9tssNQujdKiqBsGqbC5MR1OJeALC_Yq-URvDVq39vhOLkNcSe',
#      'width': 3024}],
#    'place_id': 'ChIJ44MojGVnZIgRcTbCBsjkG5M',
#    'plus_code': {'compound_code': '55JP+XW Nashville, Tennessee',
#     'global_code': '868M55JP+XW'},
#    'rating': 5,
#    'reference': 'ChIJ44MojGVnZIgRcTbCBsjkG5M',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '2001 Dr DB Todd Jr Blvd, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1128669, 'lng': -86.76522740000001},
#     'viewport': {'northeast': {'lat': 36.11389887989272,
#       'lng': -86.76392632010729},
#      'southwest': {'lat': 36.11119922010728, 'lng': -86.76662597989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "Aleksey's Market",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3968,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102540283510731906070">Péter Svajcsik</a>'],
#      'photo_reference': 'ATtYBwJ4nypTXqvHapNAUhPieUH49pZN-An4-gtMpaAAaxDFi7YncQLTOx1G9GnsPzFGddUAp4qgbK13XHEK5PDD3vCwkOf0o2ULu9q4CzPw0G5Fi8QaVZQZHCAPW6AMYSkvIgJxrrDw1E6HOa-fBzqXr0ovlUV5l-KaUlxf70Vllo_yFWsW',
#      'width': 2976}],
#    'place_id': 'ChIJVcZm7MBlZIgRNKQ6_KcFQO8',
#    'plus_code': {'compound_code': '467M+4W Nashville, Tennessee',
#     'global_code': '868M467M+4W'},
#    'rating': 4.8,
#    'reference': 'ChIJVcZm7MBlZIgRNKQ6_KcFQO8',
#    'scope': 'GOOGLE',
#    'types': ['supermarket',
#     'grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 223,
#    'vicinity': '718 Thompson Ln, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.11418, 'lng': -86.74626119999999},
#     'viewport': {'northeast': {'lat': 36.11550922989272,
#       'lng': -86.74504992010728},
#      'southwest': {'lat': 36.11280957010727, 'lng': -86.74774957989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'La Yaquita Super Mercado & Carniceria',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1280,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103304374603220159022">Nathan Freitas</a>'],
#      'photo_reference': 'ATtYBwIYqEkHPfazUc4jsHTwErhxHAiyGxC7fQCitjShP2LoOVjuLm6yJlW25RrxBYzzgocRq-D14iflE01aRDz59qHRIpYGc_Ai8l5KaWuaqhPhK6Lt0OBRj5zc1c3wo7o64hecDd1V_tOQg79tCHmI4e0hb8dl47GjHG_Et6uCYIzZq6pD',
#      'width': 960}],
#    'place_id': 'ChIJVapVzuRlZIgRF79SRgtKBKU',
#    'plus_code': {'compound_code': '4773+MF Nashville, Tennessee',
#     'global_code': '868M4773+MF'},
#    'rating': 3,
#    'reference': 'ChIJVapVzuRlZIgRF79SRgtKBKU',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 9,
#    'vicinity': '2704 Nolensville Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.148724, 'lng': -86.8604389},
#     'viewport': {'northeast': {'lat': 36.15012517989273,
#       'lng': -86.85909187010728},
#      'southwest': {'lat': 36.14742552010728, 'lng': -86.86179152989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103832292777728970389">Clara Molina</a>'],
#      'photo_reference': 'ATtYBwK_HFFszrI0YVq7ASI8jMVVXMHpkFLHZbkEK9oQosPeVWMid-SU5jGTRATU9WRr-Vznz0jg3sjlNPdXTxdDMaWs_x3GnQQgeGk7EQAIK3MdubaHHi-zQhANL7xe9b-khKWCKF2qke4YkSMZbOQmQU8nINxDSEwdc-zPhjJQev8BFyzm',
#      'width': 1920}],
#    'place_id': 'ChIJ_yOHRXZhZIgRSvQatfG8liY',
#    'plus_code': {'compound_code': '44XQ+FR Nashville, Tennessee',
#     'global_code': '868M44XQ+FR'},
#    'price_level': 2,
#    'rating': 3.9,
#    'reference': 'ChIJ_yOHRXZhZIgRSvQatfG8liY',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 655,
#    'vicinity': '5705 Charlotte Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1521777, 'lng': -86.8538342},
#     'viewport': {'northeast': {'lat': 36.15345317989272,
#       'lng': -86.85230927010727},
#      'southwest': {'lat': 36.15075352010727, 'lng': -86.85500892989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Save A Lot',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114873572080972326366">Mohamed</a>'],
#      'photo_reference': 'ATtYBwLztg6-fJ2Uonml-4epBtboKgfWEaj1gq44-3iUpaP48wF9SW9qoTUNzSQwFDZdn_dH2cv9SDAyc_dgilFNH-k5YW6pv1W7nuqcTJ7anjmdZ7nRXMmPFpbW6SC3IJa7uyI0sapg9CinQ-gFchvb5m4wIJl272hgypealc7YC394HqO5',
#      'width': 4032}],
#    'place_id': 'ChIJR3s_9XFhZIgRnOmroUutAIc',
#    'plus_code': {'compound_code': '542W+VF Nashville, Tennessee',
#     'global_code': '868M542W+VF'},
#    'rating': 4.3,
#    'reference': 'ChIJR3s_9XFhZIgRnOmroUutAIc',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 232,
#    'vicinity': '5404 Charlotte Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1470294, 'lng': -86.8635401},
#     'viewport': {'northeast': {'lat': 36.14837922989273,
#       'lng': -86.86219027010728},
#      'southwest': {'lat': 36.14567957010728, 'lng': -86.86488992989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'K&S World Market',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110659991627955763294">Barry Jover</a>'],
#      'photo_reference': 'ATtYBwKrSC1kRNzSVq7b0U-Sjpvmq1hXW_Ec1SzrhMC0Ac9POGDgZKJoQSnUr5VstTHgiyxLgUFoNgnyqnKP_ClG41tVK1PTaDO-oNJ9u6QGRENohc4bbJa0bmdILmj65zakr4bM1fKsyh9fJ8Cv0AvF_6iPi3PjkN19id6vP3PP_B5ns7v9',
#      'width': 3024}],
#    'place_id': 'ChIJOZDICp1hZIgRcZnCutvsQK0',
#    'plus_code': {'compound_code': '44WP+RH Nashville, Tennessee',
#     'global_code': '868M44WP+RH'},
#    'rating': 4.3,
#    'reference': 'ChIJOZDICp1hZIgRcZnCutvsQK0',
#    'scope': 'GOOGLE',
#    'types': ['supermarket',
#     'grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 723,
#    'vicinity': '5861 Charlotte Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1448383, 'lng': -86.8715893},
#     'viewport': {'northeast': {'lat': 36.14632242989272,
#       'lng': -86.87040572010727},
#      'southwest': {'lat': 36.14362277010728, 'lng': -86.87310537989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Mi Favorita Super',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110277181500999606911">Omar M</a>'],
#      'photo_reference': 'ATtYBwJ3VMOZnRMCIq9K_u-V8CFbvBYUKocz07nLOWFE7yDswVKoDDEXIOKOua9rX3rx4FmL4GnxXedha63UQf-9H2QZfWksP1y4RHIZQCyPDHARzKZGrCTg_QjN4IZmWbj-b0N5bMWunXciqZPpTYr1W8zvWrfYtSsRNYOPfgWY4-YUx8OC',
#      'width': 5312}],
#    'place_id': 'ChIJk4INZoVhZIgR6ge7S2DIduY',
#    'plus_code': {'compound_code': '44VH+W9 Nashville, Tennessee',
#     'global_code': '868M44VH+W9'},
#    'rating': 4.2,
#    'reference': 'ChIJk4INZoVhZIgR6ge7S2DIduY',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 146,
#    'vicinity': '6317 Charlotte Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1267272, 'lng': -86.8475064},
#     'viewport': {'northeast': {'lat': 36.12797762989273,
#       'lng': -86.84605667010729},
#      'southwest': {'lat': 36.12527797010728, 'lng': -86.84875632989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Publix Super Market at Hill Center at Belle Meade',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116780368244981387168">Sarah Crawford</a>'],
#      'photo_reference': 'ATtYBwIAJTR4fqA31TgqCAlof0j3Lq68FubaIlYq_2d8TmsTURMK22Moj3YgO4zGESWoGRg4wQ8rh-tD_kT6bJZBek_7gYom-t2BbNqTZHIz_XHf5T4bHVYTyDfvuVWhJi73rBk30MsA3StKt6sitNQ7Bvj6v0s4g9L2RSMARPvHXW6CWa9Y',
#      'width': 3984}],
#    'place_id': 'ChIJ_98e89xjZIgRkX7e3TmFvyw',
#    'plus_code': {'compound_code': '45G2+MX Nashville, Tennessee',
#     'global_code': '868M45G2+MX'},
#    'price_level': 2,
#    'rating': 4.4,
#    'reference': 'ChIJ_98e89xjZIgRkX7e3TmFvyw',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'bakery',
#     'liquor_store',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 358,
#    'vicinity': '4324 Harding Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.14495950000001, 'lng': -86.8740361},
#     'viewport': {'northeast': {'lat': 36.14638327989272,
#       'lng': -86.87254922010727},
#      'southwest': {'lat': 36.14368362010728, 'lng': -86.87524887989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'ALDI',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107244682706324479289">David Ancell</a>'],
#      'photo_reference': 'ATtYBwLyDHnACDSOzX35ki2VfKAXSO-8GXES6Hxu607cNoy9tHk279CLhXALKSprq1hCSUX0Peay5Rx1fK0oX9PCw9t1v1TfQF-_jaoervN0T818p-FK6tYOaExxSYFLo3pg1UNOcCi84Mtmp_cPxOnatF9vyEFX5tr70Nvmyqk-IkuD7nR8',
#      'width': 4032}],
#    'place_id': 'ChIJ75kruY9hZIgRaMHuKhEG7vw',
#    'plus_code': {'compound_code': '44VG+X9 Nashville, Tennessee',
#     'global_code': '868M44VG+X9'},
#    'price_level': 1,
#    'rating': 4.6,
#    'reference': 'ChIJ75kruY9hZIgRaMHuKhEG7vw',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 646,
#    'vicinity': '405 American Rd, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1574323, 'lng': -86.87454939999999},
#     'viewport': {'northeast': {'lat': 36.15888497989272,
#       'lng': -86.87318082010728},
#      'southwest': {'lat': 36.15618532010728, 'lng': -86.87588047989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Robertson Avenue Market',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2576,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112305647775457658496">A Google User</a>'],
#      'photo_reference': 'ATtYBwKXBEnTn3Di8E5JcdDgLt6_o9EXNPjNcSrnmTYhINl14Kh7DpDZMUYDIQIp1qmes14aYuqPP61Bf_2-PVM74UvMOY9CKHb1VbTeTE28uvfBmjGTlVJN8NGjw8cPbt6hoR0dUWCmRUPMYlkLiOT6249nPvG4Z4XrmQojqisjEhzPEdgL',
#      'width': 1932}],
#    'place_id': 'ChIJxcH_fr1hZIgRjt0YWNDQMJI',
#    'plus_code': {'compound_code': '544G+X5 Nashville, Tennessee',
#     'global_code': '868M544G+X5'},
#    'rating': 4.3,
#    'reference': 'ChIJxcH_fr1hZIgRjt0YWNDQMJI',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 88,
#    'vicinity': '6229 Robertson Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1402176, 'lng': -86.8829105},
#     'viewport': {'northeast': {'lat': 36.14146022989272,
#       'lng': -86.88140622010728},
#      'southwest': {'lat': 36.13876057010727, 'lng': -86.88410587989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Publix Super Market at Hill Center at Nashville West',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108113789002620796958">Rex Cope</a>'],
#      'photo_reference': 'ATtYBwL2cyLa738HDYXe_J2IfdoWGyqdJ_Ig7xJPHJrb2_QCryn4r3hieVRBvrhh7au7Td8psQambW0p03WWwALoK1lm_2u-gkGfSEuIwhI1gU9rUR7SleRr63hrn6Xez0971K1it7Y0mouYzcsfqljBtaytV4SP9JSg0GOPdV8HgvJOwYE7',
#      'width': 4032}],
#    'place_id': 'ChIJbSHs2IphZIgRVNJFmBoOn3c',
#    'plus_code': {'compound_code': '44R8+3R Nashville, Tennessee',
#     'global_code': '868M44R8+3R'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJbSHs2IphZIgRVNJFmBoOn3c',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'bakery',
#     'liquor_store',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 421,
#    'vicinity': '6614 Charlotte Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1307261, 'lng': -86.85222700000001},
#     'viewport': {'northeast': {'lat': 36.13209387989272,
#       'lng': -86.85101287010728},
#      'southwest': {'lat': 36.12939422010728, 'lng': -86.85371252989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "Trader Joe's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111883553107378193704">Dustin Meza</a>'],
#      'photo_reference': 'ATtYBwK3xrJGUCr-v2XinIhHfKd5bOCCtdd0-Ju4rzJHlVeObclihmAeJhZKH1uUcso4_nC7sB69E_xeOgVda33IkA_QwTr3aJ5LJIXbpoQ6LWk52cS6Ob74sYvoAHxBeHzuz-cm-p051az6eBqyGP7q_HohMk8mNWuvqvmwPx3__MuZtgpl',
#      'width': 4032}],
#    'place_id': 'ChIJI27K4o5jZIgRkiQ31PPyWiw',
#    'plus_code': {'compound_code': '44JX+74 Nashville, Tennessee',
#     'global_code': '868M44JX+74'},
#    'rating': 4.7,
#    'reference': 'ChIJI27K4o5jZIgRkiQ31PPyWiw',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'florist',
#     'supermarket',
#     'liquor_store',
#     'food',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 392,
#    'vicinity': '90 White Bridge Rd, Nashville'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 36.1260733, 'lng': -86.8448939},
#     'viewport': {'northeast': {'lat': 36.12736967989272,
#       'lng': -86.84364682010728},
#      'southwest': {'lat': 36.12467002010727, 'lng': -86.84634647989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Harris Teeter',
#    'permanently_closed': True,
#    'place_id': 'ChIJwy-w_NxjZIgRjoMOEbsjj08',
#    'plus_code': {'compound_code': '45G4+C2 Nashville, Tennessee',
#     'global_code': '868M45G4+C2'},
#    'rating': 4,
#    'reference': 'ChIJwy-w_NxjZIgRjoMOEbsjj08',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'florist',
#     'pharmacy',
#     'bakery',
#     'supermarket',
#     'food',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '4416 Ridgefield Way, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1576546, 'lng': -86.8426645},
#     'viewport': {'northeast': {'lat': 36.15909842989272,
#       'lng': -86.84131947010727},
#      'southwest': {'lat': 36.15639877010727, 'lng': -86.84401912989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': '3 & M Mart',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111103027546614440458">Lucian Brown</a>'],
#      'photo_reference': 'ATtYBwKtmxDDbeY0UZAkPJtP_rjFRCy4SNPxBLBhDcYXpyKihT4mg7OdFbV2bYEwdiMxo50OyEscH9TN6i1Wcprw1gQR-9jkfKDZNQAeMKTM0qfaecvpUFlALqyr3brhyv5vIoQS7vdvFIY1EjceCne0YQA9QyQ0d6t4Fj_3q_JyWqX_T2An',
#      'width': 1920}],
#    'place_id': 'ChIJfULdXBVhZIgRLJctT3HrvLc',
#    'plus_code': {'compound_code': '5554+3W Nashville, Tennessee',
#     'global_code': '868M5554+3W'},
#    'rating': 4,
#    'reference': 'ChIJfULdXBVhZIgRLJctT3HrvLc',
#    'scope': 'GOOGLE',
#    'types': ['supermarket',
#     'grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': '4601 Illinois Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1490082, 'lng': -86.86342929999999},
#     'viewport': {'northeast': {'lat': 36.15035447989273,
#       'lng': -86.86207872010728},
#      'southwest': {'lat': 36.14765482010728, 'lng': -86.86477837989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Guanabana',
#    'place_id': 'ChIJV8bVWmRhZIgR0ipGBu32Cuc',
#    'plus_code': {'compound_code': '44XP+JJ Nashville, Tennessee',
#     'global_code': '868M44XP+JJ'},
#    'rating': 0,
#    'reference': 'ChIJV8bVWmRhZIgR0ipGBu32Cuc',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': '5861 Charlotte Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1529702, 'lng': -86.8433122},
#     'viewport': {'northeast': {'lat': 36.15446392989272,
#       'lng': -86.84197072010728},
#      'southwest': {'lat': 36.15176427010728, 'lng': -86.84467037989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Good Food for Good People Inc',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJo0jJaWphZIgReYWIl-OnDjs',
#    'plus_code': {'compound_code': '5534+5M Nashville, Tennessee',
#     'global_code': '868M5534+5M'},
#    'rating': 3,
#    'reference': 'ChIJo0jJaWphZIgReYWIl-OnDjs',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'park',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': '4611 Alabama Ave, Nashville'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 36.1309156, 'lng': -86.8574398},
#     'viewport': {'northeast': {'lat': 36.13225662989272,
#       'lng': -86.85607957010727},
#      'southwest': {'lat': 36.12955697010728, 'lng': -86.85877922989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "JC's Amish Produce",
#    'permanently_closed': True,
#    'photos': [{'height': 1836,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113033504553306816485">Sally Lafave</a>'],
#      'photo_reference': 'ATtYBwLs4J_16EChu1L34xh6mHWIdHJv47hByu1dqFAT5iN0uHfIrUHQweK0W4nGZFj93KgklxXWA82zYkHNfzvtf_ejzjO2wEkvrkkXZz4hMW8yKwb8LROjAYnon-OXW5Lm-w9Ck4LGRWPd4Mm9e6lF5_gAzoNuRB7mwNN-0oO4uYo1g_ui',
#      'width': 3264}],
#    'place_id': 'ChIJ13_aHtRjZIgR59-eJwLqPo4',
#    'plus_code': {'compound_code': '44JV+92 Nashville, Tennessee',
#     'global_code': '868M44JV+92'},
#    'rating': 5,
#    'reference': 'ChIJ13_aHtRjZIgR59-eJwLqPo4',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': 'Fountain Pl, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1479912, 'lng': -86.862405},
#     'viewport': {'northeast': {'lat': 36.14954157989273,
#       'lng': -86.86114262010727},
#      'southwest': {'lat': 36.14684192010728, 'lng': -86.86384227989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Cho A Dong',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1683,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115454757633528502596">Chiaro Foto</a>'],
#      'photo_reference': 'ATtYBwJQ0WEwW_KAzK_0eSSPXxw6KHGQ0qfI8BG7HNzIUOvbtC2nFa1Cayb3QjrGoMb8SX6e_DLiE5HfUK0AwXzI9VmYtn9doT60O0ZLwDUNERMfSprVb4cuxEWyjWeDz0Wg82aVSKMPMY1yDAoIIfwBKuPn13-pHG1C-VpNK8tw-LTViMj4',
#      'width': 1937}],
#    'place_id': 'ChIJiXvRnZ1hZIgR1JpZ7ISTU6U',
#    'plus_code': {'compound_code': '44XQ+52 Nashville, Tennessee',
#     'global_code': '868M44XQ+52'},
#    'rating': 4.7,
#    'reference': 'ChIJiXvRnZ1hZIgR1JpZ7ISTU6U',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 19,
#    'vicinity': '5837 Charlotte Pike, Nashville'}]]

# %% [markdown]
# city_list = ['Berry_Hill': 36.11637813798946, -86.76761477125187]
# df = pd.DataFrame(list(city_list.items()))

# %% [markdown]
# d = {}
# for results in city_list:
#         d['Berry_Hill'] = api_key

# %% [markdown]
# results.shape

# %% [markdown]
# response.tojson

# %% [markdown]
# response_df = pd.read_json('E:/Capstone/res.json')
# response_df_df.head()

# %%
type(results_df)
# Out:
# list

# %%
results_nash_map = folium.Map([36.163242365862246,-86.78142455028717], zoom_start = 12)

for store in results_df:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(nash_map)

results_nash_map
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-d32caf8e1c7e> in <module>
#       2
#       3 for store in results_df:
# ----> 4     lat_lng = store['geometry']['location']
#       5     location = [lat_lng['lat'], lat_lng['lng']]
#       6     popup = store['name']
#
# TypeError: list indices must be integers or slices, not str

# %%
east_nash_map = folium.Map([36.163242365862246,-86.78142455028717], zoom_start = 12)

for store in response_east['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(east_nash_map)

east_nash_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for store in response_east['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(nash_map)

# %%
nash_map = folium.Map([36.163242365862246,-86.78142455028717], zoom_start = 12)

for store in response_nash['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(nash_map)
for store in response_east['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(nash_map)
for store in response_west['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(nash_map)
for store in response_south['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(nash_map)
for store in response_north['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(nash_map)

nash_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# https://docs.python.org/3/library/json.html

# %%
for store in response_east['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(nash_map)

# %% [markdown]
# res=response.json()

# %% [markdown]
# res

# %% [markdown]
# pd.DataFrame.from_dict(res)

# %% [markdown]
# response.content

# %% [markdown]
# endpoint='https://maps.googleapis.com/maps/api/place/nearbysearch/json&key:'

# %% [markdown]
# soup = BeautifulSoup(response.content, "html.parser")
# soup.find(attrs={"class": "section-result"}) \
#     .find("table")

# %% [markdown]
# places = pd.concat(response)
# places

# %% [markdown]
# star

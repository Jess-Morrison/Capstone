# %% [markdown]
# #code start

# %%
from bs4 import BeautifulSoup
import pandas as pd
from IPython.core.display import display, HTML
import pandas as pd
import requests
import matplotlib.pyplot as plt
from IPython.display import Image
import folium
from key_2 import api_key
import json
# %matplotlib inline

# %%
endpoint ='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.163242365862246,-86.78142455028717&radius=1600&keyword=groceries&key=AIzaSyDR7esAMJqahioM7VjF0FOsoM3mv1Jheo4'

# %% [markdown]
# params = dict()
# params["keyword"]= "groceries"

# %%
response = requests.get(endpoint)

# %%
# %who
# Out:
# BeautifulSoup	 HTML	 Image	 api_key	 display	 endpoint	 folium	 json	 pd
# plt	 requests	 response

# %%
def find_nearby_places(api_key=api_key,
                      location='36.163242365862246,-86.78142455028717',
                      radius='16000',
                      base = 'https://maps.googleapis.com/maps/api/place/nearbysearch/',
                      keyword= 'groceries',
                      response_type = 'json',
                      maxResults='60',
                      **kwargs):
    '''
    Constructs endpoint and params dict, makes request, and returns output as json
    
    api_key: requred, str, API key from google cloud console
    location: required, str, central location for near by search, format: "<lat>, <lng>"
    radius: required, str, radius of circle (in meters) to search for nearby locations
    base: not required, str, URL base for API request
    resoponse_type: not required, format of response
    **kwargs: not required, search criteria for near by locations
    '''
    endpoint = base+response_type
    kwargs['key'] = api_key
    kwargs['location'] = '36.163242365862246,-86.78142455028717'
    kwargs['radius'] = '16000'
    kwargs['maxResults']= '60'
    kwargs['keyword'] = 'groceries',
    res = requests.get(endpoint, kwargs)
    return res.json()

# %% [markdown]
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.160678412664296,-86.78306233064329 &radius=1600&keyword=groceries&key=api_key

# %% [markdown]
# response = requests.get(endpoint, params = params)

# %% [markdown]
# ###URL ='https://www.google.com/maps/search/Groceries/@36.1818696,-86.8284668,14z/data=!3m1!4b1!4m2!2m1!6e6'

# %% [markdown]
# response = requests.post(endpoint)
# response.json()

# %% [markdown]
# response = requests.get(endpoint)
# response.status_code

# %%
type(response)
# Out:
# requests.models.Response

# %%
response = find_nearby_places()

# %%
response
# Out:
# {'html_attributions': [],
#  'next_page_token': 'ATtYBwKmrOfEm2t9J4zwBcClLsTLbfLOWpej8_uEZ4_wxNgo6axkmuqAOJpTIROXsHwxDGVKysXeM693VdJ2Zxhn7tb4V0csujrXzdIfymHCOFv25-fMnZ0xgtaG3iPej3XApa5Rc2eOomw0tGM5G4bqKgDAFh9HX7lTMNvurCDE677f_3XS_WtpV5xK5Rfwtqc93NmOl4Dae-ENNPKmkuLvBE6bbeQI2gKFIMaEFd6jcAObqfMh9CYdBcI3U2ZlZsC9m-63JcCjKaO8lzhy621tph3IchkM2_Hpoui7BDS6j2305f4e495eWgEl9rswWnBUqkidb-KrtbLIBAu7xq4GHTtZi6bCFvCheGXbj35HEqIILqSEtuAH3HaJNWw23qx14H4LPPDgsk4GP1UuGawrrlZoR4nnRsiFJs5Q-nb0p9oVcdfubjYmu-h4Fq0',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1199226, 'lng': -86.7771759},
#     'viewport': {'northeast': {'lat': 36.12131622989272,
#       'lng': -86.77576167010727},
#      'southwest': {'lat': 36.11861657010727, 'lng': -86.77846132989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3179,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109351011289266507435">Ehsan Manoushan</a>'],
#      'photo_reference': 'ATtYBwLnpK320UDu_pI9vCkt1J4cQbtGdVpuQK6BhBOCO-Cy-suBM1PrBKSvDCjQBgaGVmlmZPQgS9Y6nzKJnwD9v45exn2iBHuQTyPqph2rqpyaeiewjIh0UHjmbThXFA1V9EsV4BbgUBmWLs8jZgs6QJxyLWAXiW5G-P4AsRXbUSg1t03a',
#      'width': 1924}],
#    'place_id': 'ChIJ9_tF0c1lZIgRyxJ31oCrtRI',
#    'plus_code': {'compound_code': '469F+X4 Nashville, Tennessee',
#     'global_code': '868M469F+X4'},
#    'price_level': 2,
#    'rating': 3.8,
#    'reference': 'ChIJ9_tF0c1lZIgRyxJ31oCrtRI',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 630,
#    'vicinity': '2615 Franklin Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1301887, 'lng': -86.80261089999999},
#     'viewport': {'northeast': {'lat': 36.13147872989272,
#       'lng': -86.80109647010728},
#      'southwest': {'lat': 36.12877907010727, 'lng': -86.80379612989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117053513999049084047">Katherine Romero</a>'],
#      'photo_reference': 'ATtYBwJWk0wU3gyp4vpWXVr-9LKgLiFBG0qYVGAGym576VGaMWPQhDNLcSgpHryKs2-eyGPpoK04VMSA8cQHlhmQ2OGzItES4VT_tPd2NEZfCKo24E5jcZqTApuNLc4pBHSGj3lKqot5Kq7Pbfed25WvUajmwVZYASOlCyYSWVq-r9AKfMq1',
#      'width': 3264}],
#    'place_id': 'ChIJ8XuUZR9kZIgRohFW4543QB8',
#    'plus_code': {'compound_code': '45JW+3X Nashville, Tennessee',
#     'global_code': '868M45JW+3X'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJ8XuUZR9kZIgRohFW4543QB8',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 553,
#    'vicinity': '2201 21st Ave S, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1318851, 'lng': -86.76877499999999},
#     'viewport': {'northeast': {'lat': 36.13314642989272,
#       'lng': -86.76743662010726},
#      'southwest': {'lat': 36.13044677010728, 'lng': -86.77013627989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Wedgehill Market',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115761387019637953020">Michael Orosco</a>'],
#      'photo_reference': 'ATtYBwLuJoGo942LrN9H_f2_gW2PoRbUdhsS6rlqRecVYrdMX9t82MgxkzPCCUVuHwbxytPP8OZbm9YoQAvig7vH_n1uvd4y35qEuguhNZr4wN7Jt2m2mKW7pVgdqNoUmRKFJggPGdo_Emt89FhRNet28L3cP2t_zp34onAGVRi3pFBn-FOt',
#      'width': 5312}],
#    'place_id': 'ChIJmyJmjthlZIgR_8KhYLlhP0E',
#    'plus_code': {'compound_code': '46JJ+QF Nashville, Tennessee',
#     'global_code': '868M46JJ+QF'},
#    'rating': 4.6,
#    'reference': 'ChIJmyJmjthlZIgR_8KhYLlhP0E',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 71,
#    'vicinity': '600 Benton Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.117707, 'lng': -86.7967994},
#     'viewport': {'northeast': {'lat': 36.11910602989273,
#       'lng': -86.79554037010728},
#      'southwest': {'lat': 36.11640637010728, 'lng': -86.79824002989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "Osborne's Bi-Rite",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100106521944641494656">Matt Mc</a>'],
#      'photo_reference': 'ATtYBwKth3oKsiSgj3i8FI8d0zBNgn_a5trdJdFymLOiEd4FNr61CdXCUwOSPv4VogUA1wkNmSwWGxcj6gpMyp8MEFAk4aBNNRY15w8qnAPUy5-iodQjYdgwX_KrZTjkUM6lL54hd4xDLK-613zK7Q0--X-UFzXUvJitkPkzeSulkFe30e_p',
#      'width': 3024}],
#    'place_id': 'ChIJaQEV-DtkZIgR1fuVUETHCAc',
#    'plus_code': {'compound_code': '4693+37 Nashville, Tennessee',
#     'global_code': '868M4693+37'},
#    'rating': 4.5,
#    'reference': 'ChIJaQEV-DtkZIgR1fuVUETHCAc',
#    'scope': 'GOOGLE',
#    'types': ['supermarket',
#     'grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 252,
#    'vicinity': '3116 Belmont Blvd, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1445892, 'lng': -86.8136},
#     'viewport': {'northeast': {'lat': 36.14593902989272,
#       'lng': -86.81225017010728},
#      'southwest': {'lat': 36.14323937010727, 'lng': -86.81494982989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Piggly Wiggly',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113359179597487495544">Jack Warman</a>'],
#      'photo_reference': 'ATtYBwKudBKzLx8H-btasGeHzVDMNuqFmZxsVDM0mmZCuZAh67jGAy7Eg0wt34ZHL0VBN3aGgq6vuOAnrWS-9rn1NAumMSuYfbQZoeRWz_RSzAJJ9CNAoiT1cMstlNNsEMJjnoF7YDEYc3bssf95qLPgUgTUEqs50R952AaC-mDfvuJ6UQxp',
#      'width': 3840}],
#    'place_id': 'ChIJF_mw3q9mZIgRQdSpspW80MQ',
#    'plus_code': {'compound_code': '45VP+RH Nashville, Tennessee',
#     'global_code': '868M45VP+RH'},
#    'price_level': 2,
#    'rating': 4,
#    'reference': 'ChIJF_mw3q9mZIgRQdSpspW80MQ',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 361,
#    'vicinity': '2900 West End Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1758569, 'lng': -86.79427369999999},
#     'viewport': {'northeast': {'lat': 36.17703907989273,
#       'lng': -86.79283387010727},
#      'southwest': {'lat': 36.17433942010728, 'lng': -86.79553352989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1280,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110336675155918874463">Kroger</a>'],
#      'photo_reference': 'ATtYBwKRUKpWAf0k1bzPDx2ot90JZ11CDu8IErhUG_lNw1Ma9WJk6JbrG0g-VnLakK3bRiFlXLo8ZFCvtCcSgN6hdAHu2lalsREWatnLDXEGL4P2sgfnEbJU7JjzQLJWLWfNOvubPVl7dRJZf2dnUs9BgwMTQW6I6OMxtZ0O3URkfCNXgcNL',
#      'width': 1920}],
#    'place_id': 'ChIJ0f1NweJmZIgRYnc_3nqNyag',
#    'plus_code': {'compound_code': '56G4+87 Nashville, Tennessee',
#     'global_code': '868M56G4+87'},
#    'price_level': 2,
#    'rating': 3.7,
#    'reference': 'ChIJ0f1NweJmZIgRYnc_3nqNyag',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 889,
#    'vicinity': '800 Monroe St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1050835, 'lng': -86.815626},
#     'viewport': {'northeast': {'lat': 36.10642872989272,
#       'lng': -86.81412642010729},
#      'southwest': {'lat': 36.10372907010728, 'lng': -86.81682607989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "Trader Joe's",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100201960762355239004">Paul Kang</a>'],
#      'photo_reference': 'ATtYBwJw3Uvy1hYsjemifbf8uIQ1hiEhDiA2o7FHLApngWuARo_Zd59IoPWAgFEBD4AwJENzh8hDgfBnRv7nde71CpZxskHdd4aVmUrsYy7UgS6W-gCwvDYEl-TqY41cxwM_xMxo_q-pw9_HGPjYJpxkOukdhuhPEIeFkzaWF2DMqsSrwhSR',
#      'width': 4032}],
#    'place_id': 'ChIJH60AEXFkZIgR9d0pAe7Btro',
#    'plus_code': {'compound_code': '454M+2P Nashville, Tennessee',
#     'global_code': '868M454M+2P'},
#    'price_level': 2,
#    'rating': 4.6,
#    'reference': 'ChIJH60AEXFkZIgR9d0pAe7Btro',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'florist',
#     'supermarket',
#     'liquor_store',
#     'food',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 2233,
#    'vicinity': '3909 Hillsboro Pike, Nashville'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 36.1634125, 'lng': -86.779421},
#     'viewport': {'northeast': {'lat': 36.16473492989273,
#       'lng': -86.77817392010726},
#      'southwest': {'lat': 36.16203527010729, 'lng': -86.78087357989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'H.G. Hill Urban Market',
#    'permanently_closed': True,
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106519442576080453760">A Google User</a>'],
#      'photo_reference': 'ATtYBwJngw78KIo0nG20Birj8ak0PWdAfhcF9pTGZQI2auRt5rqljzyGQZjBD4bHfO-VEUvsRO5pAkHEbRy22FXXzMIO2dYs4MJvo4VFNR7CH9bD-yQ1Tch7IoFj2d5PdNkbiVkagi4M6MxOY-i-hRmxTjEX_IJDZD3t5DcnxxHYLOxTqx5j',
#      'width': 3264}],
#    'place_id': 'ChIJPStOVVhmZIgRso0FW3wu3Hw',
#    'plus_code': {'compound_code': '567C+96 Nashville, Tennessee',
#     'global_code': '868M567C+96'},
#    'rating': 4.2,
#    'reference': 'ChIJPStOVVhmZIgRso0FW3wu3Hw',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 191,
#    'vicinity': '415 Church St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1594967, 'lng': -86.8140176},
#     'viewport': {'northeast': {'lat': 36.16086467989272,
#       'lng': -86.81256562010728},
#      'southwest': {'lat': 36.15816502010728, 'lng': -86.81526527989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "Resha's Bi-Rite Market",
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJ4ZED5shmZIgRz1kBNC9ENYg',
#    'plus_code': {'compound_code': '555P+Q9 Nashville, Tennessee',
#     'global_code': '868M555P+Q9'},
#    'rating': 3.8,
#    'reference': 'ChIJ4ZED5shmZIgRz1kBNC9ENYg',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 57,
#    'vicinity': '717 25th Ave N, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1098319, 'lng': -86.72515729999999},
#     'viewport': {'northeast': {'lat': 36.11133767989271,
#       'lng': -86.72388797010727},
#      'southwest': {'lat': 36.10863802010727, 'lng': -86.72658762989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2560,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111583370177102107504">Neather Black</a>'],
#      'photo_reference': 'ATtYBwI45MxiqOWZ-Aqq3Q9jphWJzPK7SmFG0rgXHmTRovKzvH7AIHTDAxlDTG-BEgGULDkqtD-2Wo2K3-FtqyLzBIjanRjii02oNfbAI8zxeFf-SNYaejU-tiE_jrxOfk-f8KnDeNrzckM-rILWyuJixYyhx10_LjgLVqMtm7MNHIQfNkN_',
#      'width': 1920}],
#    'place_id': 'ChIJsdxD4EFvZIgRia2JrXjnDZo',
#    'plus_code': {'compound_code': '475F+WW Nashville, Tennessee',
#     'global_code': '868M475F+WW'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJsdxD4EFvZIgRia2JrXjnDZo',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 645,
#    'vicinity': '61 E Thompson Ln, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1853811, 'lng': -86.8159932},
#     'viewport': {'northeast': {'lat': 36.18663382989272,
#       'lng': -86.81489022010727},
#      'southwest': {'lat': 36.18393417010728, 'lng': -86.81758987989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Save A Lot',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1440,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111089389699251425402">A Google User</a>'],
#      'photo_reference': 'ATtYBwK1tXpcEu0RFtHrRrEtbTijOWHAs4jfUJk6zB2RcZqmgCMf6NPTWIgy_Dhzrf-UMKZs9Govu1a-6RdZKJ0ExP1-E9Ley5OTIAxh5wmippTRt8qA8gWfR2lXPRGridzXpZYMUKtzoW1D_NGwX7okLPYpA0Nx53989lpi5FT177KzsYHf',
#      'width': 2560}],
#    'place_id': 'ChIJCTHj7C5nZIgR8KzLicfUjkw',
#    'plus_code': {'compound_code': '55PM+5J Nashville, Tennessee',
#     'global_code': '868M55PM+5J'},
#    'rating': 4,
#    'reference': 'ChIJCTHj7C5nZIgR8KzLicfUjkw',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 512,
#    'vicinity': '2400 Clarksville Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1056803, 'lng': -86.81846379999999},
#     'viewport': {'northeast': {'lat': 36.10702517989272,
#       'lng': -86.81705972010727},
#      'southwest': {'lat': 36.10432552010728, 'lng': -86.81975937989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116175916570966053337">Cavell Blood</a>'],
#      'photo_reference': 'ATtYBwKKsHNQEtH8_kOueCJzwjmByVwTFWPAp0cP6Sqptfu2he2OGDEaGk8OGT5nGETgl1bBBVJ1uKROmzA_qnR_7J_eIh-h4n36jM5Drq3mGQrpmV-iyZn1WWI4rwcuiNX1EAF4aI0Jd90lwD3Gqj1rZXrUBCyB1eyAvXVFkCpAbZwmx1Xo',
#      'width': 3264}],
#    'place_id': 'ChIJmbwrlHZkZIgR-bMSVV4X4YY',
#    'plus_code': {'compound_code': '454J+7J Nashville, Tennessee',
#     'global_code': '868M454J+7J'},
#    'price_level': 2,
#    'rating': 4.3,
#    'reference': 'ChIJmbwrlHZkZIgR-bMSVV4X4YY',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 374,
#    'vicinity': '2131 Abbott Martin Rd, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1239257, 'lng': -86.850561},
#     'viewport': {'northeast': {'lat': 36.12517007989273,
#       'lng': -86.84904282010727},
#      'southwest': {'lat': 36.12247042010728, 'lng': -86.8517424798927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110390319083466216606">A Google User</a>'],
#      'photo_reference': 'ATtYBwJ8bN7VfcF5fMdhqN3Y1HW7rI4NR79xKdDpejlJDKIuGzY7DxlURxKNLT3EEsoSMCnwVCqdh-maKNdAAZu0OUplAZ_eJCbeB9zh3b7MHs14s8C1qOEi_NHFegtzMHrAoav8d1326FZhLtKzN2IGO9rRVDesL-67_4TsvN6oQr0uyUH4',
#      'width': 4032}],
#    'place_id': 'ChIJgwbO18RjZIgRiitXTeFueHE',
#    'plus_code': {'compound_code': '44FX+HQ Nashville, Tennessee',
#     'global_code': '868M44FX+HQ'},
#    'price_level': 2,
#    'rating': 4,
#    'reference': 'ChIJgwbO18RjZIgRiitXTeFueHE',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 200,
#    'vicinity': '4560 Harding Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.148724, 'lng': -86.8604389},
#     'viewport': {'northeast': {'lat': 36.15012517989273,
#       'lng': -86.85909187010728},
#      'southwest': {'lat': 36.14742552010728, 'lng': -86.86179152989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103832292777728970389">Clara Molina</a>'],
#      'photo_reference': 'ATtYBwJa2TQT8zaNPUcK6uypftoG-Gi2n6JLKMiDoqcrXVRi4kA-AjOWp4L5oUJvWaTOVCBIkWU5zE1RJqIbk0G-eaPv9HmhDmK11ue9SDXyqPirNxdvHWdbVhlMOfsAwGJLmOqTQ4pVPZAOfYE9wiq5nAnS48p24Nr79hiuqHKt9QBRbfWk',
#      'width': 1920}],
#    'place_id': 'ChIJ_yOHRXZhZIgRSvQatfG8liY',
#    'plus_code': {'compound_code': '44XQ+FR Nashville, Tennessee',
#     'global_code': '868M44XQ+FR'},
#    'price_level': 2,
#    'rating': 3.9,
#    'reference': 'ChIJ_yOHRXZhZIgRSvQatfG8liY',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 655,
#    'vicinity': '5705 Charlotte Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1844743, 'lng': -86.74677849999999},
#     'viewport': {'northeast': {'lat': 36.18570212989272,
#       'lng': -86.74576282010727},
#      'southwest': {'lat': 36.18300247010728, 'lng': -86.74846247989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2201,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113827070569302562718">Andrew L</a>'],
#      'photo_reference': 'ATtYBwKVvemQOtDExv84u9ydYOcnbKtQjh9V9oZtKWmPMRxig7oOWAtpo-kA3-grF3ZHSdjHvssJcwpqXe70n6viJQNTwwwpWdyHXoaV9vGl5UG2fa8MAqZG7EQimu5fL-uTn-qoqEBlXCX0kDmw3b0qpxyV1ji1a67GXdZCjgsABnn9y-mh',
#      'width': 7268}],
#    'place_id': 'ChIJCyiJ2tBnZIgReYaDDx5KLEM',
#    'plus_code': {'compound_code': '57M3+Q7 Nashville, Tennessee',
#     'global_code': '868M57M3+Q7'},
#    'price_level': 2,
#    'rating': 3.7,
#    'reference': 'ChIJCyiJ2tBnZIgReYaDDx5KLEM',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 687,
#    'vicinity': '711 Gallatin Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1329002, 'lng': -86.7887039},
#     'viewport': {'northeast': {'lat': 36.13425077989272,
#       'lng': -86.78734452010728},
#      'southwest': {'lat': 36.13155112010728, 'lng': -86.79004417989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'The Store',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJyzYwFj5lZIgRFGB0hYpHoQA',
#    'plus_code': {'compound_code': '46M6+5G Nashville, Tennessee',
#     'global_code': '868M46M6+5G'},
#    'rating': 5,
#    'reference': 'ChIJyzYwFj5lZIgRFGB0hYpHoQA',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 12,
#    'vicinity': '2009 12th Ave S, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1014506, 'lng': -86.7401198},
#     'viewport': {'northeast': {'lat': 36.10276232989272,
#       'lng': -86.7388847201073},
#      'southwest': {'lat': 36.10006267010728, 'lng': -86.74158437989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Osborne Bi-Rite',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2184,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113970857497524711494">Bobby Boucher</a>'],
#      'photo_reference': 'ATtYBwIrQPOQtgXd8yxGHqcDkvuMGxjnXDvjX3l4kxnApDtMTdZXpI96wo13DFXKJa534SQfPLBBzvHAryp-EZZ50EfqqLt53VuEDnlaaq6lozLHHuiKXrksiHPaa4sckp6OM8_vQET0KhpFyEmzM2at_u_gtxvKatA4kLwlzTC3RPitGxz-',
#      'width': 4608}],
#    'place_id': 'ChIJ5y2372JvZIgR1_y4Qj-MW2g',
#    'plus_code': {'compound_code': '4725+HX Nashville, Tennessee',
#     'global_code': '868M4725+HX'},
#    'rating': 4.4,
#    'reference': 'ChIJ5y2372JvZIgR1_y4Qj-MW2g',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 226,
#    'vicinity': '3302 Nolensville Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1267272, 'lng': -86.8475064},
#     'viewport': {'northeast': {'lat': 36.12797762989273,
#       'lng': -86.84605667010729},
#      'southwest': {'lat': 36.12527797010728, 'lng': -86.84875632989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Publix Super Market at Hill Center at Belle Meade',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116780368244981387168">Sarah Crawford</a>'],
#      'photo_reference': 'ATtYBwKhNC-cCumqcso-h5IT7jBl2BJcSf8NN5qSaME8bqC5Hpi1sPq0s3uKy5wrmPqhATIWq1zuz29ZiVfLjzqsmuqcEQClbsznL_IO6Vr_qMeF4MBvSSE_7t3rajoIu4p99kQoq-eZE8GormQfjgb5yEc0823s4S3wwp0eAoR3kfrKZ4oX',
#      'width': 3984}],
#    'place_id': 'ChIJ_98e89xjZIgRkX7e3TmFvyw',
#    'plus_code': {'compound_code': '45G2+MX Nashville, Tennessee',
#     'global_code': '868M45G2+MX'},
#    'price_level': 2,
#    'rating': 4.4,
#    'reference': 'ChIJ_98e89xjZIgRkX7e3TmFvyw',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'bakery',
#     'liquor_store',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 357,
#    'vicinity': '4324 Harding Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1257545, 'lng': -86.7109041},
#     'viewport': {'northeast': {'lat': 36.12709057989272,
#       'lng': -86.70937397010728},
#      'southwest': {'lat': 36.12439092010728, 'lng': -86.71207362989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Save A Lot',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3264,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105495554959137446847">A Google User</a>'],
#      'photo_reference': 'ATtYBwJFPnRtmpDpadmKh6NiQEIyTNyr2t7zqija9zyL7EB4SoLxmZLQr-uoRWw-qtWSocFUmfYYbrmTzPYtwIpaCf0Es37-NxZNiYu1AExj12k_lOqGEvGmhxNGgcp-qzlqvMwOn4g_HNhWtD1beMCLkNm_HiDegBSlRgqbAuh3HUcAOZhi',
#      'width': 2448}],
#    'place_id': 'ChIJHxD44C1vZIgRehI73vtnco0',
#    'plus_code': {'compound_code': '47GQ+8J Nashville, Tennessee',
#     'global_code': '868M47GQ+8J'},
#    'rating': 4,
#    'reference': 'ChIJHxD44C1vZIgRehI73vtnco0',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 579,
#    'vicinity': '1113 Murfreesboro Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1128669, 'lng': -86.76522740000001},
#     'viewport': {'northeast': {'lat': 36.11389887989272,
#       'lng': -86.76392632010729},
#      'southwest': {'lat': 36.11119922010728, 'lng': -86.76662597989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "Aleksey's Market",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3968,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102540283510731906070">Péter Svajcsik</a>'],
#      'photo_reference': 'ATtYBwIMP1Uq7szTz3VNyJjIsgZr1Qgyw_S8KXProMAK2225FdhuaB-L1cw89c7mVN45i9_tAyXRRujMcJD0ixfJgN4ggm00G6KBxOwPtXz_-j8h1b6Lo-qMisb_TN2Rp2SwDKnl18qy1Fl1vYmiYXrpXVPiIVye2pWEgG8Hsf94jcDEH9zx',
#      'width': 2976}],
#    'place_id': 'ChIJVcZm7MBlZIgRNKQ6_KcFQO8',
#    'plus_code': {'compound_code': '467M+4W Nashville, Tennessee',
#     'global_code': '868M467M+4W'},
#    'rating': 4.8,
#    'reference': 'ChIJVcZm7MBlZIgRNKQ6_KcFQO8',
#    'scope': 'GOOGLE',
#    'types': ['supermarket',
#     'grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 222,
#    'vicinity': '718 Thompson Ln, Nashville'}],
#  'status': 'OK'}

# %%
response['results'][0].values()
# Out:
# dict_values(['OPERATIONAL', {'location': {'lat': 36.1199226, 'lng': -86.7771759}, 'viewport': {'northeast': {'lat': 36.12131622989272, 'lng': -86.77576167010727}, 'southwest': {'lat': 36.11861657010727, 'lng': -86.77846132989272}}}, 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png', 'Kroger', {'open_now': True}, [{'height': 3179, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109351011289266507435">Ehsan Manoushan</a>'], 'photo_reference': 'ATtYBwLnpK320UDu_pI9vCkt1J4cQbtGdVpuQK6BhBOCO-Cy-suBM1PrBKSvDCjQBgaGVmlmZPQgS9Y6nzKJnwD9v45exn2iBHuQTyPqph2rqpyaeiewjIh0UHjmbThXFA1V9EsV4BbgUBmWLs8jZgs6QJxyLWAXiW5G-P4AsRXbUSg1t03a', 'width': 1924}], 'ChIJ9_tF0c1lZIgRyxJ31oCrtRI', {'compound_code': '469F+X4 Nashville, Tennessee', 'global_code': '868M469F+X4'}, 2, 3.8, 'ChIJ9_tF0c1lZIgRyxJ31oCrtRI', 'GOOGLE', ['grocery_or_supermarket', 'food', 'point_of_interest', 'store', 'establishment'], 630, '2615 Franklin Pike, Nashville'])

# %%
results=pd.DataFrame.from_dict(response['results'])
results
# Out:
#        business_status                                           geometry  \
# 0          OPERATIONAL  {'location': {'lat': 36.1199226, 'lng': -86.77...
# 1          OPERATIONAL  {'location': {'lat': 36.1301887, 'lng': -86.80...
# 2          OPERATIONAL  {'location': {'lat': 36.1318851, 'lng': -86.76...
# 3          OPERATIONAL  {'location': {'lat': 36.117707, 'lng': -86.796...
# 4          OPERATIONAL  {'location': {'lat': 36.1445892, 'lng': -86.81...
# 5          OPERATIONAL  {'location': {'lat': 36.1758569, 'lng': -86.79...
# 6          OPERATIONAL  {'location': {'lat': 36.1050835, 'lng': -86.81...
# 7   CLOSED_TEMPORARILY  {'location': {'lat': 36.1634125, 'lng': -86.77...
# 8          OPERATIONAL  {'location': {'lat': 36.1594967, 'lng': -86.81...
# 9          OPERATIONAL  {'location': {'lat': 36.1098319, 'lng': -86.72...
# 10         OPERATIONAL  {'location': {'lat': 36.1853811, 'lng': -86.81...
# 11         OPERATIONAL  {'location': {'lat': 36.1056803, 'lng': -86.81...
# 12         OPERATIONAL  {'location': {'lat': 36.1239257, 'lng': -86.85...
# 13         OPERATIONAL  {'location': {'lat': 36.148724, 'lng': -86.860...
# 14         OPERATIONAL  {'location': {'lat': 36.1844743, 'lng': -86.74...
# 15         OPERATIONAL  {'location': {'lat': 36.1329002, 'lng': -86.78...
# 16         OPERATIONAL  {'location': {'lat': 36.1014506, 'lng': -86.74...
# 17         OPERATIONAL  {'location': {'lat': 36.1267272, 'lng': -86.84...
# 18         OPERATIONAL  {'location': {'lat': 36.1257545, 'lng': -86.71...
# 19         OPERATIONAL  {'location': {'lat': 36.1128669, 'lng': -86.76...
#
#                                                  icon  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                                  name        opening_hours  \
# 0                                              Kroger   {'open_now': True}
# 1                                              Kroger   {'open_now': True}
# 2                                    Wedgehill Market  {'open_now': False}
# 3                                   Osborne's Bi-Rite  {'open_now': False}
# 4                                       Piggly Wiggly   {'open_now': True}
# 5                                              Kroger   {'open_now': True}
# 6                                        Trader Joe's  {'open_now': False}
# 7                              H.G. Hill Urban Market                  NaN
# 8                              Resha's Bi-Rite Market  {'open_now': False}
# 9                                              Kroger   {'open_now': True}
# 10                                         Save A Lot  {'open_now': False}
# 11                                             Kroger   {'open_now': True}
# 12                                             Kroger   {'open_now': True}
# 13                                             Kroger   {'open_now': True}
# 14                                             Kroger   {'open_now': True}
# 15                                          The Store  {'open_now': False}
# 16                                    Osborne Bi-Rite  {'open_now': False}
# 17  Publix Super Market at Hill Center at Belle Meade   {'open_now': True}
# 18                                         Save A Lot  {'open_now': False}
# 19                                   Aleksey's Market  {'open_now': False}
#
#                                                photos  \
# 0   [{'height': 3179, 'html_attributions': ['<a hr...
# 1   [{'height': 2448, 'html_attributions': ['<a hr...
# 2   [{'height': 2988, 'html_attributions': ['<a hr...
# 3   [{'height': 4032, 'html_attributions': ['<a hr...
# 4   [{'height': 2160, 'html_attributions': ['<a hr...
# 5   [{'height': 1280, 'html_attributions': ['<a hr...
# 6   [{'height': 3024, 'html_attributions': ['<a hr...
# 7   [{'height': 2448, 'html_attributions': ['<a hr...
# 8                                                 NaN
# 9   [{'height': 2560, 'html_attributions': ['<a hr...
# 10  [{'height': 1440, 'html_attributions': ['<a hr...
# 11  [{'height': 2448, 'html_attributions': ['<a hr...
# 12  [{'height': 3024, 'html_attributions': ['<a hr...
# 13  [{'height': 1080, 'html_attributions': ['<a hr...
# 14  [{'height': 2201, 'html_attributions': ['<a hr...
# 15                                                NaN
# 16  [{'height': 2184, 'html_attributions': ['<a hr...
# 17  [{'height': 2988, 'html_attributions': ['<a hr...
# 18  [{'height': 3264, 'html_attributions': ['<a hr...
# 19  [{'height': 3968, 'html_attributions': ['<a hr...
#
#                        place_id  \
# 0   ChIJ9_tF0c1lZIgRyxJ31oCrtRI
# 1   ChIJ8XuUZR9kZIgRohFW4543QB8
# 2   ChIJmyJmjthlZIgR_8KhYLlhP0E
# 3   ChIJaQEV-DtkZIgR1fuVUETHCAc
# 4   ChIJF_mw3q9mZIgRQdSpspW80MQ
# 5   ChIJ0f1NweJmZIgRYnc_3nqNyag
# 6   ChIJH60AEXFkZIgR9d0pAe7Btro
# 7   ChIJPStOVVhmZIgRso0FW3wu3Hw
# 8   ChIJ4ZED5shmZIgRz1kBNC9ENYg
# 9   ChIJsdxD4EFvZIgRia2JrXjnDZo
# 10  ChIJCTHj7C5nZIgR8KzLicfUjkw
# 11  ChIJmbwrlHZkZIgR-bMSVV4X4YY
# 12  ChIJgwbO18RjZIgRiitXTeFueHE
# 13  ChIJ_yOHRXZhZIgRSvQatfG8liY
# 14  ChIJCyiJ2tBnZIgReYaDDx5KLEM
# 15  ChIJyzYwFj5lZIgRFGB0hYpHoQA
# 16  ChIJ5y2372JvZIgR1_y4Qj-MW2g
# 17  ChIJ_98e89xjZIgRkX7e3TmFvyw
# 18  ChIJHxD44C1vZIgRehI73vtnco0
# 19  ChIJVcZm7MBlZIgRNKQ6_KcFQO8
#
#                                             plus_code  price_level  rating  \
# 0   {'compound_code': '469F+X4 Nashville, Tennesse...          2.0     3.8
# 1   {'compound_code': '45JW+3X Nashville, Tennesse...          2.0     4.1
# 2   {'compound_code': '46JJ+QF Nashville, Tennesse...          NaN     4.6
# 3   {'compound_code': '4693+37 Nashville, Tennesse...          NaN     4.5
# 4   {'compound_code': '45VP+RH Nashville, Tennesse...          2.0     4.0
# 5   {'compound_code': '56G4+87 Nashville, Tennesse...          2.0     3.7
# 6   {'compound_code': '454M+2P Nashville, Tennesse...          2.0     4.6
# 7   {'compound_code': '567C+96 Nashville, Tennesse...          NaN     4.2
# 8   {'compound_code': '555P+Q9 Nashville, Tennesse...          NaN     3.8
# 9   {'compound_code': '475F+WW Nashville, Tennesse...          2.0     4.1
# 10  {'compound_code': '55PM+5J Nashville, Tennesse...          NaN     4.0
# 11  {'compound_code': '454J+7J Nashville, Tennesse...          2.0     4.3
# 12  {'compound_code': '44FX+HQ Nashville, Tennesse...          2.0     4.0
# 13  {'compound_code': '44XQ+FR Nashville, Tennesse...          2.0     3.9
# 14  {'compound_code': '57M3+Q7 Nashville, Tennesse...          2.0     3.7
# 15  {'compound_code': '46M6+5G Nashville, Tennesse...          NaN     5.0
# 16  {'compound_code': '4725+HX Nashville, Tennesse...          NaN     4.4
# 17  {'compound_code': '45G2+MX Nashville, Tennesse...          2.0     4.4
# 18  {'compound_code': '47GQ+8J Nashville, Tennesse...          NaN     4.0
# 19  {'compound_code': '467M+4W Nashville, Tennesse...          NaN     4.8
#
#                       reference   scope  \
# 0   ChIJ9_tF0c1lZIgRyxJ31oCrtRI  GOOGLE
# 1   ChIJ8XuUZR9kZIgRohFW4543QB8  GOOGLE
# 2   ChIJmyJmjthlZIgR_8KhYLlhP0E  GOOGLE
# 3   ChIJaQEV-DtkZIgR1fuVUETHCAc  GOOGLE
# 4   ChIJF_mw3q9mZIgRQdSpspW80MQ  GOOGLE
# 5   ChIJ0f1NweJmZIgRYnc_3nqNyag  GOOGLE
# 6   ChIJH60AEXFkZIgR9d0pAe7Btro  GOOGLE
# 7   ChIJPStOVVhmZIgRso0FW3wu3Hw  GOOGLE
# 8   ChIJ4ZED5shmZIgRz1kBNC9ENYg  GOOGLE
# 9   ChIJsdxD4EFvZIgRia2JrXjnDZo  GOOGLE
# 10  ChIJCTHj7C5nZIgR8KzLicfUjkw  GOOGLE
# 11  ChIJmbwrlHZkZIgR-bMSVV4X4YY  GOOGLE
# 12  ChIJgwbO18RjZIgRiitXTeFueHE  GOOGLE
# 13  ChIJ_yOHRXZhZIgRSvQatfG8liY  GOOGLE
# 14  ChIJCyiJ2tBnZIgReYaDDx5KLEM  GOOGLE
# 15  ChIJyzYwFj5lZIgRFGB0hYpHoQA  GOOGLE
# 16  ChIJ5y2372JvZIgR1_y4Qj-MW2g  GOOGLE
# 17  ChIJ_98e89xjZIgRkX7e3TmFvyw  GOOGLE
# 18  ChIJHxD44C1vZIgRehI73vtnco0  GOOGLE
# 19  ChIJVcZm7MBlZIgRNKQ6_KcFQO8  GOOGLE
#
#                                                 types  user_ratings_total  \
# 0   [grocery_or_supermarket, food, point_of_intere...                 630
# 1   [grocery_or_supermarket, food, point_of_intere...                 553
# 2   [grocery_or_supermarket, supermarket, food, po...                  71
# 3   [supermarket, grocery_or_supermarket, food, po...                 252
# 4   [grocery_or_supermarket, supermarket, food, po...                 361
# 5   [grocery_or_supermarket, food, point_of_intere...                 889
# 6   [grocery_or_supermarket, florist, supermarket,...                2233
# 7   [grocery_or_supermarket, supermarket, food, po...                 191
# 8   [grocery_or_supermarket, supermarket, food, po...                  57
# 9   [grocery_or_supermarket, food, point_of_intere...                 645
# 10  [grocery_or_supermarket, food, point_of_intere...                 512
# 11  [grocery_or_supermarket, food, point_of_intere...                 374
# 12  [grocery_or_supermarket, food, point_of_intere...                 200
# 13  [grocery_or_supermarket, food, point_of_intere...                 655
# 14  [grocery_or_supermarket, food, point_of_intere...                 687
# 15  [grocery_or_supermarket, food, point_of_intere...                  12
# 16  [grocery_or_supermarket, supermarket, food, po...                 226
# 17  [grocery_or_supermarket, bakery, liquor_store,...                 357
# 18  [grocery_or_supermarket, food, point_of_intere...                 579
# 19  [supermarket, grocery_or_supermarket, food, po...                 222
#
#                              vicinity permanently_closed
# 0       2615 Franklin Pike, Nashville                NaN
# 1          2201 21st Ave S, Nashville                NaN
# 2           600 Benton Ave, Nashville                NaN
# 3        3116 Belmont Blvd, Nashville                NaN
# 4        2900 West End Ave, Nashville                NaN
# 5            800 Monroe St, Nashville                NaN
# 6      3909 Hillsboro Pike, Nashville                NaN
# 7            415 Church St, Nashville               True
# 8           717 25th Ave N, Nashville                NaN
# 9         61 E Thompson Ln, Nashville                NaN
# 10   2400 Clarksville Pike, Nashville                NaN
# 11   2131 Abbott Martin Rd, Nashville                NaN
# 12       4560 Harding Pike, Nashville                NaN
# 13     5705 Charlotte Pike, Nashville                NaN
# 14        711 Gallatin Ave, Nashville                NaN
# 15         2009 12th Ave S, Nashville                NaN
# 16   3302 Nolensville Pike, Nashville                NaN
# 17       4324 Harding Pike, Nashville                NaN
# 18  1113 Murfreesboro Pike, Nashville                NaN
# 19         718 Thompson Ln, Nashville                NaN

# %%
city_list = ['Berry_Hill': 36.11637813798946, -86.76761477125187]
df = pd.DataFrame(list(city_list.items()))
# Out:
#   File "<ipython-input-11-d4f2570c63c6>", line 1
#     city_list = ['Berry_Hill': 36.11637813798946, -86.76761477125187]
#                              ^
# SyntaxError: invalid syntax

# %%
d = {}
for results in city_list:
        d['Berry_Hill'] = api_key

# %%
results.shape

# %% [markdown]
# response.tojson

# %% [markdown]
# response_df = pd.read_json('E:/Capstone/res.json')
# response_df_df.head()

# %%
nash_map = folium.Map([36.163242365862246,-86.78142455028717], zoom_start = 12)

for store in response['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(nash_map)

nash_map

# %% [markdown]
# https://docs.python.org/3/library/json.html

# %% [markdown]
# res=response.json()

# %% [markdown]
# res

# %% [markdown]
# pd.DataFrame.from_dict(res)

# %% [markdown]
# response.content

# %% [markdown]
# endpoint='https://maps.googleapis.com/maps/api/place/nearbysearch/json&key:'

# %% [markdown]
# soup = BeautifulSoup(response.content, "html.parser")
# soup.find(attrs={"class": "section-result"}) \
#     .find("table")

# %% [markdown]
# places = pd.concat(response)
# places

# %% [markdown]
# star

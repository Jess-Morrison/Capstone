# %% [markdown]
# #code start

# %%
from bs4 import BeautifulSoup
import pandas as pd
from IPython.core.display import display, HTML
import pandas as pd
import requests
import matplotlib.pyplot as plt
from IPython.display import Image
import folium
from key_2 import api_key
import json
# %matplotlib inline

# %%
endpoint_nash ='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.163242365862246,-86.78142455028717&maxResults=60&radius=3300&keyword=groceries&key=AIzaSyDR7esAMJqahioM7VjF0FOsoM3mv1Jheo4'

# %% [markdown]
# params = dict()
# params["keyword"]= "groceries"

# %% [markdown]
# response = requests.get(endpoint)

# %%
# %who
# Out:
# BeautifulSoup	 HTML	 Image	 api_key	 display	 endpoint_nash	 folium	 json	 pd
# plt	 requests

# %%
def find_nearby_places_nash(api_key=api_key,
                      location='36.163242365862246,-86.78142455028717',
                      radius='3300',
                      base = 'https://maps.googleapis.com/maps/api/place/nearbysearch/',
                      keyword= 'groceries',
                      response_type = 'json',
                      pageToken='nextPageToken',
                      **kwargs):
    '''
    Constructs endpoint and params dict, makes request, and returns output as json
    
    api_key: requred, str, API key from google cloud console
    location: required, str, central location for near by search, format: "<lat>, <lng>"
    radius: required, str, radius of circle (in meters) to search for nearby locations
    base: not required, str, URL base for API request
    resoponse_type: not required, format of response
    **kwargs: not required, search criteria for near by locations
    '''
    endpoint_nash = base+response_type
    kwargs['key'] = api_key
    kwargs['location'] = '36.163242365862246,-86.78142455028717'
    kwargs['radius'] = '3300'
    kwargs['pageToken']= 'nextPageToken'
    kwargs['keyword'] = 'groceries',
    res = requests.get(endpoint_nash, kwargs)
    return res.json()

# %% [markdown]
# print(str(response.url))

# %% [markdown]
# response = requests.post(endpoint)
# response.content

# %% [markdown]
# soup = BeautifulSoup(response.content, "html.parser")
# soup.find(attrs={"class": "section-result"}) \
#     .find("section-divider-bottom-line")

# %% [markdown]
# full2017all = []
# x = 1
# while x < 280:
#   # baseURL = "https://www.runrocknroll.com/Events/Nashville/The-Races/Marathon/2017-Results"
#     URL ='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.163242365862246,-86.78142455028717&radius=1600&keyword=groceries&key=AIzaSyDR7esAMJqahioM7VjF0FOsoM3mv1Jheo4'.format(x)
#     response = requests.post(URL)
#     soup =BeautifulSoup(response.content, "html.parser")
#     full2017page = soup.find(attrs = {"class": "section-result"}).find("results")
#     full2017_list = pd.read_html(str(full2017page))
#     full2017_list = full2017_list[0]
#     full2017all.append(full2017_list)
#     x += 1

# %% [markdown]
# url='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.160678412664296,-86.78306233064329&radius=1600&keyword=groceries&key=api_key'

# %% [markdown]
# response = requests.get(endpoint, params = params)

# %% [markdown]
# ###URL ='https://www.google.com/maps/search/Groceries/@36.1818696,-86.8284668,14z/data=!3m1!4b1!4m2!2m1!6e6'

# %% [markdown]
# response = requests.post(endpoint)

# %% [markdown]
# response=response.json()

# %%
response = requests.get(endpoint_nash)
response.status_code
# Out:
# 200

# %%
type(response)
# Out:
# requests.models.Response

# %%
response_nash = find_nearby_places_nash()

# %%
response_nash
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1445892, 'lng': -86.8136},
#     'viewport': {'northeast': {'lat': 36.14593902989272,
#       'lng': -86.81225017010728},
#      'southwest': {'lat': 36.14323937010727, 'lng': -86.81494982989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Piggly Wiggly',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113359179597487495544">Jack Warman</a>'],
#      'photo_reference': 'ATtYBwLWtIYKKM6DN6QB8jQhK86pMQBYR8hT_pt8UwJS_1-zHYrU_0jnxX_It0Ejw5yn_zBY_skUC2gaMyEkJwNW3t5a-poFkwDZQw18xnTA0y1P1AVXFMylX1NCcKZ-E3CwKd8vmrt9-vOB8M-L4iTVEZkcWIYzAUXednOiwxl-PapbI5-p',
#      'width': 3840}],
#    'place_id': 'ChIJF_mw3q9mZIgRQdSpspW80MQ',
#    'plus_code': {'compound_code': '45VP+RH Nashville, Tennessee',
#     'global_code': '868M45VP+RH'},
#    'price_level': 2,
#    'rating': 4,
#    'reference': 'ChIJF_mw3q9mZIgRQdSpspW80MQ',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 361,
#    'vicinity': '2900 West End Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1758569, 'lng': -86.79427369999999},
#     'viewport': {'northeast': {'lat': 36.17703907989273,
#       'lng': -86.79283387010727},
#      'southwest': {'lat': 36.17433942010728, 'lng': -86.79553352989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1280,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110336675155918874463">Kroger</a>'],
#      'photo_reference': 'ATtYBwLIe4no7G8NjcmXsL7uyE0fYUiUSh-w3E1c9DOrA72jQeo0FcHhYTRqM-tPJDzMd545qriXqOOLsngHkvba3WsBLKcgTSZ8e2Gkjp5pbQDkY4mSfdn03MJnPkhVzygnLeW44j8a0UaoT9Rz2Ufq1E1hlsE1vdPc1AoQ8_cI1ckrO6fy',
#      'width': 1920}],
#    'place_id': 'ChIJ0f1NweJmZIgRYnc_3nqNyag',
#    'plus_code': {'compound_code': '56G4+87 Nashville, Tennessee',
#     'global_code': '868M56G4+87'},
#    'price_level': 2,
#    'rating': 3.7,
#    'reference': 'ChIJ0f1NweJmZIgRYnc_3nqNyag',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 890,
#    'vicinity': '800 Monroe St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1853811, 'lng': -86.8159932},
#     'viewport': {'northeast': {'lat': 36.18663382989272,
#       'lng': -86.81489022010727},
#      'southwest': {'lat': 36.18393417010728, 'lng': -86.81758987989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Save A Lot',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1440,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111089389699251425402">A Google User</a>'],
#      'photo_reference': 'ATtYBwJEJe3cYVKvJYmB14xV2U4vDSNn4Yo9EXd4lHOx36DEMD5kAaeVeVK8mDD5VFlHhz-6QpaOieOveIvDOegIeg12V6SAq9QAA4muYZWTePj6nUqBxvuQ9HjXmDNhOAjANpvsUsKwnb16gF7fLUatQo9ldVw0u4K39Z_xvTjCN-3vQLEE',
#      'width': 2560}],
#    'place_id': 'ChIJCTHj7C5nZIgR8KzLicfUjkw',
#    'plus_code': {'compound_code': '55PM+5J Nashville, Tennessee',
#     'global_code': '868M55PM+5J'},
#    'rating': 4,
#    'reference': 'ChIJCTHj7C5nZIgR8KzLicfUjkw',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 512,
#    'vicinity': '2400 Clarksville Pike, Nashville'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 36.1634125, 'lng': -86.779421},
#     'viewport': {'northeast': {'lat': 36.16473492989273,
#       'lng': -86.77817392010726},
#      'southwest': {'lat': 36.16203527010729, 'lng': -86.78087357989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'H.G. Hill Urban Market',
#    'permanently_closed': True,
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106519442576080453760">A Google User</a>'],
#      'photo_reference': 'ATtYBwIE3GD2-XOqfnuAUPS9nt0QKUEazR7pAXTl0u9dkmRDWn8T--5J4tc_ncJaD9AMwz6Ayn0h1MT2AHjCeaheORNKfFjzCMe0_WY4jpZ_qi1ZPCqsMBSkkrPqa1A6fuydvTVoOLbwVTLOHdgwLFxd3YynZoIR-kwhfrsTfUECB0PdeiAF',
#      'width': 3264}],
#    'place_id': 'ChIJPStOVVhmZIgRso0FW3wu3Hw',
#    'plus_code': {'compound_code': '567C+96 Nashville, Tennessee',
#     'global_code': '868M567C+96'},
#    'rating': 4.2,
#    'reference': 'ChIJPStOVVhmZIgRso0FW3wu3Hw',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 191,
#    'vicinity': '415 Church St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1594967, 'lng': -86.8140176},
#     'viewport': {'northeast': {'lat': 36.16086467989272,
#       'lng': -86.81256562010728},
#      'southwest': {'lat': 36.15816502010728, 'lng': -86.81526527989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "Resha's Bi-Rite Market",
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJ4ZED5shmZIgRz1kBNC9ENYg',
#    'plus_code': {'compound_code': '555P+Q9 Nashville, Tennessee',
#     'global_code': '868M555P+Q9'},
#    'rating': 3.8,
#    'reference': 'ChIJ4ZED5shmZIgRz1kBNC9ENYg',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 57,
#    'vicinity': '717 25th Ave N, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1844743, 'lng': -86.74677849999999},
#     'viewport': {'northeast': {'lat': 36.18570212989272,
#       'lng': -86.74576282010727},
#      'southwest': {'lat': 36.18300247010728, 'lng': -86.74846247989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2201,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113827070569302562718">Andrew L</a>'],
#      'photo_reference': 'ATtYBwKYjyKn2JxyyZoMakHaqzXZBHigISD95bREyUQ9hAdy9bRs39gg50pffU0N9ZghvBIOzqzwzjw7uxoylm8hYw1M7omlTmD2pNGMDUDtBGf7D0UDZa_5UvCFXEL6Zi0xF3wCrG_J8nB66MBIJNJqHPT7-EA-V5-I2dn7f_WSdcuys81x',
#      'width': 7268}],
#    'place_id': 'ChIJCyiJ2tBnZIgReYaDDx5KLEM',
#    'plus_code': {'compound_code': '57M3+Q7 Nashville, Tennessee',
#     'global_code': '868M57M3+Q7'},
#    'price_level': 2,
#    'rating': 3.7,
#    'reference': 'ChIJCyiJ2tBnZIgReYaDDx5KLEM',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 687,
#    'vicinity': '711 Gallatin Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1755409, 'lng': -86.75727979999999},
#     'viewport': {'northeast': {'lat': 36.17693902989273,
#       'lng': -86.75582627010729},
#      'southwest': {'lat': 36.17423937010728, 'lng': -86.75852592989274}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Weiss Drive-In Market',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115968242670899721832">Andrea</a>'],
#      'photo_reference': 'ATtYBwILEvpLa5jmHBvKoXef9GDL5EXdZrGFMcJstuv63kHgrdaNikfDdTTiGrnJcg_f4QiYrAERkXBjy23mL6SecE0c1ne7YcKuD-4yUZWqp7zbGG0NkHL7V7X3pqxdeDsm6nIOWTgmGTmbkCzjZuEQOF3560OhGki3cpCjoYiOgqC1LNqT',
#      'width': 4032}],
#    'place_id': 'ChIJrVUAszRmZIgR_uKBTX5M2yo',
#    'plus_code': {'compound_code': '56GV+63 Nashville, Tennessee',
#     'global_code': '868M56GV+63'},
#    'rating': 4.1,
#    'reference': 'ChIJrVUAszRmZIgR_uKBTX5M2yo',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 14,
#    'vicinity': '826 Main St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1739207, 'lng': -86.7459911},
#     'viewport': {'northeast': {'lat': 36.17517912989273,
#       'lng': -86.74465462010728},
#      'southwest': {'lat': 36.17247947010728, 'lng': -86.74735427989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': '4 Way Market',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106875532012586085102">Massbaum</a>'],
#      'photo_reference': 'ATtYBwJRdRjP0Hqw5PU-2oHfUcQ1ywHJmoS6IwwI7aq_PGIkE5walZuiFLwP8e4HftEwFDYRcFF1lWMawDDCfcC_S1qqJOHCYCR2SdNNDlMz7jqjffmkt4qJ-5FUJGgYlEAt3UDB4HeQko6AR7DIhIFOpJgVGD5VBStJUvysTdJpEzMOKJ94',
#      'width': 4032}],
#    'place_id': 'ChIJCXauaCtmZIgRYZpTghT1TBE',
#    'plus_code': {'compound_code': '57F3+HJ Nashville, Tennessee',
#     'global_code': '868M57F3+HJ'},
#    'rating': 4.3,
#    'reference': 'ChIJCXauaCtmZIgRYZpTghT1TBE',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 72,
#    'vicinity': '1401 Fatherland St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1318851, 'lng': -86.76877499999999},
#     'viewport': {'northeast': {'lat': 36.13314642989272,
#       'lng': -86.76743662010726},
#      'southwest': {'lat': 36.13044677010728, 'lng': -86.77013627989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Wedgehill Market',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115761387019637953020">Michael Orosco</a>'],
#      'photo_reference': 'ATtYBwIaC4eGHGrJd71SlcVGtlO4c_Q7HJo7cGk62H4aKa_TxKq9c_WCIY1-8ME2-t5KSTugHodOYjhZYS6r7cRjLKbbhgGb-j_yGYDIoG7AaxU5V8NoHQSy0NNB-aXUggwAIeOxntNH71tI5c5f-4w_ImeE4uz2ByxR320pvPVNebfepWOg',
#      'width': 5312}],
#    'place_id': 'ChIJmyJmjthlZIgR_8KhYLlhP0E',
#    'plus_code': {'compound_code': '46JJ+QF Nashville, Tennessee',
#     'global_code': '868M46JJ+QF'},
#    'rating': 4.6,
#    'reference': 'ChIJmyJmjthlZIgR_8KhYLlhP0E',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 71,
#    'vicinity': '600 Benton Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.15901760000001, 'lng': -86.8182096},
#     'viewport': {'northeast': {'lat': 36.16033492989273,
#       'lng': -86.81705327010728},
#      'southwest': {'lat': 36.15763527010728, 'lng': -86.81975292989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "Swett's Market",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1440,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106731321516876371408">A Google User</a>'],
#      'photo_reference': 'ATtYBwKS135Zu5EBA2klFW6kI7yVRajfsqZ7njbf8R5AttC99ZdRv-D1OGZDxcTBQf2Cn4snMId8Inz8dvZCvXjItc964hNg8TPbq2ok11WFTIxor0O4rl_RJd6DfY6sAe038n4MN97dWPPLOlLeSCUCIf0rpW_ruGQynM0oMdg-jN3VlE1e',
#      'width': 2560}],
#    'place_id': 'ChIJ4Rt8tstmZIgR8DW1VbfQCMw',
#    'plus_code': {'compound_code': '555J+JP Nashville, Tennessee',
#     'global_code': '868M555J+JP'},
#    'rating': 3.8,
#    'reference': 'ChIJ4Rt8tstmZIgR8DW1VbfQCMw',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 106,
#    'vicinity': '702 28th Ave N, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1832883, 'lng': -86.7475518},
#     'viewport': {'northeast': {'lat': 36.18446342989272,
#       'lng': -86.74629432010728},
#      'southwest': {'lat': 36.18176377010728, 'lng': -86.74899397989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'ALDI',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107053115772497782619">A Google User</a>'],
#      'photo_reference': 'ATtYBwLIK4ZkD6Gtd91CCG75qM-b3lYA7T8ye4LebbCwZ3L7diKDAGah2swlJh-3q_At6j-usLV8YBLg2Xrcj7vVVIvTM7pEvCXV1BsE4esnhCPQQVZmMy_oFCV_WGzCMaqlmfH1mpx963BqErLS4jbEnzCHypJuuABFwVKIg47QB2PfhR4T',
#      'width': 4032}],
#    'place_id': 'ChIJgRoqI9FnZIgRK-JHS7MI0qE',
#    'plus_code': {'compound_code': '57M2+8X Nashville, Tennessee',
#     'global_code': '868M57M2+8X'},
#    'price_level': 1,
#    'rating': 4.5,
#    'reference': 'ChIJgRoqI9FnZIgRK-JHS7MI0qE',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 631,
#    'vicinity': '615 Gallatin Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1474762, 'lng': -86.7593486},
#     'viewport': {'northeast': {'lat': 36.14896467989272,
#       'lng': -86.75792707010729},
#      'southwest': {'lat': 36.14626502010727, 'lng': -86.76062672989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Z Mart',
#    'place_id': 'ChIJsWvqChNmZIgR_T0Pp_k_TrM',
#    'plus_code': {'compound_code': '46WR+X7 Nashville, Tennessee',
#     'global_code': '868M46WR+X7'},
#    'rating': 3.5,
#    'reference': 'ChIJsWvqChNmZIgR_T0Pp_k_TrM',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 6,
#    'vicinity': '141 Lafayette St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1832368, 'lng': -86.812551},
#     'viewport': {'northeast': {'lat': 36.18449012989272,
#       'lng': -86.81129432010728},
#      'southwest': {'lat': 36.18179047010728, 'lng': -86.81399397989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "SAM'S MARKET",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103659464595606534317">SAM</a>'],
#      'photo_reference': 'ATtYBwI5JzULLJ0NwpGmMViKhpUq4O-HdlMwPHWK3nQdchPf6X85NQlyaI8-S3dC9cCTdBYujw9hJKwTCzENtPLg6QRQk84i1PPntONr5tXzggomZclBUhkKtYY30V3JV4K8e1XTLPb62kEo62dOnEVGYU2t1ib6aHcBIH-986mPXN02o8LR',
#      'width': 3264}],
#    'place_id': 'ChIJGVsGTi9nZIgRAa6Iee-oLMQ',
#    'plus_code': {'compound_code': '55MP+7X Nashville, Tennessee',
#     'global_code': '868M55MP+7X'},
#    'rating': 4.5,
#    'reference': 'ChIJGVsGTi9nZIgRAa6Iee-oLMQ',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 34,
#    'vicinity': '2012 Clarksville Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1567496, 'lng': -86.7880596},
#     'viewport': {'northeast': {'lat': 36.15822177989272,
#       'lng': -86.78688217010726},
#      'southwest': {'lat': 36.15552212010728, 'lng': -86.78958182989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Whole Foods Market',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3801,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116546288138045050659">A Google User</a>'],
#      'photo_reference': 'ATtYBwLcVSlhBHbKiP4qInUGeEnNJExd81Hsv0PwSNjBrRo42B4nV0yBZ5JPm4_ziibgU9zewKJoguBC76aPtk62O9L9qLNqJHU33mk2hv8oO0w6KSoEWwuKszAaHRHcQU5ojweeb821QsF8QgvbQHSBUoTJ5IDoOknWTXgPFqv-KvoYCyRA',
#      'width': 6000}],
#    'place_id': 'ChIJY1hOx5hnZIgRaU2PoQEx2R0',
#    'plus_code': {'compound_code': '5646+MQ Nashville, Tennessee',
#     'global_code': '868M5646+MQ'},
#    'rating': 4.6,
#    'reference': 'ChIJY1hOx5hnZIgRaU2PoQEx2R0',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 156,
#    'vicinity': '1202 Broadway, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1527599, 'lng': -86.78545869999999},
#     'viewport': {'northeast': {'lat': 36.15402722989273,
#       'lng': -86.78403837010728},
#      'southwest': {'lat': 36.15132757010728, 'lng': -86.78673802989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'The Turnip Truck Urban Fare',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111780832437308997914">A Google User</a>'],
#      'photo_reference': 'ATtYBwJZxhLlM0bQ40qItDz5i6rQoBxS52opU7jm3K0znOY03bJI4bjmJVoCUQMRgaVm6Bn_ZmGHZDsT10_QTgfeswOBn2kTKfHtO7jBxB9xCC5ums-AXh7JhmyrrplCMNL0QGdMqFOQiz2Zk_RUlwsnMKy4lssgaXve14tWv9nrP7GvI_mq',
#      'width': 3024}],
#    'place_id': 'ChIJE-1HDItmZIgRSm3egxKPeck',
#    'plus_code': {'compound_code': '5637+4R Nashville, Tennessee',
#     'global_code': '868M5637+4R'},
#    'rating': 4.5,
#    'reference': 'ChIJE-1HDItmZIgRSm3egxKPeck',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 424,
#    'vicinity': '321 12th Ave S, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1329002, 'lng': -86.7887039},
#     'viewport': {'northeast': {'lat': 36.13425077989272,
#       'lng': -86.78734452010728},
#      'southwest': {'lat': 36.13155112010728, 'lng': -86.79004417989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'The Store',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJyzYwFj5lZIgRFGB0hYpHoQA',
#    'plus_code': {'compound_code': '46M6+5G Nashville, Tennessee',
#     'global_code': '868M46M6+5G'},
#    'rating': 5,
#    'reference': 'ChIJyzYwFj5lZIgRFGB0hYpHoQA',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 12,
#    'vicinity': '2009 12th Ave S, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1632696, 'lng': -86.7896679},
#     'viewport': {'northeast': {'lat': 36.16425947989273,
#       'lng': -86.78834562010726},
#      'southwest': {'lat': 36.16155982010728, 'lng': -86.79104527989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Publix Super Market at Capitol View',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101238290545615941587">Jenn Durham</a>'],
#      'photo_reference': 'ATtYBwIKXXuBqhjHwDUT_F9FQMxra9DSDxyu1G3jSg1HroaRCOr7azlwQpbPhpppRchac01h-0WUQ2XUJPZG8mFewuG96Yd4ZKG1NXPuSSN6Ys-6K9H0dgEki8MVp2eJ0uS-m0hQoiBZkzUgJtXcbFvk1vkkli7Bvcb-zaIJtIZwocK63YyF',
#      'width': 4032}],
#    'place_id': 'ChIJ_3hhuz9nZIgROr9342w22Ic',
#    'plus_code': {'compound_code': '5676+84 Nashville, Tennessee',
#     'global_code': '868M5676+84'},
#    'rating': 4.4,
#    'reference': 'ChIJ_3hhuz9nZIgROr9342w22Ic',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'bakery',
#     'liquor_store',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 137,
#    'vicinity': '1010 Dr Martin L King Jr Blvd, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1549405, 'lng': -86.7734169},
#     'viewport': {'northeast': {'lat': 36.15631442989272,
#       'lng': -86.77200867010727},
#      'southwest': {'lat': 36.15361477010727, 'lng': -86.77470832989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'DOWNTOWN FRESH MARKET',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113017152172333760517">A Google User</a>'],
#      'photo_reference': 'ATtYBwJHeno7UYpmh7lIjmVUq9u3bnStxHIViS-tCGQtXOmr9sCuxi5pJDrVeQPaQNewtsPibIkNOhqn-6yJE5I6BZXQoA45ag-xgo_jsIz_ZOj-dwC7N1EnpKRSCJuEefE1Jx9IHaV2AW23OliLDkhx1EtPH4P8jgqdztxAcrr6Epuvddtg',
#      'width': 3024}],
#    'place_id': 'ChIJuTn3A-tnZIgREs7ZhppWRb0',
#    'plus_code': {'compound_code': '563G+XJ Nashville, Tennessee',
#     'global_code': '868M563G+XJ'},
#    'rating': 5,
#    'reference': 'ChIJuTn3A-tnZIgREs7ZhppWRb0',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'convenience_store',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '531 4th Ave S, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1877595, 'lng': -86.7730452},
#     'viewport': {'northeast': {'lat': 36.18911957989271,
#       'lng': -86.77182812010729},
#      'southwest': {'lat': 36.18641992010726, 'lng': -86.77452777989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Star Market',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJORilXaVnZIgRxP_1G83ELjk',
#    'plus_code': {'compound_code': '56QG+4Q Nashville, Tennessee',
#     'global_code': '868M56QG+4Q'},
#    'rating': 0,
#    'reference': 'ChIJORilXaVnZIgRxP_1G83ELjk',
#    'scope': 'GOOGLE',
#    'types': ['convenience_store',
#     'grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': '903 Dickerson Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1318231, 'lng': -86.7573699},
#     'viewport': {'northeast': {'lat': 36.13325702989272,
#       'lng': -86.75590727010729},
#      'southwest': {'lat': 36.13055737010728, 'lng': -86.75860692989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'U.S.Discount Tobacco & Beer',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3264,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105673395222210057069">Sandra Tucker</a>'],
#      'photo_reference': 'ATtYBwKYIKejn9nwHiOL1iOQAKEWhCVhq5S-L_7XUzYk5suGfi2DHpwL0loJtrAEUUOMGTRSWLlmG8cfrK9YBswjiaSW2UcEqmg3PamEFNhBUNtqWbKFgWAM5LMiorTpG17q0wtjrj9hFO1hMcTkOjFqz4fcRWJ7U5cNRcGsz_ybtxyzAclM',
#      'width': 2448}],
#    'place_id': 'ChIJ93X87-FlZIgRo71ee_0_6rY',
#    'plus_code': {'compound_code': '46JV+P3 Nashville, Tennessee',
#     'global_code': '868M46JV+P3'},
#    'rating': 4.2,
#    'reference': 'ChIJ93X87-FlZIgRo71ee_0_6rY',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 19,
#    'vicinity': '1997 Nolensville Pike, Nashville'}],
#  'status': 'OK'}

# %%
type(response_nash)
# Out:
# dict

# %%
response_nash['results'][0].values()
# Out:
# dict_values(['OPERATIONAL', {'location': {'lat': 36.1445892, 'lng': -86.8136}, 'viewport': {'northeast': {'lat': 36.14593902989272, 'lng': -86.81225017010728}, 'southwest': {'lat': 36.14323937010727, 'lng': -86.81494982989271}}}, 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png', 'Piggly Wiggly', {'open_now': True}, [{'height': 2160, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113359179597487495544">Jack Warman</a>'], 'photo_reference': 'ATtYBwLWtIYKKM6DN6QB8jQhK86pMQBYR8hT_pt8UwJS_1-zHYrU_0jnxX_It0Ejw5yn_zBY_skUC2gaMyEkJwNW3t5a-poFkwDZQw18xnTA0y1P1AVXFMylX1NCcKZ-E3CwKd8vmrt9-vOB8M-L4iTVEZkcWIYzAUXednOiwxl-PapbI5-p', 'width': 3840}], 'ChIJF_mw3q9mZIgRQdSpspW80MQ', {'compound_code': '45VP+RH Nashville, Tennessee', 'global_code': '868M45VP+RH'}, 2, 4, 'ChIJF_mw3q9mZIgRQdSpspW80MQ', 'GOOGLE', ['grocery_or_supermarket', 'supermarket', 'food', 'point_of_interest', 'store', 'establishment'], 361, '2900 West End Ave, Nashville'])

# %%
endpoint_east='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.19537564483769, -86.74323696479676&maxResults=60&radius=3300&keyword=groceries&key=AIzaSyDR7esAMJqahioM7VjF0FOsoM3mv1Jheo4'

# %%
def find_nearby_places_east(api_key=api_key,
                      location='36.19537564483769, -86.74323696479676',
                      radius='3300',
                      base = 'https://maps.googleapis.com/maps/api/place/nearbysearch/',
                      keyword= 'groceries',
                      response_type = 'json',
                      pageToken='nextPageToken',
                      **kwargs):
    '''
    Constructs endpoint and params dict, makes request, and returns output as json
    
    api_key: requred, str, API key from google cloud console
    location: required, str, central location for near by search, format: "<lat>, <lng>"
    radius: required, str, radius of circle (in meters) to search for nearby locations
    base: not required, str, URL base for API request
    resoponse_type: not required, format of response
    **kwargs: not required, search criteria for near by locations
    '''
    endpoint_east = base+response_type
    kwargs['key'] = api_key
    kwargs['location'] = '36.19537564483769, -86.74323696479676'
    kwargs['radius'] = '3300'
    kwargs['pageToken']= 'nextPageToken'
    kwargs['keyword'] = 'groceries',
    res = requests.get(endpoint_east, kwargs)
    return res.json()

# %%
response = requests.get(endpoint_east)
response.status_code
# Out:
# 200

# %%
response_east = find_nearby_places_east()
response_east
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1844743, 'lng': -86.74677849999999},
#     'viewport': {'northeast': {'lat': 36.18570212989272,
#       'lng': -86.74576282010727},
#      'southwest': {'lat': 36.18300247010728, 'lng': -86.74846247989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2201,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113827070569302562718">Andrew L</a>'],
#      'photo_reference': 'ATtYBwLVE6yjXjBcWgDrWikdOYopMCPJz52H95pk3dj04lVEaIbdFBMekHVzKlAWZa2p-JmBFlWGBB5nElZpGAKPnEFZobOnBo3dzLHlSG5Sk7K2h8c_9IPkxjwERRWZnaozGjBP-Id4lG4FtNL-hLEzz7r_3fy6CU9WFwDWgjsouuGbpi2S',
#      'width': 7268}],
#    'place_id': 'ChIJCyiJ2tBnZIgReYaDDx5KLEM',
#    'plus_code': {'compound_code': '57M3+Q7 Nashville, Tennessee',
#     'global_code': '868M57M3+Q7'},
#    'price_level': 2,
#    'rating': 3.7,
#    'reference': 'ChIJCyiJ2tBnZIgReYaDDx5KLEM',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 687,
#    'vicinity': '711 Gallatin Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.2101188, 'lng': -86.7324397},
#     'viewport': {'northeast': {'lat': 36.21148802989272,
#       'lng': -86.73108607010728},
#      'southwest': {'lat': 36.20878837010728, 'lng': -86.73378572989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3096,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116765434657480531728">A Google User</a>'],
#      'photo_reference': 'ATtYBwL71NSAMKGxAECMz-CGfLCqpL2k0W_NHbM8xloN9sc2yVBQ8bA8iQDMXASzPZGqdiixTYLP5ZJmYKL_DYK2COSLAOsB7DveQtDpiEQTAt2Zek4qM9Idwgs13bYD5OSpQyK1SOU8pjZAfingPc_k8M_h4HaahAIR30hLaz6DMKx0Btii',
#      'width': 4128}],
#    'place_id': 'ChIJZyYDJgVoZIgRp_UaluUQWjY',
#    'plus_code': {'compound_code': '6769+22 Nashville, Tennessee',
#     'global_code': '868M6769+22'},
#    'price_level': 2,
#    'rating': 3.9,
#    'reference': 'ChIJZyYDJgVoZIgRp_UaluUQWjY',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 893,
#    'vicinity': '3410 Gallatin Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1755409, 'lng': -86.75727979999999},
#     'viewport': {'northeast': {'lat': 36.17693902989273,
#       'lng': -86.75582627010729},
#      'southwest': {'lat': 36.17423937010728, 'lng': -86.75852592989274}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Weiss Drive-In Market',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115968242670899721832">Andrea</a>'],
#      'photo_reference': 'ATtYBwKMM5JxpGuBgiV07dvqShz1C-O-whjL7dx2tS-Kckuy8J_VFb6yjRocheJ7U-3-PiScd8lEds28_ieLl98xbooPisFWw91_vjArwzXYGOGw4AVQQyC9gBOUflkv3pcPdLzN9wSpvrPv2sLATHccdUMHzgGNKsPPKYfYCIHejQmxsRHZ',
#      'width': 4032}],
#    'place_id': 'ChIJrVUAszRmZIgR_uKBTX5M2yo',
#    'plus_code': {'compound_code': '56GV+63 Nashville, Tennessee',
#     'global_code': '868M56GV+63'},
#    'rating': 4.1,
#    'reference': 'ChIJrVUAszRmZIgR_uKBTX5M2yo',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 14,
#    'vicinity': '826 Main St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.2077791, 'lng': -86.76702279999999},
#     'viewport': {'northeast': {'lat': 36.20899562989273,
#       'lng': -86.76577952010727},
#      'southwest': {'lat': 36.20629597010728, 'lng': -86.76847917989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Piggly Wiggly',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2340,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109400472957608256078">Caleb Hendon</a>'],
#      'photo_reference': 'ATtYBwJ29LfDR1swwm0rdciKVvJ9EFfhEeVq9RZWuAVYeRiz3yGT3wH1EK1rpuP90IRqnUzfoUK_mIeSJ2wOlHzwU5lL1EYKwZZoVs8b1EvZ18A2u5a5T_3opteolaKqn-CrINom3BrNoQvkyfj_F5eG5An2y3EeTZJELpkRuWMr-KaBB_ag',
#      'width': 4160}],
#    'place_id': 'ChIJM3OiQKVnZIgRxiZuRvmGZxg',
#    'plus_code': {'compound_code': '665M+45 Nashville, Tennessee',
#     'global_code': '868M665M+45'},
#    'price_level': 2,
#    'rating': 4,
#    'reference': 'ChIJM3OiQKVnZIgRxiZuRvmGZxg',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 533,
#    'vicinity': '2317 Dickerson Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1739207, 'lng': -86.7459911},
#     'viewport': {'northeast': {'lat': 36.17517912989273,
#       'lng': -86.74465462010728},
#      'southwest': {'lat': 36.17247947010728, 'lng': -86.74735427989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': '4 Way Market',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106875532012586085102">Massbaum</a>'],
#      'photo_reference': 'ATtYBwK7a2sS81TpmN4XIjC95lyaoW8v8VCsx4OoFVDM7zH9E99qy6ZOC6Mvd15GRyIZKE8K4n2sa-KmU77b0z74fnkt-D9HO0ajF7nzI6Lh9hwsmjVzHS_WkhPiccVqZeZBAuBYfiXXs1Ma1vDXsgg_WW_UMCTAIzucJpkZWXbNbfUUev0n',
#      'width': 4032}],
#    'place_id': 'ChIJCXauaCtmZIgRYZpTghT1TBE',
#    'plus_code': {'compound_code': '57F3+HJ Nashville, Tennessee',
#     'global_code': '868M57F3+HJ'},
#    'rating': 4.3,
#    'reference': 'ChIJCXauaCtmZIgRYZpTghT1TBE',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 72,
#    'vicinity': '1401 Fatherland St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1832883, 'lng': -86.7475518},
#     'viewport': {'northeast': {'lat': 36.18446342989272,
#       'lng': -86.74629432010728},
#      'southwest': {'lat': 36.18176377010728, 'lng': -86.74899397989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'ALDI',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107053115772497782619">A Google User</a>'],
#      'photo_reference': 'ATtYBwJtte70Ub97s3QlmmATS_WEFBlAYiHCjsMexP4ztHrS6kqdpkWFYJuwygZLxzK5lsbbHEOBeZYquWCD0mPlZdpGt88QgwVgOHE01X139rIhbIWKxSu13NbgOGnCj_onqCAUalhEo0ZzAVsKcQr1cCi_VYwMTAuj7LJQ6PsNSOWU_p0_',
#      'width': 4032}],
#    'place_id': 'ChIJgRoqI9FnZIgRK-JHS7MI0qE',
#    'plus_code': {'compound_code': '57M2+8X Nashville, Tennessee',
#     'global_code': '868M57M2+8X'},
#    'price_level': 1,
#    'rating': 4.5,
#    'reference': 'ChIJgRoqI9FnZIgRK-JHS7MI0qE',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 631,
#    'vicinity': '615 Gallatin Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.2022406, 'lng': -86.7389614},
#     'viewport': {'northeast': {'lat': 36.20367657989272,
#       'lng': -86.73762212010728},
#      'southwest': {'lat': 36.20097692010728, 'lng': -86.74032177989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "Litton's Corner Market",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3492,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103498631302409342999">Michael Tims</a>'],
#      'photo_reference': 'ATtYBwLUU4mOhBjoyZSutQOvLVSSrpuizJW8d-L-SyNjmeZQ-TCxBTqi_eyFocVhB9I2Jwic-GrMQ9nspVD4rGp48EMZPXLhvsmpg4tTrFfzdJxCMqjMUqz6nkByyaZ6uIJl97m2DLsFf-XSJK9chnt1kv-RUs_ZqOi4U18HQC5f8wZHmQnS',
#      'width': 4656}],
#    'place_id': 'ChIJa55T0QtoZIgRtVCd8YGpy8I',
#    'plus_code': {'compound_code': '6726+VC Nashville, Tennessee',
#     'global_code': '868M6726+VC'},
#    'rating': 4.1,
#    'reference': 'ChIJa55T0QtoZIgRtVCd8YGpy8I',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 29,
#    'vicinity': '2830 Gallatin Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.2012332, 'lng': -86.7581587},
#     'viewport': {'northeast': {'lat': 36.20259067989272,
#       'lng': -86.75687717010727},
#      'southwest': {'lat': 36.19989102010728, 'lng': -86.75957682989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Jammers Market',
#    'photos': [{'height': 960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113157421530263330371">Crafty Mama</a>'],
#      'photo_reference': 'ATtYBwKZhh1RXe7cglhpN9OdJ52lAWIIqt42hy2g1UhI1EdldZE7BHiUFqwEo2t8h11iYdDaa64Bks58ph1s-dJuPO6_t4joYPoxyRKd1UTz5iW06Sm1fSeNxs1pP1vA-QMa8kJ_niLB-xSFmoPqi-BwHbRFqdHhVXgVwCwwyMDxV1mOBwUt',
#      'width': 1280}],
#    'place_id': 'ChIJiaIWuetnZIgR7Riz5lPYIYI',
#    'plus_code': {'compound_code': '662R+FP Nashville, Tennessee',
#     'global_code': '868M662R+FP'},
#    'rating': 4.5,
#    'reference': 'ChIJiaIWuetnZIgR7Riz5lPYIYI',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 24,
#    'vicinity': '1519 Jones Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1999223, 'lng': -86.7696038},
#     'viewport': {'northeast': {'lat': 36.20131027989272,
#       'lng': -86.76843522010728},
#      'southwest': {'lat': 36.19861062010728, 'lng': -86.77113487989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Uptownfruitmarket',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118115938674938214568">Uptownfruitmarket</a>'],
#      'photo_reference': 'ATtYBwKujYk1qYaCmO3879FyF9ddtUGjULiNTtdu924sDr3NE2SLcZWH2AJTnUmrILJ0sJMczUdFWaslRjR7D65m7OwVuUSh4BWnEVtUlVWCOCL7yKmj4kuCX9hGP1rvTsMX5NFlemgws7jl25a3zfjFZsk5c3_V10MGt6rUIU3oes9FXV6n',
#      'width': 1080}],
#    'place_id': 'ChIJV_n1sZdnZIgRCK3MI0EMuQY',
#    'plus_code': {'compound_code': '56XJ+X5 Nashville, Tennessee',
#     'global_code': '868M56XJ+X5'},
#    'rating': 4.7,
#    'reference': 'ChIJV_n1sZdnZIgRCK3MI0EMuQY',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'finance',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 32,
#    'vicinity': '1431 Dickerson Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1877595, 'lng': -86.7730452},
#     'viewport': {'northeast': {'lat': 36.18911957989271,
#       'lng': -86.77182812010729},
#      'southwest': {'lat': 36.18641992010726, 'lng': -86.77452777989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Star Market',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJORilXaVnZIgRxP_1G83ELjk',
#    'plus_code': {'compound_code': '56QG+4Q Nashville, Tennessee',
#     'global_code': '868M56QG+4Q'},
#    'rating': 0,
#    'reference': 'ChIJORilXaVnZIgRxP_1G83ELjk',
#    'scope': 'GOOGLE',
#    'types': ['convenience_store',
#     'grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': '903 Dickerson Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.21165560000001, 'lng': -86.7649471},
#     'viewport': {'northeast': {'lat': 36.21297337989272,
#       'lng': -86.76362712010727},
#      'southwest': {'lat': 36.21027372010727, 'lng': -86.76632677989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Danial Market',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110172055445515908390">theresa deese</a>'],
#      'photo_reference': 'ATtYBwIQu2MeHg3NDX-ycFpegvrnq58gYa0vMVxd4uluGqXqF8faIENi4_Re25RyLnpZUtlkaMKoEu9EA2qQV8m9T0zONVOvJakziF2RMijAD2slhvkLP75hgUgK9PaXVxHOKJzJOJ42QiMmIGwEUV2GcpD5ur13AKTaMtiscMmrnYgG-5mj',
#      'width': 3264}],
#    'place_id': 'ChIJqxrsTYxnZIgR0IK9EdFsq1Q',
#    'plus_code': {'compound_code': '666P+M2 Nashville, Tennessee',
#     'global_code': '868M666P+M2'},
#    'rating': 4.6,
#    'reference': 'ChIJqxrsTYxnZIgR0IK9EdFsq1Q',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 19,
#    'vicinity': 'Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.2054457, 'lng': -86.7655468},
#     'viewport': {'northeast': {'lat': 36.20680752989273,
#       'lng': -86.76432932010728},
#      'southwest': {'lat': 36.20410787010728, 'lng': -86.76702897989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Trinity Lane Market',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3096,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104365275674933371481">Trenee&#39; Williamson</a>'],
#      'photo_reference': 'ATtYBwKADogA17FIXRS8egLQxIuEKNY4KDt-9d5s1PVwILSXc9kJ8FBFI_7reuZ0ciEI-kdJEuLgEn3aqrZqs0bgOodv7J0a91UxoZBMVB9Ru8QPCF2kKYKFU4uWT9vkkUMF8BAGiGiycpLmP8Nxm4W9Sic9i-e4H0i6jaRacgIGQSgxkptD',
#      'width': 4128}],
#    'place_id': 'ChIJ-bdHyJNnZIgRFrGMIosoZLo',
#    'plus_code': {'compound_code': '664M+5Q Nashville, Tennessee',
#     'global_code': '868M664M+5Q'},
#    'rating': 3.6,
#    'reference': 'ChIJ-bdHyJNnZIgRFrGMIosoZLo',
#    'scope': 'GOOGLE',
#    'types': ['convenience_store',
#     'supermarket',
#     'grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 21,
#    'vicinity': '1905 Meridian St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.20863629999999, 'lng': -86.7677653},
#     'viewport': {'northeast': {'lat': 36.20989732989272,
#       'lng': -86.76641522010728},
#      'southwest': {'lat': 36.20719767010728, 'lng': -86.76911487989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Garibaldi Market',
#    'place_id': 'ChIJo9KF4ZFnZIgRSwZcFtFegh4',
#    'plus_code': {'compound_code': '665J+FV Nashville, Tennessee',
#     'global_code': '868M665J+FV'},
#    'rating': 4.8,
#    'reference': 'ChIJo9KF4ZFnZIgRSwZcFtFegh4',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': '2402 Dickerson Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1765293, 'lng': -86.7751309},
#     'viewport': {'northeast': {'lat': 36.17791167989272,
#       'lng': -86.77373622010727},
#      'southwest': {'lat': 36.17521202010727, 'lng': -86.77643587989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "Larry's Quick Stop",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100091017896489400911">Beth1014</a>'],
#      'photo_reference': 'ATtYBwIRsXWKHz5l7W-DaAkijTrMerScVXtGRM1vCkg4SFkg6CqTOuk2Pv08H_xhfnOhKBhqxTF0ownnr3AhabE62w4O1-H6155oH0rDzhVTBO3oZW5XDAY1YvxEhpParUvZH_Jq8qGCwf-x0Pef_Ze4Pa4rbcW3-ZwfVnanzfILmKvaPpWO',
#      'width': 4160}],
#    'place_id': 'ChIJXyC3zaxnZIgRfcdTJ8AjYCQ',
#    'plus_code': {'compound_code': '56GF+JW Nashville, Tennessee',
#     'global_code': '868M56GF+JW'},
#    'rating': 3,
#    'reference': 'ChIJXyC3zaxnZIgRfcdTJ8AjYCQ',
#    'scope': 'GOOGLE',
#    'types': ['convenience_store',
#     'gas_station',
#     'grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 10,
#    'vicinity': '240 N 1st St, Nashville'}],
#  'status': 'OK'}

# %%
endpoint_south='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.10070107139286, -86.76297802246299&maxResults=60&radius=3300&keyword=groceries&key=AIzaSyDR7esAMJqahioM7VjF0FOsoM3mv1Jheo4'

# %%
def find_nearby_places_south(api_key=api_key,
                      location='36.10070107139286, -86.76297802246299',
                      radius='3300',
                      base = 'https://maps.googleapis.com/maps/api/place/nearbysearch/',
                      keyword= 'groceries',
                      response_type = 'json',
                      pageToken='nextPageToken',
                      **kwargs):
    '''
    Constructs endpoint and params dict, makes request, and returns output as json
    
    api_key: requred, str, API key from google cloud console
    location: required, str, central location for near by search, format: "<lat>, <lng>"
    radius: required, str, radius of circle (in meters) to search for nearby locations
    base: not required, str, URL base for API request
    resoponse_type: not required, format of response
    **kwargs: not required, search criteria for near by locations
    '''
    endpoint_south = base+response_type
    kwargs['key'] = api_key
    kwargs['location'] = '36.10070107139286, -86.76297802246299'
    kwargs['radius'] = '3300'
    kwargs['pageToken']= 'nextPageToken'
    kwargs['keyword'] = 'groceries',
    res = requests.get(endpoint_south, kwargs)
    return res.json()

# %%
response = requests.get(endpoint_south)
response.status_code
# Out:
# 200

# %%
response_south = find_nearby_places_south()

# %%
endpoint_west='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.14188399793224, -86.86254161940951&maxResults=60&radius=1600&keyword=groceries&key=AIzaSyDR7esAMJqahioM7VjF0FOsoM3mv1Jheo4'

# %%
def find_nearby_places_west(api_key=api_key,
                      location='36.14188399793224, -86.86254161940951',
                      radius='3300',
                      base = 'https://maps.googleapis.com/maps/api/place/nearbysearch/',
                      keyword= 'groceries',
                      response_type = 'json',
                      pageToken='nextPageToken',
                      **kwargs):
    '''
    Constructs endpoint and params dict, makes request, and returns output as json
    
    api_key: requred, str, API key from google cloud console
    location: required, str, central location for near by search, format: "<lat>, <lng>"
    radius: required, str, radius of circle (in meters) to search for nearby locations
    base: not required, str, URL base for API request
    resoponse_type: not required, format of response
    **kwargs: not required, search criteria for near by locations
    '''
    endpoint_south = base+response_type
    kwargs['key'] = api_key
    kwargs['location'] = '36.14188399793224, -86.86254161940951'
    kwargs['radius'] = '3300'
    kwargs['pageToken']= 'nextPageToken'
    kwargs['keyword'] = 'groceries',
    res = requests.get(endpoint_west, kwargs)
    return res.json()

# %%
response = requests.get(endpoint_west)
response.status_code
# Out:
# 200

# %%
response_west = find_nearby_places_west()

# %%
endpoint_north='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.18456939531024, -86.81773800109394&maxResults=60&radius=1600&keyword=groceries&key=AIzaSyDR7esAMJqahioM7VjF0FOsoM3mv1Jheo4'

# %%
def find_nearby_places_north(api_key=api_key,
                      location='36.18456939531024, -86.81773800109394',
                      radius='3300',
                      base = 'https://maps.googleapis.com/maps/api/place/nearbysearch/',
                      keyword= 'groceries',
                      response_type = 'json',
                      pageToken='nextPageToken',
                      **kwargs):
    '''
    Constructs endpoint and params dict, makes request, and returns output as json
    
    api_key: requred, str, API key from google cloud console
    location: required, str, central location for near by search, format: "<lat>, <lng>"
    radius: required, str, radius of circle (in meters) to search for nearby locations
    base: not required, str, URL base for API request
    resoponse_type: not required, format of response
    **kwargs: not required, search criteria for near by locations
    '''
    endpoint_north = base+response_type
    kwargs['key'] = api_key
    kwargs['location'] = '36.18456939531024, -86.81773800109394'
    kwargs['radius'] = '3300'
    kwargs['pageToken']= 'nextPageToken'
    kwargs['keyword'] = 'groceries',
    res = requests.get(endpoint_north, kwargs)
    return res.json()

# %%
response = requests.get(endpoint_north)
response.status_code
# Out:
# 200

# %%
response_north = find_nearby_places_north()

# %%
results_east=pd.DataFrame.from_dict(response_east['results'])

# %%
results_west=pd.DataFrame.from_dict(response_west['results'])

# %%
results_south=pd.DataFrame.from_dict(response_south['results'])

# %%
results_north=pd.DataFrame.from_dict(response_north['results'])

# %% [markdown]
# type(results_df)

# %% [markdown]
# results_df= pd.concat[(response_east + response_nash + response_north + response_south + response_west)]

# %% [markdown]
# results_df['results'].astype(object)

# %% [markdown]
# results_df=(response_east + response_nash + response_north
# +response_south+ response_west)

# %% [markdown]
# for store in jsonResponse["results"]:
#     print(item["name"])

# %%
results_df = [response_east['results'] + response_nash['results'] + response_north['results']
+response_south['results']+ response_west['results']]

# %%
response_east['results'][0].values()
# Out:
# dict_values(['OPERATIONAL', {'location': {'lat': 36.1844743, 'lng': -86.74677849999999}, 'viewport': {'northeast': {'lat': 36.18570212989272, 'lng': -86.74576282010727}, 'southwest': {'lat': 36.18300247010728, 'lng': -86.74846247989272}}}, 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png', 'Kroger', {'open_now': True}, [{'height': 2201, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113827070569302562718">Andrew L</a>'], 'photo_reference': 'ATtYBwLVE6yjXjBcWgDrWikdOYopMCPJz52H95pk3dj04lVEaIbdFBMekHVzKlAWZa2p-JmBFlWGBB5nElZpGAKPnEFZobOnBo3dzLHlSG5Sk7K2h8c_9IPkxjwERRWZnaozGjBP-Id4lG4FtNL-hLEzz7r_3fy6CU9WFwDWgjsouuGbpi2S', 'width': 7268}], 'ChIJCyiJ2tBnZIgReYaDDx5KLEM', {'compound_code': '57M3+Q7 Nashville, Tennessee', 'global_code': '868M57M3+Q7'}, 2, 3.7, 'ChIJCyiJ2tBnZIgReYaDDx5KLEM', 'GOOGLE', ['grocery_or_supermarket', 'food', 'point_of_interest', 'store', 'establishment'], 687, '711 Gallatin Ave, Nashville'])

# %% [markdown]
# results_df=pd.DataFrame.from_list(results_df['results'])

# %% [markdown]
# results_df=pd.DataFrame(results_df)
# results_df.reset_index()

# %%
type(results_north)
# Out:
# pandas.core.frame.DataFrame

# %%
results_north
# Out:
#        business_status                                           geometry  \
# 0          OPERATIONAL  {'location': {'lat': 36.1758569, 'lng': -86.79...
# 1          OPERATIONAL  {'location': {'lat': 36.1853811, 'lng': -86.81...
# 2          OPERATIONAL  {'location': {'lat': 36.1594967, 'lng': -86.81...
# 3          OPERATIONAL  {'location': {'lat': 36.2098477, 'lng': -86.83...
# 4          OPERATIONAL  {'location': {'lat': 36.15901760000001, 'lng':...
# 5          OPERATIONAL  {'location': {'lat': 36.193048, 'lng': -86.832...
# 6          OPERATIONAL  {'location': {'lat': 36.1832368, 'lng': -86.81...
# 7          OPERATIONAL  {'location': {'lat': 36.1567496, 'lng': -86.78...
# 8   CLOSED_TEMPORARILY  {'location': {'lat': 36.1634125, 'lng': -86.77...
# 9          OPERATIONAL  {'location': {'lat': 36.2084865, 'lng': -86.83...
# 10         OPERATIONAL  {'location': {'lat': 36.1599221, 'lng': -86.85...
# 11         OPERATIONAL  {'location': {'lat': 36.214061, 'lng': -86.816...
# 12         OPERATIONAL  {'location': {'lat': 36.1576546, 'lng': -86.84...
# 13         OPERATIONAL  {'location': {'lat': 36.1619172, 'lng': -86.84...
# 14         OPERATIONAL  {'location': {'lat': 36.1797936, 'lng': -86.82...
# 15         OPERATIONAL  {'location': {'lat': 36.1527329, 'lng': -86.83...
# 16         OPERATIONAL  {'location': {'lat': 36.1632696, 'lng': -86.78...
# 17         OPERATIONAL  {'location': {'lat': 36.2077803, 'lng': -86.78...
# 18         OPERATIONAL  {'location': {'lat': 36.1527599, 'lng': -86.78...
#
#                                                  icon  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                    name        opening_hours  \
# 0                                Kroger   {'open_now': True}
# 1                            Save A Lot  {'open_now': False}
# 2                Resha's Bi-Rite Market  {'open_now': False}
# 3                                Kroger   {'open_now': True}
# 4                        Swett's Market   {'open_now': True}
# 5                         Bordeaux Food  {'open_now': False}
# 6                          SAM'S MARKET  {'open_now': False}
# 7                    Whole Foods Market  {'open_now': False}
# 8                H.G. Hill Urban Market                  NaN
# 9               Hunter's Hometown Foods  {'open_now': False}
# 10                        Uptown market   {'open_now': True}
# 11                         Kijiji Foods  {'open_now': False}
# 12                           3 & M Mart   {'open_now': True}
# 13                 Super Mercado Latina                  NaN
# 14                              Daily's   {'open_now': True}
# 15                       Rosie's Market  {'open_now': False}
# 16  Publix Super Market at Capitol View   {'open_now': True}
# 17              Unique discount Tobacco   {'open_now': True}
# 18          The Turnip Truck Urban Fare  {'open_now': False}
#
#                                                photos  \
# 0   [{'height': 1280, 'html_attributions': ['<a hr...
# 1   [{'height': 1440, 'html_attributions': ['<a hr...
# 2                                                 NaN
# 3   [{'height': 1080, 'html_attributions': ['<a hr...
# 4   [{'height': 1440, 'html_attributions': ['<a hr...
# 5                                                 NaN
# 6   [{'height': 2448, 'html_attributions': ['<a hr...
# 7   [{'height': 3801, 'html_attributions': ['<a hr...
# 8   [{'height': 2448, 'html_attributions': ['<a hr...
# 9   [{'height': 1440, 'html_attributions': ['<a hr...
# 10  [{'height': 1600, 'html_attributions': ['<a hr...
# 11  [{'height': 960, 'html_attributions': ['<a hre...
# 12  [{'height': 1080, 'html_attributions': ['<a hr...
# 13                                                NaN
# 14                                                NaN
# 15  [{'height': 2268, 'html_attributions': ['<a hr...
# 16  [{'height': 3024, 'html_attributions': ['<a hr...
# 17  [{'height': 3024, 'html_attributions': ['<a hr...
# 18  [{'height': 4032, 'html_attributions': ['<a hr...
#
#                        place_id  \
# 0   ChIJ0f1NweJmZIgRYnc_3nqNyag
# 1   ChIJCTHj7C5nZIgR8KzLicfUjkw
# 2   ChIJ4ZED5shmZIgRz1kBNC9ENYg
# 3   ChIJ8_NRorxgZIgRrfj0tUFShq4
# 4   ChIJ4Rt8tstmZIgR8DW1VbfQCMw
# 5   ChIJvTVWTs9gZIgRuVx57Xu68ww
# 6   ChIJGVsGTi9nZIgRAa6Iee-oLMQ
# 7   ChIJY1hOx5hnZIgRaU2PoQEx2R0
# 8   ChIJPStOVVhmZIgRso0FW3wu3Hw
# 9   ChIJl5Oo-rxgZIgRQcj1A6s8R68
# 10  ChIJZYEdWQxhZIgRk7ziXPy9oKw
# 11  ChIJb3eWYFFnZIgRJ1cPSos4Zrc
# 12  ChIJfULdXBVhZIgRLJctT3HrvLc
# 13  ChIJ8QCi2BNhZIgRMtuYEFAHvaY
# 14  ChIJUQLDPNVgZIgRmyj3WCvY_Sg
# 15  ChIJu1HcRkZhZIgRwJab053mMeY
# 16  ChIJ_3hhuz9nZIgROr9342w22Ic
# 17  ChIJldWEoXdnZIgRYi2eGhA70pM
# 18  ChIJE-1HDItmZIgRSm3egxKPeck
#
#                                             plus_code  price_level  rating  \
# 0   {'compound_code': '56G4+87 Nashville, Tennesse...          2.0     3.7
# 1   {'compound_code': '55PM+5J Nashville, Tennesse...          NaN     4.0
# 2   {'compound_code': '555P+Q9 Nashville, Tennesse...          NaN     3.8
# 3   {'compound_code': '6556+WW Nashville, Tennesse...          2.0     4.0
# 4   {'compound_code': '555J+JP Nashville, Tennesse...          NaN     3.8
# 5   {'compound_code': '55V9+62 Nashville, Tennesse...          NaN     4.2
# 6   {'compound_code': '55MP+7X Nashville, Tennesse...          NaN     4.5
# 7   {'compound_code': '5646+MQ Nashville, Tennesse...          NaN     4.6
# 8   {'compound_code': '567C+96 Nashville, Tennesse...          NaN     4.2
# 9   {'compound_code': '6556+99 Nashville, Tennesse...          NaN     4.6
# 10  {'compound_code': '545V+XR Nashville, Tennesse...          NaN     4.6
# 11  {'compound_code': '657M+J7 Nashville, Tennesse...          NaN     4.0
# 12  {'compound_code': '5554+3W Nashville, Tennesse...          NaN     4.0
# 13  {'compound_code': '5562+QF Nashville, Tennesse...          NaN     0.0
# 14  {'compound_code': '55HG+WF Nashville, Tennesse...          NaN     0.0
# 15  {'compound_code': '5538+3J Nashville, Tennesse...          NaN     4.7
# 16  {'compound_code': '5676+84 Nashville, Tennesse...          NaN     4.4
# 17  {'compound_code': '6658+49 Nashville, Tennesse...          NaN     4.2
# 18  {'compound_code': '5637+4R Nashville, Tennesse...          NaN     4.5
#
#                       reference   scope  \
# 0   ChIJ0f1NweJmZIgRYnc_3nqNyag  GOOGLE
# 1   ChIJCTHj7C5nZIgR8KzLicfUjkw  GOOGLE
# 2   ChIJ4ZED5shmZIgRz1kBNC9ENYg  GOOGLE
# 3   ChIJ8_NRorxgZIgRrfj0tUFShq4  GOOGLE
# 4   ChIJ4Rt8tstmZIgR8DW1VbfQCMw  GOOGLE
# 5   ChIJvTVWTs9gZIgRuVx57Xu68ww  GOOGLE
# 6   ChIJGVsGTi9nZIgRAa6Iee-oLMQ  GOOGLE
# 7   ChIJY1hOx5hnZIgRaU2PoQEx2R0  GOOGLE
# 8   ChIJPStOVVhmZIgRso0FW3wu3Hw  GOOGLE
# 9   ChIJl5Oo-rxgZIgRQcj1A6s8R68  GOOGLE
# 10  ChIJZYEdWQxhZIgRk7ziXPy9oKw  GOOGLE
# 11  ChIJb3eWYFFnZIgRJ1cPSos4Zrc  GOOGLE
# 12  ChIJfULdXBVhZIgRLJctT3HrvLc  GOOGLE
# 13  ChIJ8QCi2BNhZIgRMtuYEFAHvaY  GOOGLE
# 14  ChIJUQLDPNVgZIgRmyj3WCvY_Sg  GOOGLE
# 15  ChIJu1HcRkZhZIgRwJab053mMeY  GOOGLE
# 16  ChIJ_3hhuz9nZIgROr9342w22Ic  GOOGLE
# 17  ChIJldWEoXdnZIgRYi2eGhA70pM  GOOGLE
# 18  ChIJE-1HDItmZIgRSm3egxKPeck  GOOGLE
#
#                                                 types  user_ratings_total  \
# 0   [grocery_or_supermarket, food, point_of_intere...                 890
# 1   [grocery_or_supermarket, food, point_of_intere...                 512
# 2   [grocery_or_supermarket, supermarket, food, po...                  57
# 3   [grocery_or_supermarket, food, point_of_intere...                 629
# 4   [grocery_or_supermarket, food, point_of_intere...                 106
# 5   [grocery_or_supermarket, food, point_of_intere...                 196
# 6   [grocery_or_supermarket, food, point_of_intere...                  34
# 7   [grocery_or_supermarket, supermarket, food, he...                 156
# 8   [grocery_or_supermarket, supermarket, food, po...                 191
# 9   [grocery_or_supermarket, supermarket, food, po...                 381
# 10  [supermarket, grocery_or_supermarket, food, po...                  45
# 11  [grocery_or_supermarket, food, point_of_intere...                   7
# 12  [supermarket, grocery_or_supermarket, food, po...                   4
# 13  [supermarket, grocery_or_supermarket, food, po...                   0
# 14  [grocery_or_supermarket, food, point_of_intere...                   0
# 15  [grocery_or_supermarket, food, point_of_intere...                  33
# 16  [grocery_or_supermarket, bakery, liquor_store,...                 137
# 17  [grocery_or_supermarket, food, point_of_intere...                  14
# 18  [grocery_or_supermarket, food, point_of_intere...                 424
#
#                                     vicinity permanently_closed
# 0                   800 Monroe St, Nashville                NaN
# 1           2400 Clarksville Pike, Nashville                NaN
# 2                  717 25th Ave N, Nashville                NaN
# 3           3930 Clarksville Pike, Nashville                NaN
# 4                  702 28th Ave N, Nashville                NaN
# 5           3205 Clarksville Pike, Nashville                NaN
# 6           2012 Clarksville Pike, Nashville                NaN
# 7                   1202 Broadway, Nashville                NaN
# 8                   415 Church St, Nashville               True
# 9           3910 Clarksville Pike, Nashville                NaN
# 10              5520 Kentucky Ave, Nashville                NaN
# 11          3620 Buena Vista Pike, Nashville                NaN
# 12              4601 Illinois Ave, Nashville                NaN
# 13                                 Nashville                NaN
# 14            1740 Ed Temple Blvd, Nashville                NaN
# 15             3900 Charlotte Ave, Nashville                NaN
# 16  1010 Dr Martin L King Jr Blvd, Nashville                NaN
# 17               403 W Trinity Ln, Nashville                NaN
# 18                 321 12th Ave S, Nashville                NaN

# %% [markdown]
# results_df['results'][0].values()

# %%
results_nash=pd.DataFrame.from_dict(response_nash['results'])
results_nash
# Out:
#        business_status                                           geometry  \
# 0          OPERATIONAL  {'location': {'lat': 36.1445892, 'lng': -86.81...
# 1          OPERATIONAL  {'location': {'lat': 36.1758569, 'lng': -86.79...
# 2          OPERATIONAL  {'location': {'lat': 36.1853811, 'lng': -86.81...
# 3   CLOSED_TEMPORARILY  {'location': {'lat': 36.1634125, 'lng': -86.77...
# 4          OPERATIONAL  {'location': {'lat': 36.1594967, 'lng': -86.81...
# 5          OPERATIONAL  {'location': {'lat': 36.1844743, 'lng': -86.74...
# 6          OPERATIONAL  {'location': {'lat': 36.1755409, 'lng': -86.75...
# 7          OPERATIONAL  {'location': {'lat': 36.1739207, 'lng': -86.74...
# 8          OPERATIONAL  {'location': {'lat': 36.1318851, 'lng': -86.76...
# 9          OPERATIONAL  {'location': {'lat': 36.15901760000001, 'lng':...
# 10         OPERATIONAL  {'location': {'lat': 36.1832883, 'lng': -86.74...
# 11         OPERATIONAL  {'location': {'lat': 36.1474762, 'lng': -86.75...
# 12         OPERATIONAL  {'location': {'lat': 36.1832368, 'lng': -86.81...
# 13         OPERATIONAL  {'location': {'lat': 36.1567496, 'lng': -86.78...
# 14         OPERATIONAL  {'location': {'lat': 36.1527599, 'lng': -86.78...
# 15         OPERATIONAL  {'location': {'lat': 36.1329002, 'lng': -86.78...
# 16         OPERATIONAL  {'location': {'lat': 36.1632696, 'lng': -86.78...
# 17         OPERATIONAL  {'location': {'lat': 36.1549405, 'lng': -86.77...
# 18         OPERATIONAL  {'location': {'lat': 36.1877595, 'lng': -86.77...
# 19         OPERATIONAL  {'location': {'lat': 36.1318231, 'lng': -86.75...
#
#                                                  icon  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                    name        opening_hours  \
# 0                         Piggly Wiggly   {'open_now': True}
# 1                                Kroger   {'open_now': True}
# 2                            Save A Lot  {'open_now': False}
# 3                H.G. Hill Urban Market                  NaN
# 4                Resha's Bi-Rite Market  {'open_now': False}
# 5                                Kroger   {'open_now': True}
# 6                 Weiss Drive-In Market   {'open_now': True}
# 7                          4 Way Market   {'open_now': True}
# 8                      Wedgehill Market  {'open_now': False}
# 9                        Swett's Market   {'open_now': True}
# 10                                 ALDI  {'open_now': False}
# 11                               Z Mart                  NaN
# 12                         SAM'S MARKET  {'open_now': False}
# 13                   Whole Foods Market  {'open_now': False}
# 14          The Turnip Truck Urban Fare  {'open_now': False}
# 15                            The Store  {'open_now': False}
# 16  Publix Super Market at Capitol View   {'open_now': True}
# 17                DOWNTOWN FRESH MARKET  {'open_now': False}
# 18                          Star Market   {'open_now': True}
# 19          U.S.Discount Tobacco & Beer   {'open_now': True}
#
#                                                photos  \
# 0   [{'height': 2160, 'html_attributions': ['<a hr...
# 1   [{'height': 1280, 'html_attributions': ['<a hr...
# 2   [{'height': 1440, 'html_attributions': ['<a hr...
# 3   [{'height': 2448, 'html_attributions': ['<a hr...
# 4                                                 NaN
# 5   [{'height': 2201, 'html_attributions': ['<a hr...
# 6   [{'height': 3024, 'html_attributions': ['<a hr...
# 7   [{'height': 3024, 'html_attributions': ['<a hr...
# 8   [{'height': 2988, 'html_attributions': ['<a hr...
# 9   [{'height': 1440, 'html_attributions': ['<a hr...
# 10  [{'height': 3024, 'html_attributions': ['<a hr...
# 11                                                NaN
# 12  [{'height': 2448, 'html_attributions': ['<a hr...
# 13  [{'height': 3801, 'html_attributions': ['<a hr...
# 14  [{'height': 4032, 'html_attributions': ['<a hr...
# 15                                                NaN
# 16  [{'height': 3024, 'html_attributions': ['<a hr...
# 17  [{'height': 4032, 'html_attributions': ['<a hr...
# 18                                                NaN
# 19  [{'height': 3264, 'html_attributions': ['<a hr...
#
#                        place_id  \
# 0   ChIJF_mw3q9mZIgRQdSpspW80MQ
# 1   ChIJ0f1NweJmZIgRYnc_3nqNyag
# 2   ChIJCTHj7C5nZIgR8KzLicfUjkw
# 3   ChIJPStOVVhmZIgRso0FW3wu3Hw
# 4   ChIJ4ZED5shmZIgRz1kBNC9ENYg
# 5   ChIJCyiJ2tBnZIgReYaDDx5KLEM
# 6   ChIJrVUAszRmZIgR_uKBTX5M2yo
# 7   ChIJCXauaCtmZIgRYZpTghT1TBE
# 8   ChIJmyJmjthlZIgR_8KhYLlhP0E
# 9   ChIJ4Rt8tstmZIgR8DW1VbfQCMw
# 10  ChIJgRoqI9FnZIgRK-JHS7MI0qE
# 11  ChIJsWvqChNmZIgR_T0Pp_k_TrM
# 12  ChIJGVsGTi9nZIgRAa6Iee-oLMQ
# 13  ChIJY1hOx5hnZIgRaU2PoQEx2R0
# 14  ChIJE-1HDItmZIgRSm3egxKPeck
# 15  ChIJyzYwFj5lZIgRFGB0hYpHoQA
# 16  ChIJ_3hhuz9nZIgROr9342w22Ic
# 17  ChIJuTn3A-tnZIgREs7ZhppWRb0
# 18  ChIJORilXaVnZIgRxP_1G83ELjk
# 19  ChIJ93X87-FlZIgRo71ee_0_6rY
#
#                                             plus_code  price_level  rating  \
# 0   {'compound_code': '45VP+RH Nashville, Tennesse...          2.0     4.0
# 1   {'compound_code': '56G4+87 Nashville, Tennesse...          2.0     3.7
# 2   {'compound_code': '55PM+5J Nashville, Tennesse...          NaN     4.0
# 3   {'compound_code': '567C+96 Nashville, Tennesse...          NaN     4.2
# 4   {'compound_code': '555P+Q9 Nashville, Tennesse...          NaN     3.8
# 5   {'compound_code': '57M3+Q7 Nashville, Tennesse...          2.0     3.7
# 6   {'compound_code': '56GV+63 Nashville, Tennesse...          NaN     4.1
# 7   {'compound_code': '57F3+HJ Nashville, Tennesse...          NaN     4.3
# 8   {'compound_code': '46JJ+QF Nashville, Tennesse...          NaN     4.6
# 9   {'compound_code': '555J+JP Nashville, Tennesse...          NaN     3.8
# 10  {'compound_code': '57M2+8X Nashville, Tennesse...          1.0     4.5
# 11  {'compound_code': '46WR+X7 Nashville, Tennesse...          NaN     3.5
# 12  {'compound_code': '55MP+7X Nashville, Tennesse...          NaN     4.5
# 13  {'compound_code': '5646+MQ Nashville, Tennesse...          NaN     4.6
# 14  {'compound_code': '5637+4R Nashville, Tennesse...          NaN     4.5
# 15  {'compound_code': '46M6+5G Nashville, Tennesse...          NaN     5.0
# 16  {'compound_code': '5676+84 Nashville, Tennesse...          NaN     4.4
# 17  {'compound_code': '563G+XJ Nashville, Tennesse...          NaN     5.0
# 18  {'compound_code': '56QG+4Q Nashville, Tennesse...          NaN     0.0
# 19  {'compound_code': '46JV+P3 Nashville, Tennesse...          NaN     4.2
#
#                       reference   scope  \
# 0   ChIJF_mw3q9mZIgRQdSpspW80MQ  GOOGLE
# 1   ChIJ0f1NweJmZIgRYnc_3nqNyag  GOOGLE
# 2   ChIJCTHj7C5nZIgR8KzLicfUjkw  GOOGLE
# 3   ChIJPStOVVhmZIgRso0FW3wu3Hw  GOOGLE
# 4   ChIJ4ZED5shmZIgRz1kBNC9ENYg  GOOGLE
# 5   ChIJCyiJ2tBnZIgReYaDDx5KLEM  GOOGLE
# 6   ChIJrVUAszRmZIgR_uKBTX5M2yo  GOOGLE
# 7   ChIJCXauaCtmZIgRYZpTghT1TBE  GOOGLE
# 8   ChIJmyJmjthlZIgR_8KhYLlhP0E  GOOGLE
# 9   ChIJ4Rt8tstmZIgR8DW1VbfQCMw  GOOGLE
# 10  ChIJgRoqI9FnZIgRK-JHS7MI0qE  GOOGLE
# 11  ChIJsWvqChNmZIgR_T0Pp_k_TrM  GOOGLE
# 12  ChIJGVsGTi9nZIgRAa6Iee-oLMQ  GOOGLE
# 13  ChIJY1hOx5hnZIgRaU2PoQEx2R0  GOOGLE
# 14  ChIJE-1HDItmZIgRSm3egxKPeck  GOOGLE
# 15  ChIJyzYwFj5lZIgRFGB0hYpHoQA  GOOGLE
# 16  ChIJ_3hhuz9nZIgROr9342w22Ic  GOOGLE
# 17  ChIJuTn3A-tnZIgREs7ZhppWRb0  GOOGLE
# 18  ChIJORilXaVnZIgRxP_1G83ELjk  GOOGLE
# 19  ChIJ93X87-FlZIgRo71ee_0_6rY  GOOGLE
#
#                                                 types  user_ratings_total  \
# 0   [grocery_or_supermarket, supermarket, food, po...                 361
# 1   [grocery_or_supermarket, food, point_of_intere...                 890
# 2   [grocery_or_supermarket, food, point_of_intere...                 512
# 3   [grocery_or_supermarket, supermarket, food, po...                 191
# 4   [grocery_or_supermarket, supermarket, food, po...                  57
# 5   [grocery_or_supermarket, food, point_of_intere...                 687
# 6   [grocery_or_supermarket, food, point_of_intere...                  14
# 7   [grocery_or_supermarket, supermarket, food, po...                  72
# 8   [grocery_or_supermarket, supermarket, food, po...                  71
# 9   [grocery_or_supermarket, food, point_of_intere...                 106
# 10  [grocery_or_supermarket, supermarket, food, po...                 631
# 11  [grocery_or_supermarket, food, point_of_intere...                   6
# 12  [grocery_or_supermarket, food, point_of_intere...                  34
# 13  [grocery_or_supermarket, supermarket, food, he...                 156
# 14  [grocery_or_supermarket, food, point_of_intere...                 424
# 15  [grocery_or_supermarket, food, point_of_intere...                  12
# 16  [grocery_or_supermarket, bakery, liquor_store,...                 137
# 17  [grocery_or_supermarket, convenience_store, fo...                   1
# 18  [convenience_store, grocery_or_supermarket, fo...                   0
# 19  [grocery_or_supermarket, food, point_of_intere...                  19
#
#                                     vicinity permanently_closed
# 0               2900 West End Ave, Nashville                NaN
# 1                   800 Monroe St, Nashville                NaN
# 2           2400 Clarksville Pike, Nashville                NaN
# 3                   415 Church St, Nashville               True
# 4                  717 25th Ave N, Nashville                NaN
# 5                711 Gallatin Ave, Nashville                NaN
# 6                     826 Main St, Nashville                NaN
# 7              1401 Fatherland St, Nashville                NaN
# 8                  600 Benton Ave, Nashville                NaN
# 9                  702 28th Ave N, Nashville                NaN
# 10               615 Gallatin Ave, Nashville                NaN
# 11               141 Lafayette St, Nashville                NaN
# 12          2012 Clarksville Pike, Nashville                NaN
# 13                  1202 Broadway, Nashville                NaN
# 14                 321 12th Ave S, Nashville                NaN
# 15                2009 12th Ave S, Nashville                NaN
# 16  1010 Dr Martin L King Jr Blvd, Nashville                NaN
# 17                  531 4th Ave S, Nashville                NaN
# 18             903 Dickerson Pike, Nashville                NaN
# 19          1997 Nolensville Pike, Nashville                NaN

# %%
results_df
# Out:
# [[{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1844743, 'lng': -86.74677849999999},
#     'viewport': {'northeast': {'lat': 36.18570212989272,
#       'lng': -86.74576282010727},
#      'southwest': {'lat': 36.18300247010728, 'lng': -86.74846247989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2201,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113827070569302562718">Andrew L</a>'],
#      'photo_reference': 'ATtYBwLVE6yjXjBcWgDrWikdOYopMCPJz52H95pk3dj04lVEaIbdFBMekHVzKlAWZa2p-JmBFlWGBB5nElZpGAKPnEFZobOnBo3dzLHlSG5Sk7K2h8c_9IPkxjwERRWZnaozGjBP-Id4lG4FtNL-hLEzz7r_3fy6CU9WFwDWgjsouuGbpi2S',
#      'width': 7268}],
#    'place_id': 'ChIJCyiJ2tBnZIgReYaDDx5KLEM',
#    'plus_code': {'compound_code': '57M3+Q7 Nashville, Tennessee',
#     'global_code': '868M57M3+Q7'},
#    'price_level': 2,
#    'rating': 3.7,
#    'reference': 'ChIJCyiJ2tBnZIgReYaDDx5KLEM',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 687,
#    'vicinity': '711 Gallatin Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.2101188, 'lng': -86.7324397},
#     'viewport': {'northeast': {'lat': 36.21148802989272,
#       'lng': -86.73108607010728},
#      'southwest': {'lat': 36.20878837010728, 'lng': -86.73378572989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3096,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116765434657480531728">A Google User</a>'],
#      'photo_reference': 'ATtYBwL71NSAMKGxAECMz-CGfLCqpL2k0W_NHbM8xloN9sc2yVBQ8bA8iQDMXASzPZGqdiixTYLP5ZJmYKL_DYK2COSLAOsB7DveQtDpiEQTAt2Zek4qM9Idwgs13bYD5OSpQyK1SOU8pjZAfingPc_k8M_h4HaahAIR30hLaz6DMKx0Btii',
#      'width': 4128}],
#    'place_id': 'ChIJZyYDJgVoZIgRp_UaluUQWjY',
#    'plus_code': {'compound_code': '6769+22 Nashville, Tennessee',
#     'global_code': '868M6769+22'},
#    'price_level': 2,
#    'rating': 3.9,
#    'reference': 'ChIJZyYDJgVoZIgRp_UaluUQWjY',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 893,
#    'vicinity': '3410 Gallatin Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1755409, 'lng': -86.75727979999999},
#     'viewport': {'northeast': {'lat': 36.17693902989273,
#       'lng': -86.75582627010729},
#      'southwest': {'lat': 36.17423937010728, 'lng': -86.75852592989274}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Weiss Drive-In Market',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115968242670899721832">Andrea</a>'],
#      'photo_reference': 'ATtYBwKMM5JxpGuBgiV07dvqShz1C-O-whjL7dx2tS-Kckuy8J_VFb6yjRocheJ7U-3-PiScd8lEds28_ieLl98xbooPisFWw91_vjArwzXYGOGw4AVQQyC9gBOUflkv3pcPdLzN9wSpvrPv2sLATHccdUMHzgGNKsPPKYfYCIHejQmxsRHZ',
#      'width': 4032}],
#    'place_id': 'ChIJrVUAszRmZIgR_uKBTX5M2yo',
#    'plus_code': {'compound_code': '56GV+63 Nashville, Tennessee',
#     'global_code': '868M56GV+63'},
#    'rating': 4.1,
#    'reference': 'ChIJrVUAszRmZIgR_uKBTX5M2yo',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 14,
#    'vicinity': '826 Main St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.2077791, 'lng': -86.76702279999999},
#     'viewport': {'northeast': {'lat': 36.20899562989273,
#       'lng': -86.76577952010727},
#      'southwest': {'lat': 36.20629597010728, 'lng': -86.76847917989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Piggly Wiggly',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2340,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109400472957608256078">Caleb Hendon</a>'],
#      'photo_reference': 'ATtYBwJ29LfDR1swwm0rdciKVvJ9EFfhEeVq9RZWuAVYeRiz3yGT3wH1EK1rpuP90IRqnUzfoUK_mIeSJ2wOlHzwU5lL1EYKwZZoVs8b1EvZ18A2u5a5T_3opteolaKqn-CrINom3BrNoQvkyfj_F5eG5An2y3EeTZJELpkRuWMr-KaBB_ag',
#      'width': 4160}],
#    'place_id': 'ChIJM3OiQKVnZIgRxiZuRvmGZxg',
#    'plus_code': {'compound_code': '665M+45 Nashville, Tennessee',
#     'global_code': '868M665M+45'},
#    'price_level': 2,
#    'rating': 4,
#    'reference': 'ChIJM3OiQKVnZIgRxiZuRvmGZxg',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 533,
#    'vicinity': '2317 Dickerson Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1739207, 'lng': -86.7459911},
#     'viewport': {'northeast': {'lat': 36.17517912989273,
#       'lng': -86.74465462010728},
#      'southwest': {'lat': 36.17247947010728, 'lng': -86.74735427989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': '4 Way Market',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106875532012586085102">Massbaum</a>'],
#      'photo_reference': 'ATtYBwK7a2sS81TpmN4XIjC95lyaoW8v8VCsx4OoFVDM7zH9E99qy6ZOC6Mvd15GRyIZKE8K4n2sa-KmU77b0z74fnkt-D9HO0ajF7nzI6Lh9hwsmjVzHS_WkhPiccVqZeZBAuBYfiXXs1Ma1vDXsgg_WW_UMCTAIzucJpkZWXbNbfUUev0n',
#      'width': 4032}],
#    'place_id': 'ChIJCXauaCtmZIgRYZpTghT1TBE',
#    'plus_code': {'compound_code': '57F3+HJ Nashville, Tennessee',
#     'global_code': '868M57F3+HJ'},
#    'rating': 4.3,
#    'reference': 'ChIJCXauaCtmZIgRYZpTghT1TBE',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 72,
#    'vicinity': '1401 Fatherland St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1832883, 'lng': -86.7475518},
#     'viewport': {'northeast': {'lat': 36.18446342989272,
#       'lng': -86.74629432010728},
#      'southwest': {'lat': 36.18176377010728, 'lng': -86.74899397989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'ALDI',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107053115772497782619">A Google User</a>'],
#      'photo_reference': 'ATtYBwJtte70Ub97s3QlmmATS_WEFBlAYiHCjsMexP4ztHrS6kqdpkWFYJuwygZLxzK5lsbbHEOBeZYquWCD0mPlZdpGt88QgwVgOHE01X139rIhbIWKxSu13NbgOGnCj_onqCAUalhEo0ZzAVsKcQr1cCi_VYwMTAuj7LJQ6PsNSOWU_p0_',
#      'width': 4032}],
#    'place_id': 'ChIJgRoqI9FnZIgRK-JHS7MI0qE',
#    'plus_code': {'compound_code': '57M2+8X Nashville, Tennessee',
#     'global_code': '868M57M2+8X'},
#    'price_level': 1,
#    'rating': 4.5,
#    'reference': 'ChIJgRoqI9FnZIgRK-JHS7MI0qE',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 631,
#    'vicinity': '615 Gallatin Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.2022406, 'lng': -86.7389614},
#     'viewport': {'northeast': {'lat': 36.20367657989272,
#       'lng': -86.73762212010728},
#      'southwest': {'lat': 36.20097692010728, 'lng': -86.74032177989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "Litton's Corner Market",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3492,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103498631302409342999">Michael Tims</a>'],
#      'photo_reference': 'ATtYBwLUU4mOhBjoyZSutQOvLVSSrpuizJW8d-L-SyNjmeZQ-TCxBTqi_eyFocVhB9I2Jwic-GrMQ9nspVD4rGp48EMZPXLhvsmpg4tTrFfzdJxCMqjMUqz6nkByyaZ6uIJl97m2DLsFf-XSJK9chnt1kv-RUs_ZqOi4U18HQC5f8wZHmQnS',
#      'width': 4656}],
#    'place_id': 'ChIJa55T0QtoZIgRtVCd8YGpy8I',
#    'plus_code': {'compound_code': '6726+VC Nashville, Tennessee',
#     'global_code': '868M6726+VC'},
#    'rating': 4.1,
#    'reference': 'ChIJa55T0QtoZIgRtVCd8YGpy8I',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 29,
#    'vicinity': '2830 Gallatin Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.2012332, 'lng': -86.7581587},
#     'viewport': {'northeast': {'lat': 36.20259067989272,
#       'lng': -86.75687717010727},
#      'southwest': {'lat': 36.19989102010728, 'lng': -86.75957682989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Jammers Market',
#    'photos': [{'height': 960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113157421530263330371">Crafty Mama</a>'],
#      'photo_reference': 'ATtYBwKZhh1RXe7cglhpN9OdJ52lAWIIqt42hy2g1UhI1EdldZE7BHiUFqwEo2t8h11iYdDaa64Bks58ph1s-dJuPO6_t4joYPoxyRKd1UTz5iW06Sm1fSeNxs1pP1vA-QMa8kJ_niLB-xSFmoPqi-BwHbRFqdHhVXgVwCwwyMDxV1mOBwUt',
#      'width': 1280}],
#    'place_id': 'ChIJiaIWuetnZIgR7Riz5lPYIYI',
#    'plus_code': {'compound_code': '662R+FP Nashville, Tennessee',
#     'global_code': '868M662R+FP'},
#    'rating': 4.5,
#    'reference': 'ChIJiaIWuetnZIgR7Riz5lPYIYI',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 24,
#    'vicinity': '1519 Jones Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1999223, 'lng': -86.7696038},
#     'viewport': {'northeast': {'lat': 36.20131027989272,
#       'lng': -86.76843522010728},
#      'southwest': {'lat': 36.19861062010728, 'lng': -86.77113487989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Uptownfruitmarket',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118115938674938214568">Uptownfruitmarket</a>'],
#      'photo_reference': 'ATtYBwKujYk1qYaCmO3879FyF9ddtUGjULiNTtdu924sDr3NE2SLcZWH2AJTnUmrILJ0sJMczUdFWaslRjR7D65m7OwVuUSh4BWnEVtUlVWCOCL7yKmj4kuCX9hGP1rvTsMX5NFlemgws7jl25a3zfjFZsk5c3_V10MGt6rUIU3oes9FXV6n',
#      'width': 1080}],
#    'place_id': 'ChIJV_n1sZdnZIgRCK3MI0EMuQY',
#    'plus_code': {'compound_code': '56XJ+X5 Nashville, Tennessee',
#     'global_code': '868M56XJ+X5'},
#    'rating': 4.7,
#    'reference': 'ChIJV_n1sZdnZIgRCK3MI0EMuQY',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'finance',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 32,
#    'vicinity': '1431 Dickerson Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1877595, 'lng': -86.7730452},
#     'viewport': {'northeast': {'lat': 36.18911957989271,
#       'lng': -86.77182812010729},
#      'southwest': {'lat': 36.18641992010726, 'lng': -86.77452777989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Star Market',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJORilXaVnZIgRxP_1G83ELjk',
#    'plus_code': {'compound_code': '56QG+4Q Nashville, Tennessee',
#     'global_code': '868M56QG+4Q'},
#    'rating': 0,
#    'reference': 'ChIJORilXaVnZIgRxP_1G83ELjk',
#    'scope': 'GOOGLE',
#    'types': ['convenience_store',
#     'grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': '903 Dickerson Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.21165560000001, 'lng': -86.7649471},
#     'viewport': {'northeast': {'lat': 36.21297337989272,
#       'lng': -86.76362712010727},
#      'southwest': {'lat': 36.21027372010727, 'lng': -86.76632677989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Danial Market',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110172055445515908390">theresa deese</a>'],
#      'photo_reference': 'ATtYBwIQu2MeHg3NDX-ycFpegvrnq58gYa0vMVxd4uluGqXqF8faIENi4_Re25RyLnpZUtlkaMKoEu9EA2qQV8m9T0zONVOvJakziF2RMijAD2slhvkLP75hgUgK9PaXVxHOKJzJOJ42QiMmIGwEUV2GcpD5ur13AKTaMtiscMmrnYgG-5mj',
#      'width': 3264}],
#    'place_id': 'ChIJqxrsTYxnZIgR0IK9EdFsq1Q',
#    'plus_code': {'compound_code': '666P+M2 Nashville, Tennessee',
#     'global_code': '868M666P+M2'},
#    'rating': 4.6,
#    'reference': 'ChIJqxrsTYxnZIgR0IK9EdFsq1Q',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 19,
#    'vicinity': 'Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.2054457, 'lng': -86.7655468},
#     'viewport': {'northeast': {'lat': 36.20680752989273,
#       'lng': -86.76432932010728},
#      'southwest': {'lat': 36.20410787010728, 'lng': -86.76702897989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Trinity Lane Market',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3096,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104365275674933371481">Trenee&#39; Williamson</a>'],
#      'photo_reference': 'ATtYBwKADogA17FIXRS8egLQxIuEKNY4KDt-9d5s1PVwILSXc9kJ8FBFI_7reuZ0ciEI-kdJEuLgEn3aqrZqs0bgOodv7J0a91UxoZBMVB9Ru8QPCF2kKYKFU4uWT9vkkUMF8BAGiGiycpLmP8Nxm4W9Sic9i-e4H0i6jaRacgIGQSgxkptD',
#      'width': 4128}],
#    'place_id': 'ChIJ-bdHyJNnZIgRFrGMIosoZLo',
#    'plus_code': {'compound_code': '664M+5Q Nashville, Tennessee',
#     'global_code': '868M664M+5Q'},
#    'rating': 3.6,
#    'reference': 'ChIJ-bdHyJNnZIgRFrGMIosoZLo',
#    'scope': 'GOOGLE',
#    'types': ['convenience_store',
#     'supermarket',
#     'grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 21,
#    'vicinity': '1905 Meridian St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.20863629999999, 'lng': -86.7677653},
#     'viewport': {'northeast': {'lat': 36.20989732989272,
#       'lng': -86.76641522010728},
#      'southwest': {'lat': 36.20719767010728, 'lng': -86.76911487989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Garibaldi Market',
#    'place_id': 'ChIJo9KF4ZFnZIgRSwZcFtFegh4',
#    'plus_code': {'compound_code': '665J+FV Nashville, Tennessee',
#     'global_code': '868M665J+FV'},
#    'rating': 4.8,
#    'reference': 'ChIJo9KF4ZFnZIgRSwZcFtFegh4',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': '2402 Dickerson Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1765293, 'lng': -86.7751309},
#     'viewport': {'northeast': {'lat': 36.17791167989272,
#       'lng': -86.77373622010727},
#      'southwest': {'lat': 36.17521202010727, 'lng': -86.77643587989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "Larry's Quick Stop",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100091017896489400911">Beth1014</a>'],
#      'photo_reference': 'ATtYBwIRsXWKHz5l7W-DaAkijTrMerScVXtGRM1vCkg4SFkg6CqTOuk2Pv08H_xhfnOhKBhqxTF0ownnr3AhabE62w4O1-H6155oH0rDzhVTBO3oZW5XDAY1YvxEhpParUvZH_Jq8qGCwf-x0Pef_Ze4Pa4rbcW3-ZwfVnanzfILmKvaPpWO',
#      'width': 4160}],
#    'place_id': 'ChIJXyC3zaxnZIgRfcdTJ8AjYCQ',
#    'plus_code': {'compound_code': '56GF+JW Nashville, Tennessee',
#     'global_code': '868M56GF+JW'},
#    'rating': 3,
#    'reference': 'ChIJXyC3zaxnZIgRfcdTJ8AjYCQ',
#    'scope': 'GOOGLE',
#    'types': ['convenience_store',
#     'gas_station',
#     'grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 10,
#    'vicinity': '240 N 1st St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1445892, 'lng': -86.8136},
#     'viewport': {'northeast': {'lat': 36.14593902989272,
#       'lng': -86.81225017010728},
#      'southwest': {'lat': 36.14323937010727, 'lng': -86.81494982989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Piggly Wiggly',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113359179597487495544">Jack Warman</a>'],
#      'photo_reference': 'ATtYBwLWtIYKKM6DN6QB8jQhK86pMQBYR8hT_pt8UwJS_1-zHYrU_0jnxX_It0Ejw5yn_zBY_skUC2gaMyEkJwNW3t5a-poFkwDZQw18xnTA0y1P1AVXFMylX1NCcKZ-E3CwKd8vmrt9-vOB8M-L4iTVEZkcWIYzAUXednOiwxl-PapbI5-p',
#      'width': 3840}],
#    'place_id': 'ChIJF_mw3q9mZIgRQdSpspW80MQ',
#    'plus_code': {'compound_code': '45VP+RH Nashville, Tennessee',
#     'global_code': '868M45VP+RH'},
#    'price_level': 2,
#    'rating': 4,
#    'reference': 'ChIJF_mw3q9mZIgRQdSpspW80MQ',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 361,
#    'vicinity': '2900 West End Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1758569, 'lng': -86.79427369999999},
#     'viewport': {'northeast': {'lat': 36.17703907989273,
#       'lng': -86.79283387010727},
#      'southwest': {'lat': 36.17433942010728, 'lng': -86.79553352989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1280,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110336675155918874463">Kroger</a>'],
#      'photo_reference': 'ATtYBwLIe4no7G8NjcmXsL7uyE0fYUiUSh-w3E1c9DOrA72jQeo0FcHhYTRqM-tPJDzMd545qriXqOOLsngHkvba3WsBLKcgTSZ8e2Gkjp5pbQDkY4mSfdn03MJnPkhVzygnLeW44j8a0UaoT9Rz2Ufq1E1hlsE1vdPc1AoQ8_cI1ckrO6fy',
#      'width': 1920}],
#    'place_id': 'ChIJ0f1NweJmZIgRYnc_3nqNyag',
#    'plus_code': {'compound_code': '56G4+87 Nashville, Tennessee',
#     'global_code': '868M56G4+87'},
#    'price_level': 2,
#    'rating': 3.7,
#    'reference': 'ChIJ0f1NweJmZIgRYnc_3nqNyag',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 890,
#    'vicinity': '800 Monroe St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1853811, 'lng': -86.8159932},
#     'viewport': {'northeast': {'lat': 36.18663382989272,
#       'lng': -86.81489022010727},
#      'southwest': {'lat': 36.18393417010728, 'lng': -86.81758987989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Save A Lot',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1440,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111089389699251425402">A Google User</a>'],
#      'photo_reference': 'ATtYBwJEJe3cYVKvJYmB14xV2U4vDSNn4Yo9EXd4lHOx36DEMD5kAaeVeVK8mDD5VFlHhz-6QpaOieOveIvDOegIeg12V6SAq9QAA4muYZWTePj6nUqBxvuQ9HjXmDNhOAjANpvsUsKwnb16gF7fLUatQo9ldVw0u4K39Z_xvTjCN-3vQLEE',
#      'width': 2560}],
#    'place_id': 'ChIJCTHj7C5nZIgR8KzLicfUjkw',
#    'plus_code': {'compound_code': '55PM+5J Nashville, Tennessee',
#     'global_code': '868M55PM+5J'},
#    'rating': 4,
#    'reference': 'ChIJCTHj7C5nZIgR8KzLicfUjkw',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 512,
#    'vicinity': '2400 Clarksville Pike, Nashville'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 36.1634125, 'lng': -86.779421},
#     'viewport': {'northeast': {'lat': 36.16473492989273,
#       'lng': -86.77817392010726},
#      'southwest': {'lat': 36.16203527010729, 'lng': -86.78087357989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'H.G. Hill Urban Market',
#    'permanently_closed': True,
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106519442576080453760">A Google User</a>'],
#      'photo_reference': 'ATtYBwIE3GD2-XOqfnuAUPS9nt0QKUEazR7pAXTl0u9dkmRDWn8T--5J4tc_ncJaD9AMwz6Ayn0h1MT2AHjCeaheORNKfFjzCMe0_WY4jpZ_qi1ZPCqsMBSkkrPqa1A6fuydvTVoOLbwVTLOHdgwLFxd3YynZoIR-kwhfrsTfUECB0PdeiAF',
#      'width': 3264}],
#    'place_id': 'ChIJPStOVVhmZIgRso0FW3wu3Hw',
#    'plus_code': {'compound_code': '567C+96 Nashville, Tennessee',
#     'global_code': '868M567C+96'},
#    'rating': 4.2,
#    'reference': 'ChIJPStOVVhmZIgRso0FW3wu3Hw',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 191,
#    'vicinity': '415 Church St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1594967, 'lng': -86.8140176},
#     'viewport': {'northeast': {'lat': 36.16086467989272,
#       'lng': -86.81256562010728},
#      'southwest': {'lat': 36.15816502010728, 'lng': -86.81526527989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "Resha's Bi-Rite Market",
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJ4ZED5shmZIgRz1kBNC9ENYg',
#    'plus_code': {'compound_code': '555P+Q9 Nashville, Tennessee',
#     'global_code': '868M555P+Q9'},
#    'rating': 3.8,
#    'reference': 'ChIJ4ZED5shmZIgRz1kBNC9ENYg',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 57,
#    'vicinity': '717 25th Ave N, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1844743, 'lng': -86.74677849999999},
#     'viewport': {'northeast': {'lat': 36.18570212989272,
#       'lng': -86.74576282010727},
#      'southwest': {'lat': 36.18300247010728, 'lng': -86.74846247989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2201,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113827070569302562718">Andrew L</a>'],
#      'photo_reference': 'ATtYBwKYjyKn2JxyyZoMakHaqzXZBHigISD95bREyUQ9hAdy9bRs39gg50pffU0N9ZghvBIOzqzwzjw7uxoylm8hYw1M7omlTmD2pNGMDUDtBGf7D0UDZa_5UvCFXEL6Zi0xF3wCrG_J8nB66MBIJNJqHPT7-EA-V5-I2dn7f_WSdcuys81x',
#      'width': 7268}],
#    'place_id': 'ChIJCyiJ2tBnZIgReYaDDx5KLEM',
#    'plus_code': {'compound_code': '57M3+Q7 Nashville, Tennessee',
#     'global_code': '868M57M3+Q7'},
#    'price_level': 2,
#    'rating': 3.7,
#    'reference': 'ChIJCyiJ2tBnZIgReYaDDx5KLEM',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 687,
#    'vicinity': '711 Gallatin Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1755409, 'lng': -86.75727979999999},
#     'viewport': {'northeast': {'lat': 36.17693902989273,
#       'lng': -86.75582627010729},
#      'southwest': {'lat': 36.17423937010728, 'lng': -86.75852592989274}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Weiss Drive-In Market',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115968242670899721832">Andrea</a>'],
#      'photo_reference': 'ATtYBwILEvpLa5jmHBvKoXef9GDL5EXdZrGFMcJstuv63kHgrdaNikfDdTTiGrnJcg_f4QiYrAERkXBjy23mL6SecE0c1ne7YcKuD-4yUZWqp7zbGG0NkHL7V7X3pqxdeDsm6nIOWTgmGTmbkCzjZuEQOF3560OhGki3cpCjoYiOgqC1LNqT',
#      'width': 4032}],
#    'place_id': 'ChIJrVUAszRmZIgR_uKBTX5M2yo',
#    'plus_code': {'compound_code': '56GV+63 Nashville, Tennessee',
#     'global_code': '868M56GV+63'},
#    'rating': 4.1,
#    'reference': 'ChIJrVUAszRmZIgR_uKBTX5M2yo',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 14,
#    'vicinity': '826 Main St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1739207, 'lng': -86.7459911},
#     'viewport': {'northeast': {'lat': 36.17517912989273,
#       'lng': -86.74465462010728},
#      'southwest': {'lat': 36.17247947010728, 'lng': -86.74735427989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': '4 Way Market',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106875532012586085102">Massbaum</a>'],
#      'photo_reference': 'ATtYBwJRdRjP0Hqw5PU-2oHfUcQ1ywHJmoS6IwwI7aq_PGIkE5walZuiFLwP8e4HftEwFDYRcFF1lWMawDDCfcC_S1qqJOHCYCR2SdNNDlMz7jqjffmkt4qJ-5FUJGgYlEAt3UDB4HeQko6AR7DIhIFOpJgVGD5VBStJUvysTdJpEzMOKJ94',
#      'width': 4032}],
#    'place_id': 'ChIJCXauaCtmZIgRYZpTghT1TBE',
#    'plus_code': {'compound_code': '57F3+HJ Nashville, Tennessee',
#     'global_code': '868M57F3+HJ'},
#    'rating': 4.3,
#    'reference': 'ChIJCXauaCtmZIgRYZpTghT1TBE',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 72,
#    'vicinity': '1401 Fatherland St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1318851, 'lng': -86.76877499999999},
#     'viewport': {'northeast': {'lat': 36.13314642989272,
#       'lng': -86.76743662010726},
#      'southwest': {'lat': 36.13044677010728, 'lng': -86.77013627989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Wedgehill Market',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115761387019637953020">Michael Orosco</a>'],
#      'photo_reference': 'ATtYBwIaC4eGHGrJd71SlcVGtlO4c_Q7HJo7cGk62H4aKa_TxKq9c_WCIY1-8ME2-t5KSTugHodOYjhZYS6r7cRjLKbbhgGb-j_yGYDIoG7AaxU5V8NoHQSy0NNB-aXUggwAIeOxntNH71tI5c5f-4w_ImeE4uz2ByxR320pvPVNebfepWOg',
#      'width': 5312}],
#    'place_id': 'ChIJmyJmjthlZIgR_8KhYLlhP0E',
#    'plus_code': {'compound_code': '46JJ+QF Nashville, Tennessee',
#     'global_code': '868M46JJ+QF'},
#    'rating': 4.6,
#    'reference': 'ChIJmyJmjthlZIgR_8KhYLlhP0E',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 71,
#    'vicinity': '600 Benton Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.15901760000001, 'lng': -86.8182096},
#     'viewport': {'northeast': {'lat': 36.16033492989273,
#       'lng': -86.81705327010728},
#      'southwest': {'lat': 36.15763527010728, 'lng': -86.81975292989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "Swett's Market",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1440,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106731321516876371408">A Google User</a>'],
#      'photo_reference': 'ATtYBwKS135Zu5EBA2klFW6kI7yVRajfsqZ7njbf8R5AttC99ZdRv-D1OGZDxcTBQf2Cn4snMId8Inz8dvZCvXjItc964hNg8TPbq2ok11WFTIxor0O4rl_RJd6DfY6sAe038n4MN97dWPPLOlLeSCUCIf0rpW_ruGQynM0oMdg-jN3VlE1e',
#      'width': 2560}],
#    'place_id': 'ChIJ4Rt8tstmZIgR8DW1VbfQCMw',
#    'plus_code': {'compound_code': '555J+JP Nashville, Tennessee',
#     'global_code': '868M555J+JP'},
#    'rating': 3.8,
#    'reference': 'ChIJ4Rt8tstmZIgR8DW1VbfQCMw',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 106,
#    'vicinity': '702 28th Ave N, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1832883, 'lng': -86.7475518},
#     'viewport': {'northeast': {'lat': 36.18446342989272,
#       'lng': -86.74629432010728},
#      'southwest': {'lat': 36.18176377010728, 'lng': -86.74899397989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'ALDI',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107053115772497782619">A Google User</a>'],
#      'photo_reference': 'ATtYBwLIK4ZkD6Gtd91CCG75qM-b3lYA7T8ye4LebbCwZ3L7diKDAGah2swlJh-3q_At6j-usLV8YBLg2Xrcj7vVVIvTM7pEvCXV1BsE4esnhCPQQVZmMy_oFCV_WGzCMaqlmfH1mpx963BqErLS4jbEnzCHypJuuABFwVKIg47QB2PfhR4T',
#      'width': 4032}],
#    'place_id': 'ChIJgRoqI9FnZIgRK-JHS7MI0qE',
#    'plus_code': {'compound_code': '57M2+8X Nashville, Tennessee',
#     'global_code': '868M57M2+8X'},
#    'price_level': 1,
#    'rating': 4.5,
#    'reference': 'ChIJgRoqI9FnZIgRK-JHS7MI0qE',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 631,
#    'vicinity': '615 Gallatin Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1474762, 'lng': -86.7593486},
#     'viewport': {'northeast': {'lat': 36.14896467989272,
#       'lng': -86.75792707010729},
#      'southwest': {'lat': 36.14626502010727, 'lng': -86.76062672989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Z Mart',
#    'place_id': 'ChIJsWvqChNmZIgR_T0Pp_k_TrM',
#    'plus_code': {'compound_code': '46WR+X7 Nashville, Tennessee',
#     'global_code': '868M46WR+X7'},
#    'rating': 3.5,
#    'reference': 'ChIJsWvqChNmZIgR_T0Pp_k_TrM',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 6,
#    'vicinity': '141 Lafayette St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1832368, 'lng': -86.812551},
#     'viewport': {'northeast': {'lat': 36.18449012989272,
#       'lng': -86.81129432010728},
#      'southwest': {'lat': 36.18179047010728, 'lng': -86.81399397989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "SAM'S MARKET",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103659464595606534317">SAM</a>'],
#      'photo_reference': 'ATtYBwI5JzULLJ0NwpGmMViKhpUq4O-HdlMwPHWK3nQdchPf6X85NQlyaI8-S3dC9cCTdBYujw9hJKwTCzENtPLg6QRQk84i1PPntONr5tXzggomZclBUhkKtYY30V3JV4K8e1XTLPb62kEo62dOnEVGYU2t1ib6aHcBIH-986mPXN02o8LR',
#      'width': 3264}],
#    'place_id': 'ChIJGVsGTi9nZIgRAa6Iee-oLMQ',
#    'plus_code': {'compound_code': '55MP+7X Nashville, Tennessee',
#     'global_code': '868M55MP+7X'},
#    'rating': 4.5,
#    'reference': 'ChIJGVsGTi9nZIgRAa6Iee-oLMQ',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 34,
#    'vicinity': '2012 Clarksville Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1567496, 'lng': -86.7880596},
#     'viewport': {'northeast': {'lat': 36.15822177989272,
#       'lng': -86.78688217010726},
#      'southwest': {'lat': 36.15552212010728, 'lng': -86.78958182989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Whole Foods Market',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3801,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116546288138045050659">A Google User</a>'],
#      'photo_reference': 'ATtYBwLcVSlhBHbKiP4qInUGeEnNJExd81Hsv0PwSNjBrRo42B4nV0yBZ5JPm4_ziibgU9zewKJoguBC76aPtk62O9L9qLNqJHU33mk2hv8oO0w6KSoEWwuKszAaHRHcQU5ojweeb821QsF8QgvbQHSBUoTJ5IDoOknWTXgPFqv-KvoYCyRA',
#      'width': 6000}],
#    'place_id': 'ChIJY1hOx5hnZIgRaU2PoQEx2R0',
#    'plus_code': {'compound_code': '5646+MQ Nashville, Tennessee',
#     'global_code': '868M5646+MQ'},
#    'rating': 4.6,
#    'reference': 'ChIJY1hOx5hnZIgRaU2PoQEx2R0',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 156,
#    'vicinity': '1202 Broadway, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1527599, 'lng': -86.78545869999999},
#     'viewport': {'northeast': {'lat': 36.15402722989273,
#       'lng': -86.78403837010728},
#      'southwest': {'lat': 36.15132757010728, 'lng': -86.78673802989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'The Turnip Truck Urban Fare',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111780832437308997914">A Google User</a>'],
#      'photo_reference': 'ATtYBwJZxhLlM0bQ40qItDz5i6rQoBxS52opU7jm3K0znOY03bJI4bjmJVoCUQMRgaVm6Bn_ZmGHZDsT10_QTgfeswOBn2kTKfHtO7jBxB9xCC5ums-AXh7JhmyrrplCMNL0QGdMqFOQiz2Zk_RUlwsnMKy4lssgaXve14tWv9nrP7GvI_mq',
#      'width': 3024}],
#    'place_id': 'ChIJE-1HDItmZIgRSm3egxKPeck',
#    'plus_code': {'compound_code': '5637+4R Nashville, Tennessee',
#     'global_code': '868M5637+4R'},
#    'rating': 4.5,
#    'reference': 'ChIJE-1HDItmZIgRSm3egxKPeck',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 424,
#    'vicinity': '321 12th Ave S, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1329002, 'lng': -86.7887039},
#     'viewport': {'northeast': {'lat': 36.13425077989272,
#       'lng': -86.78734452010728},
#      'southwest': {'lat': 36.13155112010728, 'lng': -86.79004417989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'The Store',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJyzYwFj5lZIgRFGB0hYpHoQA',
#    'plus_code': {'compound_code': '46M6+5G Nashville, Tennessee',
#     'global_code': '868M46M6+5G'},
#    'rating': 5,
#    'reference': 'ChIJyzYwFj5lZIgRFGB0hYpHoQA',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 12,
#    'vicinity': '2009 12th Ave S, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1632696, 'lng': -86.7896679},
#     'viewport': {'northeast': {'lat': 36.16425947989273,
#       'lng': -86.78834562010726},
#      'southwest': {'lat': 36.16155982010728, 'lng': -86.79104527989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Publix Super Market at Capitol View',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101238290545615941587">Jenn Durham</a>'],
#      'photo_reference': 'ATtYBwIKXXuBqhjHwDUT_F9FQMxra9DSDxyu1G3jSg1HroaRCOr7azlwQpbPhpppRchac01h-0WUQ2XUJPZG8mFewuG96Yd4ZKG1NXPuSSN6Ys-6K9H0dgEki8MVp2eJ0uS-m0hQoiBZkzUgJtXcbFvk1vkkli7Bvcb-zaIJtIZwocK63YyF',
#      'width': 4032}],
#    'place_id': 'ChIJ_3hhuz9nZIgROr9342w22Ic',
#    'plus_code': {'compound_code': '5676+84 Nashville, Tennessee',
#     'global_code': '868M5676+84'},
#    'rating': 4.4,
#    'reference': 'ChIJ_3hhuz9nZIgROr9342w22Ic',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'bakery',
#     'liquor_store',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 137,
#    'vicinity': '1010 Dr Martin L King Jr Blvd, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1549405, 'lng': -86.7734169},
#     'viewport': {'northeast': {'lat': 36.15631442989272,
#       'lng': -86.77200867010727},
#      'southwest': {'lat': 36.15361477010727, 'lng': -86.77470832989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'DOWNTOWN FRESH MARKET',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113017152172333760517">A Google User</a>'],
#      'photo_reference': 'ATtYBwJHeno7UYpmh7lIjmVUq9u3bnStxHIViS-tCGQtXOmr9sCuxi5pJDrVeQPaQNewtsPibIkNOhqn-6yJE5I6BZXQoA45ag-xgo_jsIz_ZOj-dwC7N1EnpKRSCJuEefE1Jx9IHaV2AW23OliLDkhx1EtPH4P8jgqdztxAcrr6Epuvddtg',
#      'width': 3024}],
#    'place_id': 'ChIJuTn3A-tnZIgREs7ZhppWRb0',
#    'plus_code': {'compound_code': '563G+XJ Nashville, Tennessee',
#     'global_code': '868M563G+XJ'},
#    'rating': 5,
#    'reference': 'ChIJuTn3A-tnZIgREs7ZhppWRb0',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'convenience_store',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '531 4th Ave S, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1877595, 'lng': -86.7730452},
#     'viewport': {'northeast': {'lat': 36.18911957989271,
#       'lng': -86.77182812010729},
#      'southwest': {'lat': 36.18641992010726, 'lng': -86.77452777989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Star Market',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJORilXaVnZIgRxP_1G83ELjk',
#    'plus_code': {'compound_code': '56QG+4Q Nashville, Tennessee',
#     'global_code': '868M56QG+4Q'},
#    'rating': 0,
#    'reference': 'ChIJORilXaVnZIgRxP_1G83ELjk',
#    'scope': 'GOOGLE',
#    'types': ['convenience_store',
#     'grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': '903 Dickerson Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1318231, 'lng': -86.7573699},
#     'viewport': {'northeast': {'lat': 36.13325702989272,
#       'lng': -86.75590727010729},
#      'southwest': {'lat': 36.13055737010728, 'lng': -86.75860692989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'U.S.Discount Tobacco & Beer',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3264,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105673395222210057069">Sandra Tucker</a>'],
#      'photo_reference': 'ATtYBwKYIKejn9nwHiOL1iOQAKEWhCVhq5S-L_7XUzYk5suGfi2DHpwL0loJtrAEUUOMGTRSWLlmG8cfrK9YBswjiaSW2UcEqmg3PamEFNhBUNtqWbKFgWAM5LMiorTpG17q0wtjrj9hFO1hMcTkOjFqz4fcRWJ7U5cNRcGsz_ybtxyzAclM',
#      'width': 2448}],
#    'place_id': 'ChIJ93X87-FlZIgRo71ee_0_6rY',
#    'plus_code': {'compound_code': '46JV+P3 Nashville, Tennessee',
#     'global_code': '868M46JV+P3'},
#    'rating': 4.2,
#    'reference': 'ChIJ93X87-FlZIgRo71ee_0_6rY',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 19,
#    'vicinity': '1997 Nolensville Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1758569, 'lng': -86.79427369999999},
#     'viewport': {'northeast': {'lat': 36.17703907989273,
#       'lng': -86.79283387010727},
#      'southwest': {'lat': 36.17433942010728, 'lng': -86.79553352989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1280,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110336675155918874463">Kroger</a>'],
#      'photo_reference': 'ATtYBwJZb5Q0F0Sm5hD9RDVvBP_9oS1ATGpP_4qYsyEO_7pXrDHLyCTSXCuIZ9TftPdEbaJfau_jrR2cQLsWSQarTZ7eHvhJBemNozGvxcXWohzlaojatTm5KOInRYXRYV8PESfLtBZXSeLfSX5xnQAfjuB2DNcMu19REdNt6elzgEaWN9KV',
#      'width': 1920}],
#    'place_id': 'ChIJ0f1NweJmZIgRYnc_3nqNyag',
#    'plus_code': {'compound_code': '56G4+87 Nashville, Tennessee',
#     'global_code': '868M56G4+87'},
#    'price_level': 2,
#    'rating': 3.7,
#    'reference': 'ChIJ0f1NweJmZIgRYnc_3nqNyag',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 890,
#    'vicinity': '800 Monroe St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1853811, 'lng': -86.8159932},
#     'viewport': {'northeast': {'lat': 36.18663382989272,
#       'lng': -86.81489022010727},
#      'southwest': {'lat': 36.18393417010728, 'lng': -86.81758987989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Save A Lot',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1440,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111089389699251425402">A Google User</a>'],
#      'photo_reference': 'ATtYBwJLk2da_OPYAcDrY0RJXyiVexcd4GSHfvd1HV_uwztNwcA1WpYxm4YiUDkwY287qauS4Ocm9_l7tL3l0lTlan9dd-YxMR_5mTqLuvNKtAx3XLsRFqzh-BpajRI-R_RImEHQCsTlrIQ-MRjXVuXcEjOKMMxE0KusR5zGur_RWlTIikdd',
#      'width': 2560}],
#    'place_id': 'ChIJCTHj7C5nZIgR8KzLicfUjkw',
#    'plus_code': {'compound_code': '55PM+5J Nashville, Tennessee',
#     'global_code': '868M55PM+5J'},
#    'rating': 4,
#    'reference': 'ChIJCTHj7C5nZIgR8KzLicfUjkw',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 512,
#    'vicinity': '2400 Clarksville Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1594967, 'lng': -86.8140176},
#     'viewport': {'northeast': {'lat': 36.16086467989272,
#       'lng': -86.81256562010728},
#      'southwest': {'lat': 36.15816502010728, 'lng': -86.81526527989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "Resha's Bi-Rite Market",
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJ4ZED5shmZIgRz1kBNC9ENYg',
#    'plus_code': {'compound_code': '555P+Q9 Nashville, Tennessee',
#     'global_code': '868M555P+Q9'},
#    'rating': 3.8,
#    'reference': 'ChIJ4ZED5shmZIgRz1kBNC9ENYg',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 57,
#    'vicinity': '717 25th Ave N, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.2098477, 'lng': -86.837724},
#     'viewport': {'northeast': {'lat': 36.21121757989273,
#       'lng': -86.83647922010728},
#      'southwest': {'lat': 36.20851792010728, 'lng': -86.83917887989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101587297628701575481">Glogic Rodney</a>'],
#      'photo_reference': 'ATtYBwLrMjev2j6CYhQH6e8jS49k0mo8Nws9AhgQH-m0uIZ1F5psAjRFBVbTXrDDV1mWbFjXydnT6znL8sexqSJ9dcyFJ1ZmYRWXkEoM5jaKeK-uq9o0kBKFgudHst-utn54fDq9oZcoZu2kqdGiEroNgM5kRfsE2ZVycTQtTOTqWXVHzDdR',
#      'width': 1920}],
#    'place_id': 'ChIJ8_NRorxgZIgRrfj0tUFShq4',
#    'plus_code': {'compound_code': '6556+WW Nashville, Tennessee',
#     'global_code': '868M6556+WW'},
#    'price_level': 2,
#    'rating': 4,
#    'reference': 'ChIJ8_NRorxgZIgRrfj0tUFShq4',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 629,
#    'vicinity': '3930 Clarksville Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.15901760000001, 'lng': -86.8182096},
#     'viewport': {'northeast': {'lat': 36.16033492989273,
#       'lng': -86.81705327010728},
#      'southwest': {'lat': 36.15763527010728, 'lng': -86.81975292989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "Swett's Market",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1440,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106731321516876371408">A Google User</a>'],
#      'photo_reference': 'ATtYBwKzZQVQQtzTrWr_wL-Sz4TGLKp7pOLS_y2LyhO8NgpsE_bdZyAi_5GrrAuyfWWxm6dxpKfgfQi21TyvjHy8w1k6HmaU4dByK1xTq-QZetVegnDnkJ44oIeeZkVK4eJ4WS3MGno8UvB7Nwc1lZ7ZD-E7dp48b-NhTWsG6NCQgMAHrENN',
#      'width': 2560}],
#    'place_id': 'ChIJ4Rt8tstmZIgR8DW1VbfQCMw',
#    'plus_code': {'compound_code': '555J+JP Nashville, Tennessee',
#     'global_code': '868M555J+JP'},
#    'rating': 3.8,
#    'reference': 'ChIJ4Rt8tstmZIgR8DW1VbfQCMw',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 106,
#    'vicinity': '702 28th Ave N, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.193048, 'lng': -86.83246199999999},
#     'viewport': {'northeast': {'lat': 36.19457997989272,
#       'lng': -86.83091502010727},
#      'southwest': {'lat': 36.19188032010727, 'lng': -86.83361467989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Bordeaux Food',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJvTVWTs9gZIgRuVx57Xu68ww',
#    'plus_code': {'compound_code': '55V9+62 Nashville, Tennessee',
#     'global_code': '868M55V9+62'},
#    'rating': 4.2,
#    'reference': 'ChIJvTVWTs9gZIgRuVx57Xu68ww',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 196,
#    'vicinity': '3205 Clarksville Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1832368, 'lng': -86.812551},
#     'viewport': {'northeast': {'lat': 36.18449012989272,
#       'lng': -86.81129432010728},
#      'southwest': {'lat': 36.18179047010728, 'lng': -86.81399397989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "SAM'S MARKET",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103659464595606534317">SAM</a>'],
#      'photo_reference': 'ATtYBwLp8ko-4J22uBiKhSvmOn7NvxlxP4XGT3-4_YgBFZ2BI-TN5bNNbZDQPuK0WqhtUAI2t157ThAL6lk3OzTHnu77ujkthMzaA5OSSkbJ6OANuIkHTUtZDTWocSSWpz_Z_hw7PXDVM2cQyVUlWi-JhVsC3ImPUdhdQzS2X1zIVUKe1EsQ',
#      'width': 3264}],
#    'place_id': 'ChIJGVsGTi9nZIgRAa6Iee-oLMQ',
#    'plus_code': {'compound_code': '55MP+7X Nashville, Tennessee',
#     'global_code': '868M55MP+7X'},
#    'rating': 4.5,
#    'reference': 'ChIJGVsGTi9nZIgRAa6Iee-oLMQ',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 34,
# ...
#      'photo_reference': 'ATtYBwJYdQkw-ykve11ybf_dDxiGsSHlhI3_RuaZopiaiJr8_vwoICmq8fTEt7m78ZaLL1IPamPBkKN1sEzQbPYew0j1DhkjIqr9o92mvo5wfqJJDUqcpw-WBrVuqIKDBmGXexnK6m8F40XhIQMW_4bsNexO76NvRYRHKoDSt8OfdX0KUhxh',
#      'width': 4032}],
#    'place_id': 'ChIJR3s_9XFhZIgRnOmroUutAIc',
#    'plus_code': {'compound_code': '542W+VF Nashville, Tennessee',
#     'global_code': '868M542W+VF'},
#    'rating': 4.3,
#    'reference': 'ChIJR3s_9XFhZIgRnOmroUutAIc',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 232,
#    'vicinity': '5404 Charlotte Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1470294, 'lng': -86.8635401},
#     'viewport': {'northeast': {'lat': 36.14837922989273,
#       'lng': -86.86219027010728},
#      'southwest': {'lat': 36.14567957010728, 'lng': -86.86488992989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'K&S World Market',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110659991627955763294">Barry Jover</a>'],
#      'photo_reference': 'ATtYBwLXN0a-89DbSsY4UIiPGGA-o9z3SpYHnGcydb6X-iMYeZkyyMZql1HmNn8CxJZmSOhH9en1-GV8S0HBJeMHphPyENVoCqk3y3SNapcn6eAlfT75vpJKxAmhYri5ISFenZfxMM28GOY0xi3gRIoKQhJ0xj6c5c-6wPS8C6LjmJbOMkx3',
#      'width': 3024}],
#    'place_id': 'ChIJOZDICp1hZIgRcZnCutvsQK0',
#    'plus_code': {'compound_code': '44WP+RH Nashville, Tennessee',
#     'global_code': '868M44WP+RH'},
#    'rating': 4.3,
#    'reference': 'ChIJOZDICp1hZIgRcZnCutvsQK0',
#    'scope': 'GOOGLE',
#    'types': ['supermarket',
#     'grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 723,
#    'vicinity': '5861 Charlotte Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1448383, 'lng': -86.8715893},
#     'viewport': {'northeast': {'lat': 36.14632242989272,
#       'lng': -86.87040572010727},
#      'southwest': {'lat': 36.14362277010728, 'lng': -86.87310537989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Mi Favorita Super',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110277181500999606911">Omar M</a>'],
#      'photo_reference': 'ATtYBwIg-mOJN9k9yHYdyhYXbaQT2UtRY998IMgwwD6VJRlCN9lLroExDT7fRwYzwMvUx4RWlGxex5SDG-gnHPkfpVMtlfV1kTQ6qhnoo69OYbSOsygFlasooqLodte8_CjwD15Whvi-G_IbGG_8dEuJGmOrIXtBRSLARLbNvKNjoFN6UWIL',
#      'width': 5312}],
#    'place_id': 'ChIJk4INZoVhZIgR6ge7S2DIduY',
#    'plus_code': {'compound_code': '44VH+W9 Nashville, Tennessee',
#     'global_code': '868M44VH+W9'},
#    'rating': 4.2,
#    'reference': 'ChIJk4INZoVhZIgR6ge7S2DIduY',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 147,
#    'vicinity': '6317 Charlotte Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1267272, 'lng': -86.8475064},
#     'viewport': {'northeast': {'lat': 36.12797762989273,
#       'lng': -86.84605667010729},
#      'southwest': {'lat': 36.12527797010728, 'lng': -86.84875632989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Publix Super Market at Hill Center at Belle Meade',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116780368244981387168">Sarah Crawford</a>'],
#      'photo_reference': 'ATtYBwI4FEuMdyrzWh7GkpbU7BK3teCJvJatVbFqf2MfXPy_8tb0nFJGoMhleNsEINhCswHU5t6JzZYDvUT5vuAOjqrUtpWJEzK_sNgOt82Pcfh2f4NxyvplB3J5QtrPOTbXW5h1kyRlUcQdaA--kfMi_5wNAPiehXpsWYvSYhb8YmUaOYzu',
#      'width': 3984}],
#    'place_id': 'ChIJ_98e89xjZIgRkX7e3TmFvyw',
#    'plus_code': {'compound_code': '45G2+MX Nashville, Tennessee',
#     'global_code': '868M45G2+MX'},
#    'price_level': 2,
#    'rating': 4.4,
#    'reference': 'ChIJ_98e89xjZIgRkX7e3TmFvyw',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'bakery',
#     'liquor_store',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 358,
#    'vicinity': '4324 Harding Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.14495950000001, 'lng': -86.8740361},
#     'viewport': {'northeast': {'lat': 36.14638327989272,
#       'lng': -86.87254922010727},
#      'southwest': {'lat': 36.14368362010728, 'lng': -86.87524887989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'ALDI',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107244682706324479289">David Ancell</a>'],
#      'photo_reference': 'ATtYBwLP6pDwtEgDcLrFETyxyDrhUxKmPn7s9EmCej2JAsoNj52So4v1tivd-2GEuNrE3gkxECv0bIME4ubeyV1tzawJDBZ5swOOMgehS7Ub39RSPq25Yq1WIVMYfEwxlwu-hgIARqSQhQKG2KW36TjrY6qFdTmLXGDsWSEB35eUtexQfCGd',
#      'width': 4032}],
#    'place_id': 'ChIJ75kruY9hZIgRaMHuKhEG7vw',
#    'plus_code': {'compound_code': '44VG+X9 Nashville, Tennessee',
#     'global_code': '868M44VG+X9'},
#    'price_level': 1,
#    'rating': 4.6,
#    'reference': 'ChIJ75kruY9hZIgRaMHuKhEG7vw',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 646,
#    'vicinity': '405 American Rd, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1574323, 'lng': -86.87454939999999},
#     'viewport': {'northeast': {'lat': 36.15888497989272,
#       'lng': -86.87318082010728},
#      'southwest': {'lat': 36.15618532010728, 'lng': -86.87588047989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Robertson Avenue Market',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2576,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112305647775457658496">A Google User</a>'],
#      'photo_reference': 'ATtYBwJEDhnoUfJzajoReghcQt_MTuyZq8nxiw993mGEgbQLgRK4ERNXEl5RcxsnvaMUXem5PNTBE_oUeNXJ3KPyUYMVcECKEutMcV5MaX7H1-xXBKjo1Bf3HKemuYdQpirrzF4ux0PuSnEjFEeGG8378L7NGKiX1NyuTJhwsfvHKRLqB-qu',
#      'width': 1932}],
#    'place_id': 'ChIJxcH_fr1hZIgRjt0YWNDQMJI',
#    'plus_code': {'compound_code': '544G+X5 Nashville, Tennessee',
#     'global_code': '868M544G+X5'},
#    'rating': 4.3,
#    'reference': 'ChIJxcH_fr1hZIgRjt0YWNDQMJI',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 88,
#    'vicinity': '6229 Robertson Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1402176, 'lng': -86.8829105},
#     'viewport': {'northeast': {'lat': 36.14146022989272,
#       'lng': -86.88140622010728},
#      'southwest': {'lat': 36.13876057010727, 'lng': -86.88410587989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Publix Super Market at Hill Center at Nashville West',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108113789002620796958">Rex Cope</a>'],
#      'photo_reference': 'ATtYBwI65wozjoFLULwaNGoxBxlimM-OMO0CA_pA7mX-1Zjj0UoKPTsVD5RB4YrYQrOeXECkGmijbxkMvpEYSUe1CFRRQzFq8GrR_4n99va7uy8MSPaWuG-A_E3HIGh77X3h--tI1ZEUlZXpTGQPBdCaDOdQygHg6t-sDQSnhfuRjXDBkLoE',
#      'width': 4032}],
#    'place_id': 'ChIJbSHs2IphZIgRVNJFmBoOn3c',
#    'plus_code': {'compound_code': '44R8+3R Nashville, Tennessee',
#     'global_code': '868M44R8+3R'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJbSHs2IphZIgRVNJFmBoOn3c',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'bakery',
#     'liquor_store',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 421,
#    'vicinity': '6614 Charlotte Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1307261, 'lng': -86.85222700000001},
#     'viewport': {'northeast': {'lat': 36.13209387989272,
#       'lng': -86.85101287010728},
#      'southwest': {'lat': 36.12939422010728, 'lng': -86.85371252989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "Trader Joe's",
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111883553107378193704">Dustin Meza</a>'],
#      'photo_reference': 'ATtYBwK2q5OrCt-UQ6S9W_3iS1X8H--aY6tlxmX92zI_vuI0NYCzMowjESdGAQAj6itN1cNJ17IS5uES9W5ijUJmJkpCMq3SOce-huwcEyN1LNKXncFPv2_27f0JuflnrGOZTs-omyc4HYF1a3kIhH78JuJ8eWgQcGAwUdJ8-zsmKjQ0rKhz',
#      'width': 4032}],
#    'place_id': 'ChIJI27K4o5jZIgRkiQ31PPyWiw',
#    'plus_code': {'compound_code': '44JX+74 Nashville, Tennessee',
#     'global_code': '868M44JX+74'},
#    'rating': 4.7,
#    'reference': 'ChIJI27K4o5jZIgRkiQ31PPyWiw',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'florist',
#     'supermarket',
#     'liquor_store',
#     'food',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 392,
#    'vicinity': '90 White Bridge Rd, Nashville'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 36.1260733, 'lng': -86.8448939},
#     'viewport': {'northeast': {'lat': 36.12736967989272,
#       'lng': -86.84364682010728},
#      'southwest': {'lat': 36.12467002010727, 'lng': -86.84634647989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Harris Teeter',
#    'permanently_closed': True,
#    'place_id': 'ChIJwy-w_NxjZIgRjoMOEbsjj08',
#    'plus_code': {'compound_code': '45G4+C2 Nashville, Tennessee',
#     'global_code': '868M45G4+C2'},
#    'rating': 4,
#    'reference': 'ChIJwy-w_NxjZIgRjoMOEbsjj08',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'florist',
#     'pharmacy',
#     'bakery',
#     'supermarket',
#     'food',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '4416 Ridgefield Way, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1576546, 'lng': -86.8426645},
#     'viewport': {'northeast': {'lat': 36.15909842989272,
#       'lng': -86.84131947010727},
#      'southwest': {'lat': 36.15639877010727, 'lng': -86.84401912989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': '3 & M Mart',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111103027546614440458">Lucian Brown</a>'],
#      'photo_reference': 'ATtYBwL1fS1KLtUUIzFKSx3Q7aLhYih9BDy1BsKcIpaqydqCpgniumsRAFdpNEaJmcXfCxN0xStj6e-70_By2fWeaMv8aWL-d8wgRWcBtS6Dq0mN43vIfCg4YFVHZMzOgqBf9dRZ_eNnZbcVxpLbl1YH6T1XbdLC1LRnn-AG9ntu3RWEbLID',
#      'width': 1920}],
#    'place_id': 'ChIJfULdXBVhZIgRLJctT3HrvLc',
#    'plus_code': {'compound_code': '5554+3W Nashville, Tennessee',
#     'global_code': '868M5554+3W'},
#    'rating': 4,
#    'reference': 'ChIJfULdXBVhZIgRLJctT3HrvLc',
#    'scope': 'GOOGLE',
#    'types': ['supermarket',
#     'grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': '4601 Illinois Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1490082, 'lng': -86.86342929999999},
#     'viewport': {'northeast': {'lat': 36.15035447989273,
#       'lng': -86.86207872010728},
#      'southwest': {'lat': 36.14765482010728, 'lng': -86.86477837989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Guanabana',
#    'place_id': 'ChIJV8bVWmRhZIgR0ipGBu32Cuc',
#    'plus_code': {'compound_code': '44XP+JJ Nashville, Tennessee',
#     'global_code': '868M44XP+JJ'},
#    'rating': 0,
#    'reference': 'ChIJV8bVWmRhZIgR0ipGBu32Cuc',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 0,
#    'vicinity': '5861 Charlotte Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1529702, 'lng': -86.8433122},
#     'viewport': {'northeast': {'lat': 36.15446392989272,
#       'lng': -86.84197072010728},
#      'southwest': {'lat': 36.15176427010728, 'lng': -86.84467037989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Good Food for Good People Inc',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJo0jJaWphZIgReYWIl-OnDjs',
#    'plus_code': {'compound_code': '5534+5M Nashville, Tennessee',
#     'global_code': '868M5534+5M'},
#    'rating': 3,
#    'reference': 'ChIJo0jJaWphZIgReYWIl-OnDjs',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'park',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': '4611 Alabama Ave, Nashville'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 36.1309156, 'lng': -86.8574398},
#     'viewport': {'northeast': {'lat': 36.13225662989272,
#       'lng': -86.85607957010727},
#      'southwest': {'lat': 36.12955697010728, 'lng': -86.85877922989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "JC's Amish Produce",
#    'permanently_closed': True,
#    'photos': [{'height': 1836,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113033504553306816485">Sally Lafave</a>'],
#      'photo_reference': 'ATtYBwKuSOKt-p7ifhpOTgWOk9h5r6QNx_VJ2KAGAv3YQhs2D6TJz1x59CmA7il5Sv-taWSsDiCbVKHWx9V4h6K48Vv_zxrQl1bJeAQfGQu7eydvipYU1TppOFZVlrXzGoEzwNBF2KKlMqQod2-PSSkVtY1STdgoxoqjaGX5m73ZHTzvTjPC',
#      'width': 3264}],
#    'place_id': 'ChIJ13_aHtRjZIgR59-eJwLqPo4',
#    'plus_code': {'compound_code': '44JV+92 Nashville, Tennessee',
#     'global_code': '868M44JV+92'},
#    'rating': 5,
#    'reference': 'ChIJ13_aHtRjZIgR59-eJwLqPo4',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': 'Fountain Pl, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1479912, 'lng': -86.862405},
#     'viewport': {'northeast': {'lat': 36.14954157989273,
#       'lng': -86.86114262010727},
#      'southwest': {'lat': 36.14684192010728, 'lng': -86.86384227989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Cho A Dong',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1683,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115454757633528502596">Chiaro Foto</a>'],
#      'photo_reference': 'ATtYBwKCMrnuzOyOQojKDBCchYZ6dDQXD5zSrHjiQ24iP3mMbpnv9hF5eYd5RKBb-07-AZ5vxpNmwoMcEpw_BdnpEbfPg9kMyH38Geg1UlLO_6ywkfLkjWKX61pxvDPUUa1pDTteSy3BozXl8aCEnkbPr6xSth1TmmAkjm5K7nO8fEuyuazv',
#      'width': 1937}],
#    'place_id': 'ChIJiXvRnZ1hZIgR1JpZ7ISTU6U',
#    'plus_code': {'compound_code': '44XQ+52 Nashville, Tennessee',
#     'global_code': '868M44XQ+52'},
#    'rating': 4.7,
#    'reference': 'ChIJiXvRnZ1hZIgR1JpZ7ISTU6U',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 19,
#    'vicinity': '5837 Charlotte Pike, Nashville'}]]

# %% [markdown]
# city_list = ['Berry_Hill': 36.11637813798946, -86.76761477125187]
# df = pd.DataFrame(list(city_list.items()))

# %% [markdown]
# d = {}
# for results in city_list:
#         d['Berry_Hill'] = api_key

# %% [markdown]
# results.shape

# %% [markdown]
# response.tojson

# %% [markdown]
# response_df = pd.read_json('E:/Capstone/res.json')
# response_df_df.head()

# %%
type(results_df)
# Out:
# list

# %% [markdown]
# results_nash_map = folium.Map([36.163242365862246,-86.78142455028717], zoom_start = 12)
#
# for store in results_df:
#     lat_lng = store['geometry']['location']
#     location = [lat_lng['lat'], lat_lng['lng']]
#     popup = store['name']
#     folium.Marker(location = location, popup = popup).add_to(nash_map)
#
# results_nash_map

# %%
east_nash_map = folium.Map([36.163242365862246,-86.78142455028717], zoom_start = 12)

for store in response_east['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(east_nash_map)

east_nash_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# for store in response_east['results']:
#     lat_lng = store['geometry']['location']
#     location = [lat_lng['lat'], lat_lng['lng']]
#     popup = store['name']
#     folium.Marker(location = location, popup = popup).add_to(nash_map)

# %%
nash_map = folium.Map([36.163242365862246,-86.78142455028717], zoom_start = 12)

for store in response_nash['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(nash_map)
for store in response_east['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(nash_map)
for store in response_west['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(nash_map)
for store in response_south['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(nash_map)
for store in response_north['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(nash_map)

nash_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# https://docs.python.org/3/library/json.html

# %%
for store in response_east['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(nash_map)

# %% [markdown]
# res=response.json()

# %% [markdown]
# res

# %% [markdown]
# pd.DataFrame.from_dict(res)

# %% [markdown]
# response.content

# %% [markdown]
# endpoint='https://maps.googleapis.com/maps/api/place/nearbysearch/json&key:'

# %% [markdown]
# soup = BeautifulSoup(response.content, "html.parser")
# soup.find(attrs={"class": "section-result"}) \
#     .find("table")

# %% [markdown]
# places = pd.concat(response)
# places

# %% [markdown]
# star

# %% [markdown]
# #code start

# %%
from bs4 import BeautifulSoup
import pandas as pd
from IPython.core.display import display, HTML
import pandas as pd
import requests
import matplotlib.pyplot as plt
from IPython.display import Image
import folium
from key import api_key
import json
# %matplotlib inline

# %%
endpoint ='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.163242365862246,-86.78142455028717&radius=1600&keyword=groceries&key=AIzaSyDR7esAMJqahioM7VjF0FOsoM3mv1Jheo4'

# %% [markdown]
# params = dict()
# params["keyword"]= "groceries"

# %%
response = requests.get(endpoint)

# %%
# %who
# Out:
# BeautifulSoup	 HTML	 Image	 api_key	 display	 endpoint	 folium	 json	 pd
# plt	 requests	 response

# %%
def find_nearby_places(api_key=api_key,
                      location='36.163242365862246,-86.78142455028717',
                      radius='8000',
                      base = 'https://maps.googleapis.com/maps/api/place/nearbysearch/',
                      keyword= 'groceries',
                      response_type = 'json',
                      **kwargs):
    '''
    Constructs endpoint and params dict, makes request, and returns output as json
    
    api_key: requred, str, API key from google cloud console
    location: required, str, central location for near by search, format: "<lat>, <lng>"
    radius: required, str, radius of circle (in meters) to search for nearby locations
    base: not required, str, URL base for API request
    resoponse_type: not required, format of response
    **kwargs: not required, search criteria for near by locations
    '''
    endpoint = base+response_type
    kwargs['key'] = api_key
    kwargs['location'] = '36.163242365862246,-86.78142455028717'
    kwargs['radius'] = '8000'
    kwargs['keyword'] = 'groceries'
    res = requests.get(endpoint, kwargs)
    return res.json()

# %% [markdown]
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.163242365862246,-86.78142455028717&radius=1600&keyword=groceries&key=api_key

# %% [markdown]
# response = requests.get(endpoint, params = params)

# %% [markdown]
# ###URL ='https://www.google.com/maps/search/Groceries/@36.1818696,-86.8284668,14z/data=!3m1!4b1!4m2!2m1!6e6'

# %% [markdown]
# response = requests.post(endpoint)
# response.json()

# %% [markdown]
# response = requests.get(endpoint)
# response.status_code

# %%
response = find_nearby_places()

# %%
response
# Out:
# {'html_attributions': [],
#  'next_page_token': 'ATtYBwIQ5UH69mzd5wWlXvi-kvhwJruUWtNE6mCCeg296K7lvz5oIbY5aE3xmQpz8PCr5_qRQgbXuqsAyhXiQGmoqLrG-NW2ebMug0qgQoYWVDi0PQThuCtSIsyqQuNyW4BWvwCS5YuTjDp7FQZ94PxHP8SSg_mIAKS0Hqd3CRS94uYkm-91ZaeDdqKR1eiAcfpYfAkEZWK-yD5_95KZHn-fHAj1Z4p4byvV8vcs2nV9T9C0-XCdO66Uwp4MRoSoNXDUYJ6drL8bjHz-LBCCH6mD_Jr59w5sI4uPIyNMhJ42uI8rRVQRFfiqcKw181efSDToUruJgnfqnelXCk9EuAEtToFRtPzM3pe-8Dpz-r9WZb3ZCjtAZ-m_ObJRjZw_IncU-I1g9zjtKN9GfkpaGgnyBF2-OHocmzP_kWvB6ofnlv6KsaBYpjaOP3omoDA',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1199226, 'lng': -86.7771759},
#     'viewport': {'northeast': {'lat': 36.12131622989272,
#       'lng': -86.77576167010727},
#      'southwest': {'lat': 36.11861657010727, 'lng': -86.77846132989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3179,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109351011289266507435">Ehsan Manoushan</a>'],
#      'photo_reference': 'ATtYBwIHN7KGfYaddWxkPK8pgosJKfwWWDFWgsD3br1QVIwLOWc2qgleQJDFlj5RltI5JucC__zWqoUNdQ1fPMoazZBEQfxSDSMAYUvfJvGa2zLe7oQxC_-eier6abL8VpuGifGSNBHhAfC7oPkIHnOJG_wVD9ls7y_1rwSHRAcr_0h8Qk5W',
#      'width': 1924}],
#    'place_id': 'ChIJ9_tF0c1lZIgRyxJ31oCrtRI',
#    'plus_code': {'compound_code': '469F+X4 Nashville, Tennessee',
#     'global_code': '868M469F+X4'},
#    'price_level': 2,
#    'rating': 3.8,
#    'reference': 'ChIJ9_tF0c1lZIgRyxJ31oCrtRI',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 629,
#    'vicinity': '2615 Franklin Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1301887, 'lng': -86.80261089999999},
#     'viewport': {'northeast': {'lat': 36.13147872989272,
#       'lng': -86.80109647010728},
#      'southwest': {'lat': 36.12877907010727, 'lng': -86.80379612989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117053513999049084047">Katherine Romero</a>'],
#      'photo_reference': 'ATtYBwJHMhTBCYSY2ccMbD0UHYYhfQrwouX4jAl93lR6_ui-SdU_eRUsIq224xMpEe3IttkTt0OGNY1p4DPG4uWbBNrSR3cAkuTIHVQIoPN3x7QnkRyqF4yWKHzitMPiY7eEZJv9h19nvllZ_LIatsn93neFiSN256n2e9ya5arhRT1JmHn1',
#      'width': 3264}],
#    'place_id': 'ChIJ8XuUZR9kZIgRohFW4543QB8',
#    'plus_code': {'compound_code': '45JW+3X Nashville, Tennessee',
#     'global_code': '868M45JW+3X'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJ8XuUZR9kZIgRohFW4543QB8',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 553,
#    'vicinity': '2201 21st Ave S, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1318851, 'lng': -86.76877499999999},
#     'viewport': {'northeast': {'lat': 36.13314642989272,
#       'lng': -86.76743662010726},
#      'southwest': {'lat': 36.13044677010728, 'lng': -86.77013627989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Wedgehill Market',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115761387019637953020">Michael Orosco</a>'],
#      'photo_reference': 'ATtYBwKh98uSdRzcW5Hs9ZZx6p3NMwIXbexCKKvQyfTQ-XbUP94-O03pL38Hh6wqHqupfvmWusClnMFKJhaP2OHvMUwTB_QbrgAPxoo5W_nm3sbJ1xWsqAe_Ds1jkBkEVxhnsXiI80hglkYO3lXGhwNu8kvrROpPvIfKwjGHVQLkhsrWW0DT',
#      'width': 5312}],
#    'place_id': 'ChIJmyJmjthlZIgR_8KhYLlhP0E',
#    'plus_code': {'compound_code': '46JJ+QF Nashville, Tennessee',
#     'global_code': '868M46JJ+QF'},
#    'rating': 4.6,
#    'reference': 'ChIJmyJmjthlZIgR_8KhYLlhP0E',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 70,
#    'vicinity': '600 Benton Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.117707, 'lng': -86.7967994},
#     'viewport': {'northeast': {'lat': 36.11910602989273,
#       'lng': -86.79554037010728},
#      'southwest': {'lat': 36.11640637010728, 'lng': -86.79824002989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "Osborne's Bi-Rite",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100106521944641494656">Matt Mc</a>'],
#      'photo_reference': 'ATtYBwIzlxQlWLL1wl7EJ8AcEqpQ8pikJbaCJctqMmg_5xQxZRyjXePkpmRLnMsICLsfrBGRP0ImGsT5nqvSnfDiOvfdDZmpDfYnOqqPdTf7h-uBDIKT09_1Ybyl1apWW3oh7chviueqABJSQSAi2w2Scq48zmSJVvSHcmqdh_RRt_FOkIeT',
#      'width': 3024}],
#    'place_id': 'ChIJaQEV-DtkZIgR1fuVUETHCAc',
#    'plus_code': {'compound_code': '4693+37 Nashville, Tennessee',
#     'global_code': '868M4693+37'},
#    'rating': 4.5,
#    'reference': 'ChIJaQEV-DtkZIgR1fuVUETHCAc',
#    'scope': 'GOOGLE',
#    'types': ['supermarket',
#     'grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 251,
#    'vicinity': '3116 Belmont Blvd, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1445892, 'lng': -86.8136},
#     'viewport': {'northeast': {'lat': 36.14593902989272,
#       'lng': -86.81225017010728},
#      'southwest': {'lat': 36.14323937010727, 'lng': -86.81494982989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Piggly Wiggly',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113359179597487495544">Jack Warman</a>'],
#      'photo_reference': 'ATtYBwJrLKXm1NJDC2PhOQ5OG37yDgJcDxpg4tnni9bdFls6GOuiuf275m15Y52diICMNKWm5HDiBQn-KulOk6WE57MYVlv7oa63FIhmMxxWhBSP71rg2aJXXWVSZqmL-j2IDbCn8bHwsZiYKh7rQdkx6TuOBycEFUWGqmWasfFmYFmqiYXh',
#      'width': 3840}],
#    'place_id': 'ChIJF_mw3q9mZIgRQdSpspW80MQ',
#    'plus_code': {'compound_code': '45VP+RH Nashville, Tennessee',
#     'global_code': '868M45VP+RH'},
#    'price_level': 2,
#    'rating': 4,
#    'reference': 'ChIJF_mw3q9mZIgRQdSpspW80MQ',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 360,
#    'vicinity': '2900 West End Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1758569, 'lng': -86.79427369999999},
#     'viewport': {'northeast': {'lat': 36.17703907989273,
#       'lng': -86.79283387010727},
#      'southwest': {'lat': 36.17433942010728, 'lng': -86.79553352989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1280,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110336675155918874463">Kroger</a>'],
#      'photo_reference': 'ATtYBwI-F4h0kg9GLlGcWJeHUWSzBWdFzGualuH_l9PbqGEFihpY5vRMGM3icYYk_xY9liX20yHruCSZFIRhHRMqZ99whxLSZxDpOWJrZcnSamt8-EfaqBHE_m2q51-DB1nAVYEDHurzKI_LxBoI9h2ae65xo4Ak6fvvDdkFaKfNPPGWQ7r1',
#      'width': 1920}],
#    'place_id': 'ChIJ0f1NweJmZIgRYnc_3nqNyag',
#    'plus_code': {'compound_code': '56G4+87 Nashville, Tennessee',
#     'global_code': '868M56G4+87'},
#    'price_level': 2,
#    'rating': 3.7,
#    'reference': 'ChIJ0f1NweJmZIgRYnc_3nqNyag',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 889,
#    'vicinity': '800 Monroe St, Nashville'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 36.1634125, 'lng': -86.779421},
#     'viewport': {'northeast': {'lat': 36.16473492989273,
#       'lng': -86.77817392010726},
#      'southwest': {'lat': 36.16203527010729, 'lng': -86.78087357989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'H.G. Hill Urban Market',
#    'permanently_closed': True,
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106519442576080453760">A Google User</a>'],
#      'photo_reference': 'ATtYBwJ4Rk0ZWK0TsLIsAhWWEyk_K0YseRfciM9AONr9ZsIZV55dn_ctQ5BqiSx7-Aa5cBbdYNU8rd2qOODhuxqKPMVnIxzR4zVWp5n1fKKLtpzEt_Brh4LQVj7htu53ENqdXblAhPR0ELqKW6X4jYGegUBJ7Rdz5LOLKNMq1hc7LXi6vMjo',
#      'width': 3264}],
#    'place_id': 'ChIJPStOVVhmZIgRso0FW3wu3Hw',
#    'plus_code': {'compound_code': '567C+96 Nashville, Tennessee',
#     'global_code': '868M567C+96'},
#    'rating': 4.2,
#    'reference': 'ChIJPStOVVhmZIgRso0FW3wu3Hw',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 191,
#    'vicinity': '415 Church St, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1050835, 'lng': -86.815626},
#     'viewport': {'northeast': {'lat': 36.10642872989272,
#       'lng': -86.81412642010729},
#      'southwest': {'lat': 36.10372907010728, 'lng': -86.81682607989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "Trader Joe's",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100201960762355239004">Paul Kang</a>'],
#      'photo_reference': 'ATtYBwIF29-I2OgjnWYAUiAMCP9GUXGQoRTLyupKAq22gHcqLaK9WbxEi26Xwr5xrMmxxLDyEnNs3IYg7hZaw8eqsdZdu7yI1K8Cq5IENJyt8IEFTNH2gosvL1cUIWVoqp6RX_uwc5lAObuHTHZ6jMD7pVM4f_TnC-8D4wdKw_e6e603Av9l',
#      'width': 4032}],
#    'place_id': 'ChIJH60AEXFkZIgR9d0pAe7Btro',
#    'plus_code': {'compound_code': '454M+2P Nashville, Tennessee',
#     'global_code': '868M454M+2P'},
#    'price_level': 2,
#    'rating': 4.6,
#    'reference': 'ChIJH60AEXFkZIgR9d0pAe7Btro',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'florist',
#     'supermarket',
#     'liquor_store',
#     'food',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 2229,
#    'vicinity': '3909 Hillsboro Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1098319, 'lng': -86.72515729999999},
#     'viewport': {'northeast': {'lat': 36.11133767989271,
#       'lng': -86.72388797010727},
#      'southwest': {'lat': 36.10863802010727, 'lng': -86.72658762989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2560,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111583370177102107504">Neather Black</a>'],
#      'photo_reference': 'ATtYBwIGBqXDfTHyGCEHUTPA0pcMhf1rPXvVkTVjbgbZnmxxt0e1X5e0JMMcDV_ykANszrdgr3SaPf-mTKfAnWdN_8DoLoK3HslxhMElXBF5cryiLTbNmNF6zS8PrP6n3vRal9wzOD7AxM9J_Tkm8f3kjQq9a3dL9iIUWQ1OB_fCUhaxuiKh',
#      'width': 1920}],
#    'place_id': 'ChIJsdxD4EFvZIgRia2JrXjnDZo',
#    'plus_code': {'compound_code': '475F+WW Nashville, Tennessee',
#     'global_code': '868M475F+WW'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJsdxD4EFvZIgRia2JrXjnDZo',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 645,
#    'vicinity': '61 E Thompson Ln, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1594967, 'lng': -86.8140176},
#     'viewport': {'northeast': {'lat': 36.16086467989272,
#       'lng': -86.81256562010728},
#      'southwest': {'lat': 36.15816502010728, 'lng': -86.81526527989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': "Resha's Bi-Rite Market",
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJ4ZED5shmZIgRz1kBNC9ENYg',
#    'plus_code': {'compound_code': '555P+Q9 Nashville, Tennessee',
#     'global_code': '868M555P+Q9'},
#    'rating': 3.8,
#    'reference': 'ChIJ4ZED5shmZIgRz1kBNC9ENYg',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 57,
#    'vicinity': '717 25th Ave N, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1056803, 'lng': -86.81846379999999},
#     'viewport': {'northeast': {'lat': 36.10702517989272,
#       'lng': -86.81705972010727},
#      'southwest': {'lat': 36.10432552010728, 'lng': -86.81975937989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116175916570966053337">Cavell Blood</a>'],
#      'photo_reference': 'ATtYBwJQnKm9f5DnjcywAXD9CgLGhzrFzta7bse4ZTwpdQTK4rUewk9awsvjMaIuU_ul32cesTn2aSgHFCAFihhpOsEmKUDS87BR_-csPqDxr3IGQRymzvunvAaq6JcmDuH8uGsfnz2-sk3cu39_PsYbvtpLk8PczEGcmcuLtb7SX6xJIB4G',
#      'width': 3264}],
#    'place_id': 'ChIJmbwrlHZkZIgR-bMSVV4X4YY',
#    'plus_code': {'compound_code': '454J+7J Nashville, Tennessee',
#     'global_code': '868M454J+7J'},
#    'price_level': 2,
#    'rating': 4.3,
#    'reference': 'ChIJmbwrlHZkZIgR-bMSVV4X4YY',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 374,
#    'vicinity': '2131 Abbott Martin Rd, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.148724, 'lng': -86.8604389},
#     'viewport': {'northeast': {'lat': 36.15012517989273,
#       'lng': -86.85909187010728},
#      'southwest': {'lat': 36.14742552010728, 'lng': -86.86179152989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103832292777728970389">Clara Molina</a>'],
#      'photo_reference': 'ATtYBwKoqLlM7M8GypYm0iB15YvMlhahLMFARi7Sgbqs7UmR131CmAXvo3CePcFVk2ajRgpza44oCpZRAgJwQtpfbsxXjLgslbFB_DBZ9sqLvc_ik0RB9r2_tigGVoGY2h3JbzANPs4RzMZnvWS0iMGxoHxJO6GS4uquUP8hNT0TYzXvYZK8',
#      'width': 1920}],
#    'place_id': 'ChIJ_yOHRXZhZIgRSvQatfG8liY',
#    'plus_code': {'compound_code': '44XQ+FR Nashville, Tennessee',
#     'global_code': '868M44XQ+FR'},
#    'price_level': 2,
#    'rating': 3.9,
#    'reference': 'ChIJ_yOHRXZhZIgRSvQatfG8liY',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 655,
#    'vicinity': '5705 Charlotte Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1239257, 'lng': -86.850561},
#     'viewport': {'northeast': {'lat': 36.12517007989273,
#       'lng': -86.84904282010727},
#      'southwest': {'lat': 36.12247042010728, 'lng': -86.8517424798927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110390319083466216606">A Google User</a>'],
#      'photo_reference': 'ATtYBwKkKxIZgRWOAMFC0M_7o8kUcYO6yXa7enKvWJwEAiCziwdvNSOYJk3gF_lP67p2B30D6qK-MdMGpTmBScoZFoeEUTjgBaRElj4ciZ5Kx01bKun4vB4mrXbsgtCxs1Z6yxM2rmlSw9pr9p2lDiT8liA2AZVS0oBXkLBuRjpeBiiSY_YA',
#      'width': 4032}],
#    'place_id': 'ChIJgwbO18RjZIgRiitXTeFueHE',
#    'plus_code': {'compound_code': '44FX+HQ Nashville, Tennessee',
#     'global_code': '868M44FX+HQ'},
#    'price_level': 2,
#    'rating': 4,
#    'reference': 'ChIJgwbO18RjZIgRiitXTeFueHE',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 200,
#    'vicinity': '4560 Harding Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1031403, 'lng': -86.8187272},
#     'viewport': {'northeast': {'lat': 36.10447387989272,
#       'lng': -86.81720402010727},
#      'southwest': {'lat': 36.10177422010727, 'lng': -86.81990367989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Whole Foods Market',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100328642485214371191">Ash Rich</a>'],
#      'photo_reference': 'ATtYBwKfPHSb-gs0KSRuLWkFLWiqolzrQWPe2yOQjgacUwaLEm-ONxPn6BiRF2UkWIUOYjeGpudfyK-cyKm414ZjkCnWkwbxG2UdTEz6PS5-N0BGmM_LuNeXaNtfy0ZiW0NOQDVruMZ3Wki_3GS3_ZD5Qldz-3ZO739MsWjUbEOeOI-RZkmz',
#      'width': 3024}],
#    'place_id': 'ChIJX8-EyHBkZIgRUTl3H0DUliw',
#    'plus_code': {'compound_code': '453J+7G Nashville, Tennessee',
#     'global_code': '868M453J+7G'},
#    'price_level': 3,
#    'rating': 4.3,
#    'reference': 'ChIJX8-EyHBkZIgRUTl3H0DUliw',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'health',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 824,
#    'vicinity': '4021 Hillsboro Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1844743, 'lng': -86.74677849999999},
#     'viewport': {'northeast': {'lat': 36.18570212989272,
#       'lng': -86.74576282010727},
#      'southwest': {'lat': 36.18300247010728, 'lng': -86.74846247989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Kroger',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2201,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113827070569302562718">Andrew L</a>'],
#      'photo_reference': 'ATtYBwKFneIV0x772pulPfvv8Ld8dnxv_Eblz9WfhORRUO02vTN-0UR2HqSHHFSIw5-90naMHn_5JHSoI-GsGVwqBz8tUmCZI2Tj9Tw-EDBjMjBJBKPVu9h9z_qz74scIqGkcd00KKCS_900wtuAML28JQTX9Zs4uDY37wxAoyfsUjduQHe_',
#      'width': 7268}],
#    'place_id': 'ChIJCyiJ2tBnZIgReYaDDx5KLEM',
#    'plus_code': {'compound_code': '57M3+Q7 Nashville, Tennessee',
#     'global_code': '868M57M3+Q7'},
#    'price_level': 2,
#    'rating': 3.7,
#    'reference': 'ChIJCyiJ2tBnZIgReYaDDx5KLEM',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 686,
#    'vicinity': '711 Gallatin Ave, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1853811, 'lng': -86.8159932},
#     'viewport': {'northeast': {'lat': 36.18663382989272,
#       'lng': -86.81489022010727},
#      'southwest': {'lat': 36.18393417010728, 'lng': -86.81758987989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Save A Lot',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1440,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111089389699251425402">A Google User</a>'],
#      'photo_reference': 'ATtYBwKJQ65vRQwIpR17EAVKfOuwxqkKy6RC-2GHRwGLwHYB_FBNQmig5VTVcXf2t8i6k50wB7_jvgM_9QQr29erkpKH0TKDZNHlEFeokzikuDyGt4gNBPhxHfkrElB5Wc_78RUAJOntH6FVKCmY73f_-HzEQdc6G1CHja6NCrqJ4Gsi-vex',
#      'width': 2560}],
#    'place_id': 'ChIJCTHj7C5nZIgR8KzLicfUjkw',
#    'plus_code': {'compound_code': '55PM+5J Nashville, Tennessee',
#     'global_code': '868M55PM+5J'},
#    'rating': 4,
#    'reference': 'ChIJCTHj7C5nZIgR8KzLicfUjkw',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 511,
#    'vicinity': '2400 Clarksville Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1267272, 'lng': -86.8475064},
#     'viewport': {'northeast': {'lat': 36.12797762989273,
#       'lng': -86.84605667010729},
#      'southwest': {'lat': 36.12527797010728, 'lng': -86.84875632989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Publix Super Market at Hill Center at Belle Meade',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116780368244981387168">Sarah Crawford</a>'],
#      'photo_reference': 'ATtYBwKKkx_VH2BbYLYUvk98J-taIB58eTqVHoYZpuOIp8oUo6No-5Uxx4PK9T0hmw-GpOg2SpF3eOuzRRL3Hvc0kJtxcPsd-cT7HsNm0o6_xB7kAURNx8cpmA07lC5PAkiEmlvWAzgrM5Oxq_gOQ4tN3srtTfhEMyPTg4m-JistiLR_RrZq',
#      'width': 3984}],
#    'place_id': 'ChIJ_98e89xjZIgRkX7e3TmFvyw',
#    'plus_code': {'compound_code': '45G2+MX Nashville, Tennessee',
#     'global_code': '868M45G2+MX'},
#    'price_level': 2,
#    'rating': 4.4,
#    'reference': 'ChIJ_98e89xjZIgRkX7e3TmFvyw',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'bakery',
#     'liquor_store',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 357,
#    'vicinity': '4324 Harding Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1014506, 'lng': -86.7401198},
#     'viewport': {'northeast': {'lat': 36.10276232989272,
#       'lng': -86.7388847201073},
#      'southwest': {'lat': 36.10006267010728, 'lng': -86.74158437989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'Osborne Bi-Rite',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2184,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113970857497524711494">Bobby Boucher</a>'],
#      'photo_reference': 'ATtYBwKhgrTfpLIMLVYwIx-UmPAOwBn1myngHSYWBwN0qcwbNYHFvjW4m-nydkNlV4ExeFOJU_VRDRIMvasKHD8UkHg-m4NQ87FVC-DPUHpLjDBxtEN3arVjAnqa0apTZE0k-2_-w1dFtvG5OZNRPGf9D0mFJsTvKSgSe6j8D8V4xF6YJBWO',
#      'width': 4608}],
#    'place_id': 'ChIJ5y2372JvZIgR1_y4Qj-MW2g',
#    'plus_code': {'compound_code': '4725+HX Nashville, Tennessee',
#     'global_code': '868M4725+HX'},
#    'rating': 4.4,
#    'reference': 'ChIJ5y2372JvZIgR1_y4Qj-MW2g',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 226,
#    'vicinity': '3302 Nolensville Pike, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1329002, 'lng': -86.7887039},
#     'viewport': {'northeast': {'lat': 36.13425077989272,
#       'lng': -86.78734452010728},
#      'southwest': {'lat': 36.13155112010728, 'lng': -86.79004417989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': 'The Store',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJyzYwFj5lZIgRFGB0hYpHoQA',
#    'plus_code': {'compound_code': '46M6+5G Nashville, Tennessee',
#     'global_code': '868M46M6+5G'},
#    'rating': 5,
#    'reference': 'ChIJyzYwFj5lZIgRFGB0hYpHoQA',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 11,
#    'vicinity': '2009 12th Ave S, Nashville'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 36.1739207, 'lng': -86.7459911},
#     'viewport': {'northeast': {'lat': 36.17517912989273,
#       'lng': -86.74465462010728},
#      'southwest': {'lat': 36.17247947010728, 'lng': -86.74735427989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'name': '4 Way Market',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106875532012586085102">Massbaum</a>'],
#      'photo_reference': 'ATtYBwITQbPtB72YByRUqdJYtHMjpygmfy_vQtKM5Rs9zQqMN0HO0CSOLbR_FH9Umlfvf9ymQGVu8uUTjQbkmsdtARETCyEEZcdOVtkomm-R4t-u6SG-LGtDj2svGlfbsfSBvSD4zxTVEmX4gcbtop_wLnbaZb0oPyO44EKWKcd1pTwUzjdG',
#      'width': 4032}],
#    'place_id': 'ChIJCXauaCtmZIgRYZpTghT1TBE',
#    'plus_code': {'compound_code': '57F3+HJ Nashville, Tennessee',
#     'global_code': '868M57F3+HJ'},
#    'rating': 4.3,
#    'reference': 'ChIJCXauaCtmZIgRYZpTghT1TBE',
#    'scope': 'GOOGLE',
#    'types': ['grocery_or_supermarket',
#     'supermarket',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 72,
#    'vicinity': '1401 Fatherland St, Nashville'}],
#  'status': 'OK'}

# %% [markdown]
# response_df = pd.read_json('E:/Capstone/res.json')
# response_df_df.head()

# %%
nash_map = folium.Map([36.163242365862246,-86.78142455028717], zoom_start = 12)

for store in response['results']:
    lat_lng = store['geometry']['location']
    location = [lat_lng['lat'], lat_lng['lng']]
    popup = store['name']
    folium.Marker(location = location, popup = popup).add_to(nash_map)

nash_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# https://docs.python.org/3/library/json.html

# %% [markdown]
# res=response.json()

# %% [markdown]
# res

# %% [markdown]
# pd.DataFrame.from_dict(res)

# %% [markdown]
# response.content

# %% [markdown]
# endpoint='https://maps.googleapis.com/maps/api/place/nearbysearch/json&key:'

# %% [markdown]
# soup = BeautifulSoup(response.content, "html.parser")
# soup.find(attrs={"class": "section-result"}) \
#     .find("table")

# %% [markdown]
# places = pd.concat(response)
# places

# %% [markdown]
# star
